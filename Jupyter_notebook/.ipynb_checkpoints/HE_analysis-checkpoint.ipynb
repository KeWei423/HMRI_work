# %%
import os
from datascience import *
import numpy as np
import pandas as pd

import matplotlib.pyplot as plots
from mpl_toolkits.mplot3d import Axes3D
plots.style.use('fivethirtyeight')
# %matplotlib inline

# %%
# import all files into 1 dictionary and conver that into a table
def create_database(path=os.getcwd()):
    subjects_dict={}
    for filename in os.listdir(path):
        if filename.endswith(".txt"):
            ID=filename.split("_")[0]
#             print("ID: ",ID)
            f = open(filename)
            lines = f.read()
            if not len(lines)==0 :
                values = lines.replace("  \n","").split("  \t")
                numb_values = [float(numb) for numb in values] 
#                 print(numb_values)
                subjects_dict[ID]=numb_values
            else:
#                 subjects_dict[ID]=[]
                continue
        else:
            continue
    return subjects_dict

# %%
def make_study_table(data_dict):
    title=["ID", "Cerebral_WM", "Cerebral_cortex", "Cerebellum_WM", "Cerebellum_cortex",
           "Caudate", "Putamen","globus_pallidus","Brain_stem", "Class"]
    study_table=Table(title)
    for key, values in data_dict.items():
        row=[key]
        row.extend(values)
        if key.startswith("BR"):
            row.append(0)
        else:
            row.append(1)
        study_table=study_table.with_row(row)
    return study_table

# %%
def generate_data(path):

    title=["ID", "Cerebral_WM", "Cerebral_cortex", "Cerebellum_WM", "Cerebellum_cortex","Caudate", "Putamen","globus_pallidus","Brain_stem"]
    
    data=pd.DataFrame(columns=title[1:])
#     data.set_index("ID")
    
    for filename in os.listdir(path):
        #get content
        content = open(os.path.join(path,filename)).read().replace(" \n","")
        content = float(content)
#         print(filename, ": ", content)
       
        #get ID 
        if filename.startswith("BR"):
            ID=filename[0:5]
        else:
            ID=filename[0:15]
        
        temp=pd.DataFrame({ID:[""*(len(title)-2)]})
    
        #get ROI name
        if title[1] in filename:
            data.at[ID, title[1]]=content
        elif title[2] in filename:
            data.at[ID, title[2]]=content
        elif title[3] in filename:
            data.at[ID, title[3]]=content
        elif title[4] in filename:
            data.at[ID, title[4]]=content
        elif title[5] in filename:
            data.at[ID, title[5]]=content
        elif title[6] in filename:
            data.at[ID, title[6]]=content
        elif title[7] in filename:
            data.at[ID, title[7]]=content
        elif title[8] in filename:
            data.at[ID, title[8]]=content
#            values[7]=content
        
#     print("row: ", values)
    return data

# %%
df=generate_data("/Users/baymac/Desktop/Data_todo/Result")
df
# Out:
#                 Cerebral_WM Cerebral_cortex Cerebellum_WM Cerebellum_cortex  \
# MEN039_20170814     1368.78         987.719        1285.9           934.379
# BR038               1705.84         1229.93       1696.92           1234.69
# MEN040_20170512     2131.39         1400.17       2104.43           1487.92
# MEN028_20170316     1846.92         1395.79          1795           1355.08
# MEN013_20170222      1375.4         1011.67       1345.86           1006.82
# BR019               1517.16         1134.15          1472           1102.35
# BR031               1293.79         962.066       1197.91           834.651
# MEN052_20190318     2360.98         1482.11        2290.4           1694.89
# MEN044_20180515     927.583         687.327        874.87            666.32
# MEN044_20180821     1406.89         1055.49       1281.63           1010.59
# MEN001_20170214  1131.15  1255.37         1503.43    1289.72
# BR012            1085.43  1226.21         1472.68    1314.79
# BR017            1386.63  1532.29         1798.82    1667.23
# BR014            1337.16   1465.4         1685.44    1520.84
# BR030            944.793  1069.46         1198.79    870.479
#
# [70 rows x 8 columns]

# %%
df.loc["BR030", "Brain_stem"]
# Out:
# 870.4792602

# %%
df.to_csv("/Users/baymac/Desktop/HE_relabel_final.csv")

# %%
og_data=Table.read_table("/Users/baymac/Desktop/HE_data.csv")
og_data
# Out:
# Column 1 | cirrhosis | pre/post TIPS | class type | Cerebral_WM | Cerebral_cortex | Cerebellum_WM | Cerebellum_cortex | Caudate | Putamen | globus_pallidus | Brain_stem
# BR001    | control   | nan           | control    | 1646.51     | 1272.37         | 1725.36       | 1304              | 1253.83 | 1385.49 | 1660.72         | 1540.81
# BR003    | control   | nan           | control    | 1354.88     | 979.476         | 1350.03       | 996.406           | 1017.35 | 1151.41 | 1336.77         | 1267.68
# BR004    | control   | nan           | control    | 1654.65     | 1225.83         | 1569.79       | 1212.37           | 1248.75 | 1471.32 | 1694.71         | 1493.12
# BR005    | control   | nan           | control    | 1562.65     | 1124.92         | 1528.4        | 1102.42           | 1116.96 | 1268.21 | 1525.92         | 1440.27
# BR006    | control   | nan           | control    | 1439.74     | 1046.56         | 1352.7        | 931.593           | 1046.37 | 1117.99 | 1378.33         | 1225.09
# BR007    | control   | nan           | control    | 1777.37     | 1422.65         | 1612.67       | 1149.59           | 1293.23 | 1428.47 | 1597.55         | 1530.52
# BR009    | control   | nan           | control    | 1376.64     | 1007.75         | 1369.24       | 1023.37           | 1007.38 | 1135.41 | 1368.01         | 1265.24
# BR010    | control   | nan           | control    | 1185.38     | 1114.97         | 1255.67       | 1094.55           | 1322.5  | 1306.04 | 1235.51         | 700.549
# BR011    | control   | nan           | control    | 1528.72     | 1184.09         | 1490.47       | 1136.38           | 1161.63 | 1269.08 | 1529.33         | 1373.12
# BR012    | control   | nan           | control    | 1498.19     | 1157.56         | 1477.95       | 1110.1            | 1085.43 | 1226.21 | 1472.68         | 1314.79
# ... (60 rows omitted)

# %%
current_data=og_data.with_columns(
    "gp/Cerebral_WM", og_data.column("globus_pallidus") / og_data.column("Cerebral_WM"),
    "gp/Cerebral_cortex", og_data.column("globus_pallidus") / og_data.column("Cerebral_cortex"),
    "gp/Cerebellum_WM", og_data.column("globus_pallidus") / og_data.column("Cerebellum_WM"),
    "gp/Cerebellum_cortex", og_data.column("globus_pallidus") / og_data.column("Cerebellum_cortex"),
    "gp/brainstem", og_data.column("globus_pallidus") / og_data.column("Brain_stem"),
    
    "putamen/Cerebral_WM", og_data.column("Putamen") / og_data.column("Cerebral_WM"),
    "putamen/Cerebral_cortex", og_data.column("Putamen") / og_data.column("Cerebral_cortex"),
    "putamen/Cerebellum_WM", og_data.column("Putamen") / og_data.column("Cerebellum_WM"),
    "putamen/Cerebellum_cortex", og_data.column("Putamen") / og_data.column("Cerebellum_cortex"),
    "putamen/brainstem", og_data.column("Putamen") / og_data.column("Brain_stem"),
    
    "caudate/Cerebral_WM", og_data.column("Caudate") / og_data.column("Cerebral_WM"),
    "caudate/Cerebral_cortex", og_data.column("Caudate") / og_data.column("Cerebral_cortex"),
    "caudate/Cerebellum_WM", og_data.column("Caudate") / og_data.column("Cerebellum_WM"),
    "caudate/Cerebellum_cortex", og_data.column("Caudate") / og_data.column("Cerebellum_cortex"),
    "caudate/brainstem", og_data.column("Caudate") / og_data.column("Brain_stem")
)


current_data
# Out:
# Column 1 | cirrhosis | pre/post TIPS | class type | Cerebral_WM | Cerebral_cortex | Cerebellum_WM | Cerebellum_cortex | Caudate | Putamen | globus_pallidus | Brain_stem | gp/Cerebral_WM | gp/Cerebral_cortex | gp/Cerebellum_WM | gp/Cerebellum_cortex | gp/brainstem | putamen/Cerebral_WM | putamen/Cerebral_cortex | putamen/Cerebellum_WM | putamen/Cerebellum_cortex | putamen/brainstem | caudate/Cerebral_WM | caudate/Cerebral_cortex | caudate/Cerebellum_WM | caudate/Cerebellum_cortex | caudate/brainstem
# BR001    | control   | nan           | control    | 1646.51     | 1272.37         | 1725.36       | 1304              | 1253.83 | 1385.49 | 1660.72         | 1540.81    | 1.00863        | 1.30522            | 0.962536         | 1.27356              | 1.07782      | 0.841472            | 1.08891                 | 0.803016              | 1.0625                    | 0.899195          | 0.76151             | 0.985432                | 0.726709              | 0.961531                  | 0.813748
# BR003    | control   | nan           | control    | 1354.88     | 979.476         | 1350.03       | 996.406           | 1017.35 | 1151.41 | 1336.77         | 1267.68    | 0.986628       | 1.36478            | 0.990173         | 1.34159              | 1.0545       | 0.849819            | 1.17553                 | 0.852872              | 1.15556                   | 0.908275          | 0.750873            | 1.03866                 | 0.753571              | 1.02102                   | 0.802524
# BR004    | control   | nan           | control    | 1654.65     | 1225.83         | 1569.79       | 1212.37           | 1248.75 | 1471.32 | 1694.71         | 1493.12    | 1.02421        | 1.3825             | 1.07958          | 1.39785              | 1.13502      | 0.889205            | 1.20026                 | 0.937274              | 1.21359                   | 0.985402          | 0.754695            | 1.0187                  | 0.795492              | 1.03001                   | 0.836339
# BR005    | control   | nan           | control    | 1562.65     | 1124.92         | 1528.4        | 1102.42           | 1116.96 | 1268.21 | 1525.92         | 1440.27    | 0.976495       | 1.35647            | 0.99838          | 1.38415              | 1.05947      | 0.811576            | 1.12738                 | 0.829765              | 1.15038                   | 0.880539          | 0.714787            | 0.992928                | 0.730806              | 1.01319                   | 0.775524
# BR006    | control   | nan           | control    | 1439.74     | 1046.56         | 1352.7        | 931.593           | 1046.37 | 1117.99 | 1378.33         | 1225.09    | 0.957347       | 1.317              | 1.01895          | 1.47954              | 1.12508      | 0.776522            | 1.06825                 | 0.826488              | 1.20008                   | 0.912575          | 0.726783            | 0.99982                 | 0.773548              | 1.12321                   | 0.85412
# BR007    | control   | nan           | control    | 1777.37     | 1422.65         | 1612.67       | 1149.59           | 1293.23 | 1428.47 | 1597.55         | 1530.52    | 0.898829       | 1.12294            | 0.990624         | 1.38967              | 1.0438       | 0.803698            | 1.00409                 | 0.885779              | 1.24259                   | 0.933324          | 0.72761             | 0.909027                | 0.80192               | 1.12495                   | 0.844964
# BR009    | control   | nan           | control    | 1376.64     | 1007.75         | 1369.24       | 1023.37           | 1007.38 | 1135.41 | 1368.01         | 1265.24    | 0.993733       | 1.35749            | 0.999103         | 1.33676              | 1.08122      | 0.82477             | 1.12668                 | 0.829227              | 1.10948                   | 0.897383          | 0.731771            | 0.999637                | 0.735726              | 0.984375                  | 0.796197
# BR010    | control   | nan           | control    | 1185.38     | 1114.97         | 1255.67       | 1094.55           | 1322.5  | 1306.04 | 1235.51         | 700.549    | 1.04229        | 1.10811            | 0.983939         | 1.12878              | 1.76362      | 1.10179             | 1.17137                 | 1.04011               | 1.19321                   | 1.8643            | 1.11568             | 1.18613                 | 1.05322               | 1.20825                   | 1.8878
# BR011    | control   | nan           | control    | 1528.72     | 1184.09         | 1490.47       | 1136.38           | 1161.63 | 1269.08 | 1529.33         | 1373.12    | 1.00039        | 1.29156            | 1.02607          | 1.34579              | 1.11376      | 0.830157            | 1.07178                 | 0.851461              | 1.11677                   | 0.924233          | 0.759872            | 0.981034                | 0.779373              | 1.02222                   | 0.845984
# BR012    | control   | nan           | control    | 1498.19     | 1157.56         | 1477.95       | 1110.1            | 1085.43 | 1226.21 | 1472.68         | 1314.79    | 0.982975       | 1.27223            | 0.996437         | 1.32662              | 1.12009      | 0.818463            | 1.05931                 | 0.829672              | 1.10459                   | 0.932629          | 0.724496            | 0.937693                | 0.734418              | 0.977777                  | 0.825555
# ... (60 rows omitted)

# %%
current_data.to_csv("/Users/baymac/Desktop/HE_final.csv")

# %%
# work_dir="/Users/baymac/Desktop/results/Results_org/"
work_dir="/Users/baymac/Desktop/results/Results_org/"

# %%
def organize_files(path):
    
    header=["Index","SegId", "NVoxels_Volume_mm3", "StructName", "Mean", "StdDev", "Min", "Max", "Range"]
    counter=0
    db=pd.DataFrame()
    lable=[]
    for filename in os.listdir(path):
#         print("file: ", filenames)
        file=pd.read_csv(path+filename, comment="#", delim_whitespace=True, names=header)
        if counter==0:
            lable=file[['StructName']].T
            db=db.append(lable)
        row=file[['Mean']].T          
        row=row.rename({'Mean':filename[:-8]},axis='index')
        db=db.append(row)
        counter += 1
    db.names=lable
    return db

# %%
data=organize_files(work_dir)
data
data.loc["MEN001_20170214.",13]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# 141.2935

# %%
data.to_csv("/Users/baymac/Desktop/HE_org_pandas.csv")
