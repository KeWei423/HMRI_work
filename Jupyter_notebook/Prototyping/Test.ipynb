# %%
import pandas as pd

# %%
path = '/home/ke/Desktop/Project_Bread/tonometry.xlsx'

# %%
data = pd.read_excel(path, sheet_name=None)
for sheet in data:
    print(data[sheet])
# Out:
#     System ID Database ID  Patient Number   Surname First Name     Sex  \
# 0        1609        DATA              84         M          S  FEMALE
# 1        1609        DATA             104         C         SH  FEMALE
# 2        1609        DATA             102         R          S    MALE
# 3        1609        DATA             109         M          R  FEMALE
# 4        1609        DATA             105         O          J    MALE
# 5        1609        DATA              88         D          K  FEMALE
# 6        1609        DATA              89         P          S  FEMALE
# 7        1609        DATA              92  McIntyre          S  FEMALE
# 8        1609        DATA             101         G          R  FEMALE
# 9        1609        DATA             110        Ch          W    MALE
# 10       1609        DATA              85         H          M  FEMALE
# 11       1609        DATA              86         P          P  FEMALE
# ...
