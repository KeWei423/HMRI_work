# %%
import os
import pandas as pd
import fnmatch
import re

# %%
# BIGGO TO DO:
# trash bin for each filter

# %%
# NOTE: Possible names for each sequence

# "3D_T1": ['*SAG*T1*NII', '*SAG*FSPGR*3D*NII']
# "FLAIR": <ID>_{SAG | AX | COR}_[T1_ | T2_][3D_]FLAIR_<DOE>.nii
# "T2": <ID>_{SAG | AX | COR}_3D_T2_[<type>]<DOE>.nii
# "T2": <ID>_{SAG | AX | COR}_T2_[<type>]<DOE>_<tag>.nii
# "BOLD": <ID>_BOLD_<DOE>.nii
# "Diffusion kurtosis": <ID>_{AX}_DkI_<small#dirs>_<DOE>.nii
#                       <ID>_{AX}_DkI_<small#dirs>_<DOE>.bval
#                       <ID>_{AX}_DkI_<small#dirs>_<DOE>.bvec
# .                     <ID>_{AX}_DkI_<big#dirs>_<DOE>.nii
#                       <ID>_{AX}_DkI_<big#dirs>_<DOE>.bval
#                       <ID>_{AX}_DkI_<big#dirs>_<DOE>.bvec
# "Diffusion tensor": <ID>_{AX}_D{k|T}I_<#dir>_<DOE>.nii
#                     <ID>_{AX}_D{k|T}I_<#dir>_<DOE>.bval
#                     <ID>_{AX}_D{k|T}I_<#dir>_<DOE>.bvec
# "Diffusion weithed": <ID>_{AX}_DWI_<DOE>.nii
#                      <ID>_{AX}_DWI_<DOE>.bval
#                      <ID>_{AX}_DWI_<DOE>.bvec
# "ASL": <ID>_{SAG | AX | COR}_ASL_<DOE>.nii   
# "SWAN": <ID>_{SAG | AX | COR}_ASL_<DOE>.nii
# "Carotid"
# "Aorta": <ID>_[CINE]_AORTA_VENC_<number>_<DOE>.nii

# %%
def get_sequence_info(sequence_name):
    """
    Convert the input from string to list 
    --------------------------------------------------------
    input:
        sequence_name: string
        
    return:
        array-like: splited the string into items for parsing later
    """
    str_list = sequence_name.replace('-','_').replace('.','_').split('_')
    if not (str_list[-1] == 'NII' or str_list[-1] == 'JSON'):
        return None
    
    str_list = list(filter(None, str_list)) 
    return str_list

#selected everything expect the '.nii' part of the string

# %%
def ignore_notes(sequence_info):
    """
    ignore notes inside the parentheses of sequence_info
    --------------------------------------------------------
    input:
        sequence_info: array-like
        
    return:
        array-like: sequence info without the parentheses and notes inside of them
    """
    
    other = []
    
    for part in sequence_info:
        if '(' not in part and ')' not in part:
            other.append(part)

    return other

# %%
def get_DOE(info):
    """
    get the date of exam 
    --------------------------------------------------------
    input:
        info: array-like
        
    return:
        string: date of exame in YYYY/MM/DD
    """
    
    if 'I' in info[-1]:
        DOE=info[-2]
        return(DOE[0:4]+"/"+DOE[4:6]+'/'+DOE[6:8])
    else:
        DOE=info[-1]
        return(DOE[0:4]+"/"+DOE[4:6]+'/'+DOE[6:8])

# %%
def base_standard(o_name):
    """
    clean up the user input sequence name into a standardized naming convetion for sorting later
        SAGITTLE --> SAG
           AXIAL --> AX
         CORONAL --> COR
            CUBE --> 3D
        WHITTIER --> WH
              RT --> RIGHT
              LT --> LEFT
    --------------------------------------------------------
    input:
        o_name: string
    
    return:
        string: standardized sequnece file name
    """
    
    n_name = o_name.replace('SAGITTAL', 'SAG').replace('CUBE', '3D').replace('AXIAL', 'AX').replace('CORONAL', 'COR')
    n_name = n_name.replace('RT', 'RIGHT').replace('LT', 'LEFT')
    info=get_sequence_info(n_name)
    
    ID = info[0]
    # ID does not follow designation [2-3 letter cohort designation][3-4 number designation]
    match = re.match(r"([A-Z]+)([0-9]+)", ID, re.I)
    if match:
        parts = match.groups()
        if parts[0] == 'WHITTIER':
            n_name = n_name.replace('WHITTIER', 'WH')
    return n_name

# %%
# <ID>_{SAG | AX | COR}_[T1_ | T2_][3D_]FLAIR_[MIP_ | MIN_IP_]<DOE>[_<tag>].nii
def filt_T1(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    # TO-DO: how to handle 
    # 1) NEUROMELANIN scans
    # 2) SE_MT
    # 3) BRAVO
    # 4) 2DTOF
    # 5) repeat?
    
    sequence_info=get_sequence_info(sequence_name)
    if sequence_info is None:
        return None
    
    if '3D' not in sequence_info and sequence_info[-1][0] == 'I':
        sequence_info[-1] = sequence_info[-1].lower()
    elif not sequence_info[-1][-1].isdigit():
        trash.append(sequence_name)
        return None

    ignore=['AVG', 'MIN', 'POST_PROCESS', 'MT', '2DTOF', 'OBLIQUE', 'THIN']
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    accept = ['SAG', 'AX', 'COR']
    if not any(word in sequence_name for word in accept):
        trash.append(sequence_name)
        return None
    
#     print("file name:", file_name)
    return sequence_name[:-4]+'.nii'

    
#TO-DO: repeated exam of the same date or at the different date

# %%
# Naming to be estabilshed
# <ID>_{SAG | AX | COR}_[T1_ | T2_][3D_]FLAIR_[MIP_ | MIN_IP_]<DOE>[_<tag>].nii
def filt_FLAIR(sequence_name, flair_3d, flair_2d, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        flair_3d : array-like
            List of files that are 3D FLAIR
        flair_2d : array-like
            List of files that are 2D FLAIR
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)
    if sequence_info is None:
        return None
            
    ignore=['AVG', 'MIN', 'MIP']
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    if '3D' not in sequence_info and sequence_info[-1][0] == 'I':
        sequence_info[-1] = sequence_info[-1].lower()
    elif not sequence_info[-1].isdigit():
        trash.append(sequence_name)
        return None
    
    if "SAG" in sequence_name:
#         print(sequence_info)
        if '3D' in sequence_name:
            flair_3d.append(sequence_name)
        else:
            flair_2d.append(sequence_name)
    elif 'AX' in sequence_name:
#         print(sequence_info)
        if '3D' in sequence_name:
            flair_3d.append(sequence_name)
        else:
            flair_2d.append(sequence_name)
    elif 'COR' in sequence_name:
#         print(sequence_info)
        if '3D' in sequence_name:
            flair_3d.append(sequence_name)
        else:
            flair_2d.append(sequence_name)
    else: 
#         print("\t ", sequence_name)
        trash.append(sequence_name)
        return None
            
    sequence_name = '_'.join(sequence_info)+'.nii'
    return sequence_name

#TO-DO: T1 has 3D, 2D

# %%
# Naming to be established:
# "T2": <ID>_{SAG | AX | COR}_3D_T2_[<type>]<DOE>.nii
# "T2": <ID>_{SAG | AX | COR}_T2_[<type>]<DOE>_<tag>.nii
def filt_T2(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)
    if sequence_info is None:
        return None
    
    ignore=['AVG', 'MIN', 'MIP']
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    if '3D' not in sequence_info and sequence_info[-1][0] == 'I':
        sequence_info[-1] = sequence_info[-1].lower()
    elif not sequence_info[-1].isdigit():
        trash.append(sequence_name)
        return None
#     print(sequence_info)
        
    return '_'.join(sequence_info)+'.nii'

#TO-DO: T2 has difference pulse types :0 and some other things

# %%
def filt_DWI(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=sequence_name.replace('-','_').replace('.','_').split('_')
#     print(sequence_info)
    
    
    if 'AX' not in sequence_info:
        sequence_info=sequence_info[0:1]+['AX']+sequence_info[1:]

    if len(sequence_info) > 6:
        trash.append(sequence_name)
#             print(sequence_info)
        return None

    if not sequence_info[-2].isdigit():
        trash.append(sequence_name)
#             print("repeeat:",sequence_info)
        return None
    else:
        #1. concatinate all with _expect the last item
        #2. lower case the extension (last item) and add a . in front of it
        n_name=('_'.join(sequence_info[:-1]))+'.'+sequence_info[-1].lower()
        return n_name

# %%
def filt_DTI(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
    n_name = sequence_name.replace('_30_DIRECTION_', '_(30_DIRECTION)_')
    
    n_name = n_name[:-4] + n_name[-4:].lower()
    return n_name

# %%
def filt_DKI(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    if 'EQ_1' in sequence_name:
        trash.append(sequence_name)
        return None
    
    n_name = sequence_name[:-4] + sequence_name[-4:].lower()
    return n_name

# %%
# BOLD naming convention: <ID>_BOLD_<DOE>.nii
def filt_bold(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)
    
    problem_bold = None
    
    sequence_info = ignore_notes(sequence_info)
    sequence_name = '_'.join(sequence_info)+'.nii'    
    
    # The following ID's are the problem ones (from previous runs). Checking if these ID's are unique
#     probs = ['SH005', 'WH1296', 'MEN009', 'WH1612', 'WH1268', 'MEN040', 'SH019', 
#              'MEN023', 'MEN007', 'WHITTIER5002']
    
    # If it contains EQ_1 or a letter attached to the end of the DOE,
    # then there is a previous one that already exists
    if sequence_info[-2] == 'EQ' or not sequence_info[-1].isdigit():
        trash.append(sequence_name)
        return None
        
#     elif ID in probs:
#         problem_bold = sequence_name
    
    elif len(sequence_info) != 3:
        problem_bold = sequence_name
    
#     return problem_bold
    return sequence_name

# %%
def filt_asl(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)            
    sequence_info=ignore_notes(sequence_info)
    if '3D' not in sequence_info and sequence_info[-1][0] == 'I':
        sequence_info[-1] = sequence_info[-1].lower()
    elif not sequence_info[-1].isdigit():
        trash.append(sequence_name)
        return None

    ignore=['DELAY', 'FL']
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    return '_'.join(sequence_info)+'.nii'

# %%
def filt_swan(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)            
    sequence_info=ignore_notes(sequence_info)
    if '3D' not in sequence_info and sequence_info[-1][0] == 'I':
        sequence_info[-1] = sequence_info[-1].lower()
    elif not sequence_info[-1].isdigit():
        trash.append(sequence_name)
        return None

    ignore=['MIDBRAIN']
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    return '_'.join(sequence_info)+'.nii'

# %%
def filt_csf(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    if '1.5' in sequence_name:
        trash.append(sequence_name)
        return None
    
    sequence_info=get_sequence_info(sequence_name)
#     print(sequence_name)
#     print(sequence_info)
    if not sequence_info[-1].isdigit():
        trash.append(sequence_name)
        return None
    
    # NOTE: V vs VC vs VENC
    ignore=['CF', 'FM']
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    return '_'.join(sequence_info)+'.nii'

#TO-DO: CSF of different location and CINE ON/OFF

# %%
def filt_carotid(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)
#     print(sequence_name)

    if not sequence_info[-1][-1].isdigit():
        trash.append(sequence_name)
        return None 
    
    return '_'.join(sequence_info)+'.nii'

# %%
def filt_aorta(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)

    ignore=['ASCENDING']
    
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    return '_'.join(sequence_info)+'.nii'

# %%
def filt_candy_cane(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)
#     print(sequence_info)
    
    if not sequence_info[-1].isdigit():
        trash.append(sequence_name)
        return None
    
    return '_'.join(sequence_info)+'.nii'

# %%
def filt_arch(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    info=get_sequence_info(sequence_name)
#     print(sequence_name)
#     print(info)
    if not info[-1].isdigit():
        trash.append(sequence_name)
        return None
    
    if 'VENC' not in info:
        info.insert(3, 'VENC_???')
    
    return '_'.join(info)[:-4]+'.nii'

# %%
def filt_mpr(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)
#     print(sequence_name)
    print(sequence_info)

# %%
def filt_cbf(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)
    
    if sequence_info[-2] == 'EQ' or not sequence_info[-1].isdigit():
        trash.append(sequence_name)
        return None
    
    return '_'.join(sequence_info)+'.nii'

# %%
def filt_probe(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)
#     print(sequence_name)
#     print(sequence_info)
    return '_'.join(sequence_info)+'.nii'

# %%
def get_path(root):
    """
    Fliter through all the files in the given path
    --------------------------------------------------------
    Parameters:
        root : string
            Path the directory that contains all the files that is to be filtered through
    """
    
    t1=[]
    flair = []
    flair_3d = []
    flair_2d = []
    t2 = []
    bold = []
    dwi=[]
    dti = []
    dki = []
    swan = []
    asl=[]
    candy_cane=[]
    arch=[]
    aorta=[]
    csf = []
    carotid = []
    cbf=[]
    probe = []
        
    t1_t=[]
    flair_t = []
    t2_t = []
    bold_t = []
    dwi_t=[]
    dti_t = []
    dki_t = []
    swan_t = []
    asl_t=[]
    candy_cane_t=[]
    arch_t=[]
    aorta_t=[]
    csf_t = []
    carotid_t = []
    cbf_t=[]
    probe_t = []
    
    change = 0
    count = 0
    
    for path, subdirs, files in os.walk(root):
        for file in files:
            file_upper=base_standard(file.upper())
            if file_upper is None:
                continue
            if fnmatch.fnmatch(file_upper, '*T1*') or fnmatch.fnmatch(file_upper, '*FSPGR*'):                 
                n_file=filt_T1(file_upper, t1_t)
#                 print("T1:", n_file)
                if n_file is not None:
                    t1.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
#                 pass
            elif fnmatch.fnmatch(file_upper, '*FLAIR*'): 
#                 print("FLAIR: \t", file_upper)
                n_file = filt_FLAIR(file_upper, flair_3d, flair_2d, flair_t)
#                 print("FLAIR:", n_file)
                if n_file is not None:
                    flair.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
#                 pass
            elif fnmatch.fnmatch(file_upper, '*T2*'):
#                 print('\t', file_upper)
                n_file = filt_T2(file_upper, t2_t)
                if n_file is not None:
                    t2.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
#                 pass
            elif fnmatch.fnmatch(file_upper, '*BOLD*'):
                n_file = filt_bold(file_upper, bold_t)
                if n_file is not None:
#                     print(file, '-->', n_file)
                    bold.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
#                 pass
            elif fnmatch.fnmatch(file_upper, '*DWI*'):
#                 print('\t', file_upper)
                n_file=filt_DWI(file_upper, dwi_t)
                if n_file is not None:
                    dwi.append((file, n_file))
            elif fnmatch.fnmatch(file_upper, '*DTI*'):
#                 print('\t', file_upper)
                n_file=filt_DTI(file_upper, dti_t)
                if n_file is not None:
                    dti.append((file, n_file))
            elif fnmatch.fnmatch(file_upper, '*DKI*'):
#                 print('\t', file_upper)
                n_file=filt_DKI(file_upper, dki_t)
                if n_file is not None:
                    dki.append((file, n_file))
            elif fnmatch.fnmatch(file_upper, '*ASL*'):
                n_file=filt_asl(file_upper, asl_t)
                if n_file is not None:
                    asl.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
#                 pass
            elif fnmatch.fnmatch(file_upper, '*SWAN*'):
                # Swan files has very consistant sequence naming
                # beaware of ID naming though
                n_file = filt_swan(file_upper, swan_t)
                if n_file is not None:
                    swan.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
            elif fnmatch.fnmatch(file_upper, '*CSF*'):
#                 print('CSF:', file_upper)
                n_file = filt_csf(file_upper, csf_t)
                if n_file is not None:
                    csf.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
                pass
            elif fnmatch.fnmatch(file_upper, '*CAROTID*'):
                #Need to ask what the carotid is doing: 
                #1. need to know the naming convention for difference carotids
#                 print('Carotid:', file_upper)
                n_file = filt_carotid(file_upper, carotid_t)
                if n_file is not None:
                    carotid.append((file, n_file))
                pass
            elif fnmatch.fnmatch(file_upper, '*AORTA*'):
                n_file=filt_aorta(file_upper, aorta_t)
                if n_file is not None:
                    aorta.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
            elif fnmatch.fnmatch(file_upper, '*CEREBR*BLOOD*FLOW*'):
#                 print("cbf:", file_upper)
                n_file=filt_cbf(file_upper, cbf_t)
                if n_file is not None:
                    cbf.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                     print(file, '-->', n_file)
            elif fnmatch.fnmatch(file_upper, '*MPR*'):
#                 print(file_upper)
#                 filt_mpr(file_upper)
                pass
            elif 'LOC' not in file_upper and fnmatch.fnmatch(file_upper, '*CANDY_CANE*'):
#                 print('Candy cane:', file_upper)
                n_file=filt_candy_cane(file_upper, candy_cane_t)
                if n_file is not None:
                    candy_cane.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                     print(file, '-->', n_file)
            elif 'LOC' not in file_upper and fnmatch.fnmatch(file_upper, '*ARCH*'):
                #    
                # 1. the inconsidency happens at the missing venc number.
                #
#                 print(file_upper)
                n_file = filt_arch(file_upper, arch_t)
                if n_file is not None:
                    arch.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                     print(file, '-->', n_file)
                pass
            elif 'LOC' not in file_upper and fnmatch.fnmatch(file_upper, '*PROBE*'):
#                 print(file_upper)
                n_file = filt_probe(file_upper, probe_t)
                if n_file is not None:
                    probe.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
                pass
            elif fnmatch.fnmatch(file_upper, '*'):
#                 print('\t', file_upper)
                pass
            else:
#                 print('\t\t', file_upper)
                pass

    trash = {'T1' : t1_t,
             'FLAIR' : flair_t,
             'T2' : t2_t,
             'BOLD' : bold_t,
             'DWI' : dwi_t,
             'DTI' : dti_t,
             'DKI' : dki_t,
             'SWAN' : swan_t,
             'ASL' : asl_t,
             'CANDY CANE' : candy_cane_t,
             'ARCH' : arch_t,
             'AORTA' : aorta_t,
             'CSF': csf_t,
             'CBF': cbf_t,
             'PROBE' :probe_t}
#     print(len(t1))
#     for pair in t1:
#         print(pair)
#     print(len(flair))
#     for pair in flair:
#         print(pair)
#     print(len(t2))
#     for pair in t2:
#         print(pair)
#     print(len(bold))
#     for pair in bold:
#         print(pair)
#     print(len(asl))
#     for pair in asl:
#         print(pair)
#     print(len(swan))
#     for pair in swan:
#         print(pair)
#     print(len(csf))
#     for pair in csf:
#         print(pair)
#     print(len(aorta))
#     for pair in aorta:
#         print(pair)
#     print(len(cbf))
#     for pair in cbf:
#         print(pair)
#     print(len(candy_cane))
#     for pair in candy_cane:
#         print(pair)
#     print(len(arch))
#     for pair in arch:
#         print(pair)
#     print(len(probe))
#     for pair in probe:
#         print(pair)

#     print("count: ", count)
#     print(change)

    for can in trash:
        print(can)
        for entry in trash[can]:
            print('\t', entry)

# %%
def main():
#     source_dir=input("Enter source dir:")
#     source_dir="/Users/baymac/Desktop/Project_NaCl_Test_DataSet/3T_Last_updated_31OCT19KW"
    source_dir = '/media/ke/8tb_part2/FSL_work/all_info'
    get_path(source_dir)

# %%
if __name__ =="__main__":
    main()
# Out:
# T1
# 	 MEN005_AX_FSPGR_MIN_20170223153214.NII
# 	 MEN005_COR_FSPGR_AVG_20170223153214.NII
# 	 MEN005_SAG_FSPGR_AVG_20170223153214.NII
# 	 MEN021_AX_FSPGR_MIN_20170302095957.NII
# 	 MEN021_COR_FSPGR_AVG_20170302095957.NII
# 	 MEN021_SAG_FSPGR_AVG_20170302095957.NII
# 	 BR022_NEUROMELANIN_T1_FSE-XL_20180130110501.NII
# 	 BR013_AX_2DTOF_FSPGR_20190315131838.NII
# 	 WH1662_AX_T1_SE_MT_20180608104614.NII
# 	 WH1340_COR_OBLIQUE_T1_20190404091541_I00001.NII
# 	 WH1340_COR_OBLIQUE_T1_20190404091541_I00002.NII
# 	 WH1419_AX_T1_SE_MT_20180629103853.NII
# 	 SH063_AX_T1_POST_PROCESS_20190821090159.NII
# 	 SH009_AX_FSPGR_MIN_20170112140902.NII
# 	 SH009_COR_FSPGR_AVG_20170112140902.NII
# 	 SH009_SAG_FSPGR_AVG_20170112140902.NII
# 	 BR048_AX_T1_POST_PROCESS_20190621094305.NII
# 	 WH1686_AX_T1_SE_MT_20181010154013.NII
# 	 BR003_AX_FSPGR_MIN_20170620095427.NII
# 	 BR003_COR_FSPGR_AVG_20170620095427.NII
# 	 BR003_SAG_FSPGR_AVG_20170620095427.NII
# 	 WH1354_AX_T1_SE_MT_20180608161238.NII
# 	 SH017_AX_FSPGR_MIN_20170213140013.NII
# 	 SH017_COR_FSPGR_AVG_20170213140013.NII
# 	 SH017_SAG_FSPGR_AVG_20170213140013.NII
# 	 SH004_AX_T1_(THIN)_20170106143911.NII
# 	 SH004_AX_T1_(THIN)_20170106143911A.NII
# 	 SH004_SAG_T1_C+_(THIN)_20170106143911.NII
# 	 SH004_AX_T1_C+_(THIN)_20170106143911.NII
# 	 BR029_NEUROMELANIN_T1_FSE-XL_20180410105120.NII
# 	 SH002_AX_FSPGR_MIN_20161216090218.NII
# 	 SH002_COR_FSPGR_AVG_20161216090218.NII
# 	 SH002_SAG_FSPGR_AVG_20161216090218.NII
# 	 WH1419_AX_T1_SE_MT_20180910105606.NII
# 	 WH1419_AX_T1_SE_MT_20180629103853.NII
# 	 BR038_SAG_FSPGR_3D_20190321144633A.NII
# 	 SH012_AX_FSPGR_MIN_20170131161308.NII
# 	 SH012_COR_FSPGR_AVG_20170131161308.NII
# 	 SH012_SAG_FSPGR_AVG_20170131161308.NII
# 	 WH1721_AX_T1_POST_PROCESS_20190813110806.NII
# 	 SH010_AX_FSPGR_MIN_20170120152021.NII
# 	 SH010_COR_FSPGR_AVG_20170120152021.NII
# 	 SH010_SAG_FSPGR_AVG_20170120152021.NII
# 	 WH1419_AX_T1_SE_MT_20180910105606.NII
# 	 BR015_NEUROMELANIN_T1_FSE-XL_20171206151415.NII
# 	 BR015_NEUROMELANIN_T1_FSE-XL_20171206151415A.NII
# 	 MEN014_AX_FSPGR_MIN_20170227145110.NII
# 	 MEN014_COR_FSPGR_AVG_20170227145110.NII
# 	 MEN014_SAG_FSPGR_AVG_20170227145110.NII
# 	 SH011_AX_FSPGR_MIN_20170131135040.NII
# 	 SH011_COR_FSPGR_AVG_20170131135040.NII
# 	 SH011_SAG_FSPGR_AVG_20170131135040.NII
# 	 SH062_AX_T1_POST_PROCESS_20190813091545.NII
# 	 BR00_AX_FSPGR_3D_T1_20171031102929_I00002A.NII
# 	 BR00_AX_FSPGR_3D_T1_20171031102929_I00001A.NII
# 	 BR035_AX_T1_POST_PROCESS_20190702101108.NII
# 	 MEN009_AX_FSPGR_MIN_20170307100421.NII
# 	 MEN009_COR_FSPGR_AVG_20170307100421.NII
# 	 MEN009_SAG_FSPGR_AVG_20170307100421.NII
# 	 WH1690_AX_T1_SE_MT_20180913120748.NII
# 	 SH059_AX_T1_SE_MT_20181018134702.NII
# 	 SH004_AX_FSPGR_MIN_20161220103018.NII
# 	 SH004_COR_FSPGR_AVG_20161220103018.NII
# 	 SH004_SAG_FSPGR_AVG_20161220103018.NII
# 	 WH1655_AX_T1_SE_MT_20180626145230.NII
# 	 BR018_NEUROMELANIN_T1_FSE-XL_20171218112857.NII
# 	 MEN022_AX_FSPGR_MIN_20170227110618.NII
# 	 MEN022_COR_FSPGR_AVG_20170227110618.NII
# 	 MEN022_SAG_FSPGR_AVG_20170227110618.NII
# 	 WH1648_NEUROMELANIN_T1_FSE-XL_20171213095323.NII
# 	 WH1601_AX_FSPGR_3D_T1_20170331102006_I00002A.NII
# 	 WH1601_AX_FSPGR_3D_T1_20170331102006_I00001A.NII
# 	 WH1487_AX_FSPGR_MIN_20170306175459.NII
# 	 WH1487_COR_FSPGR_AVG_20170306175459.NII
# 	 WH1487_SAG_FSPGR_AVG_20170306175459.NII
# 	 BR026_NEUROMELANIN_T1_FSE-XL_20180327114408A.NII
# 	 BR026_NEUROMELANIN_T1_FSE-XL_20180327114408.NII
# 	 SH003_AX_T1_POST_PROCESS_20190816130333.NII
# 	 WH1449_AX_FSPGR_MIN_20170314150459.NII
# 	 WH1449_COR_FSPGR_AVG_20170314150459.NII
# 	 WH1449_SAG_FSPGR_AVG_20170314150459.NII
# 	 WH1657_NEUROMELANIN_T1_FSE-XL_20180409150847.NII
# 	 BR001_SAG_FSPGR_3D_T1_20170511102034A.NII
# 	 WH1651_NEUROMELANIN_T1_FSE-XL_20180501103329.NII
# 	 BR037_AX_T1_SE_MT_20181012092433.NII
# 	 1499_AX_FSPGR_MIN_20170111101313.NII
# 	 1499_COR_FSPGR_AVG_20170111101313.NII
# 	 1499_SAG_FSPGR_AVG_20170111101313.NII
# 	 BR027_NEUROMELANIN_T1_FSE-XL_20180328115320.NII
# 	 BR021_NEUROMELANIN_T1_FSE-XL_20180124120947.NII
# 	 MEN029_AX_FSPGR_MIN_20170222161055.NII
# 	 MEN029_COR_FSPGR_AVG_20170222161055.NII
# 	 MEN029_SAG_FSPGR_AVG_20170222161055.NII
# 	 WH1615_AX_FSPGR_3D_T1_20180105140227_I00001A.NII
# 	 WH1615_AX_FSPGR_3D_T1_20180105140227_I00002A.NII
# 	 WH1615_COR_FSPGR_3D_T1_20180105140227_I00001A.NII
# 	 WH1615_COR_FSPGR_3D_T1_20180105140227_I00002A.NII
# 	 WH1615_NEUROMELANIN_T1_FSE-XL_20180105140227.NII
# 	 WH1604_AX_FSPGR_MIN_20170310134135.NII
# 	 WH1604_COR_FSPGR_AVG_20170310134135.NII
# 	 WH1604_SAG_FSPGR_AVG_20170310134135.NII
# 	 MEN015_AX_FSPGR_MIN_20170216143327.NII
# 	 MEN015_COR_FSPGR_AVG_20170216143327.NII
# 	 MEN015_SAG_FSPGR_AVG_20170216143327.NII
# 	 BR047_AX_T1_POST_PROCESS_20190617093504.NII
# 	 BR047_AX_T1_POST_PROCESS_20190617093504A.NII
# 	 BR047_SAG_FSPGR_3D_20190617093504A.NII
# 	 BR051_AX_T1_POST_PROCESS_20190909111639.NII
# 	 WH1660_NEUROMELANIN_T1_FSE-XL_20180411150611.NII
# 	 SH015_AX_FSPGR_MIN_20170208134024.NII
# 	 SH015_COR_FSPGR_AVG_20170208134024.NII
# 	 SH015_SAG_FSPGR_AVG_20170208134024.NII
# 	 WH1327_AX_T1_SE_MT_20180821143427.NII
# 	 WH1646_NEUROMELANIN_T1_FSE-XL_20171215105227.NII
# 	 MEN040_AX_FSPGR_3D_T1_20170512130925_I00001A.NII
# 	 MEN040_AX_FSPGR_3D_T1_20170512130925_I00002A.NII
# 	 MEN040_SAG_FSPGR_3D_20170512130925A.NII
# 	 BR024_NEUROMELANIN_T1_FSE-XL_20180227163900.NII
# 	 SH060_AX_T1_POST_PROCESS_20190820133401.NII
# 	 WH1349_AX_T1_SE_MT_20180627143541.NII
# 	 WH1649_NEUROMELANIN_T1_FSE-XL_20180503093352.NII
# 	 SH019_AX_FSPGR_MIN_20170221154543.NII
# 	 SH019_COR_FSPGR_AVG_20170221154543.NII
# 	 SH019_SAG_FSPGR_AVG_20170221154543.NII
# 	 SH001_AX_FSPGR_MIN_20161213141852.NII
# 	 SH001_COR_FSPGR_AVG_20161213141852.NII
# 	 SH001_SAG_FSPGR_AVG_20161213141852.NII
# 	 MEN034_SAG_FSPGR_3D_20170407102028A.NII
# 	 SH020_AX_FSPGR_MIN_20170303103229.NII
# 	 SH020_COR_FSPGR_AVG_20170303103229.NII
# 	 SH020_SAG_FSPGR_AVG_20170303103229.NII
# 	 MEN044_AX_T1_SE_MT_20180821094714.NII
# 	 SH007_AX_FSPGR_MIN_20170104151649.NII
# 	 SH007_COR_FSPGR_AVG_20170104151649.NII
# 	 SH007_SAG_FSPGR_AVG_20170104151649.NII
# 	 MEN002_AX_FSPGR_MIN_20170215102136.NII
# 	 MEN002_AX_FSPGR_MIN_20170215102136A.NII
# 	 MEN002_COR_FSPGR_AVG_20170215102136.NII
# 	 MEN002_COR_FSPGR_AVG_20170215102136A.NII
# 	 MEN002_SAG_FSPGR_AVG_20170215102136.NII
# 	 MEN002_SAG_FSPGR_AVG_20170215102136A.NII
# 	 MEN002_SAG_FSPGR_3D_20170215102136A.NII
# 	 MEN017_AX_FSPGR_MIN_20170224140230.NII
# 	 MEN017_COR_FSPGR_AVG_20170224140230.NII
# 	 MEN017_SAG_FSPGR_AVG_20170224140230.NII
# 	 MEN001_AX_FSPGR_MIN_20170214141641.NII
# 	 MEN001_COR_FSPGR_AVG_20170214141641.NII
# 	 MEN001_SAG_FSPGR_AVG_20170214141641.NII
# 	 WH1667_AX_T1_SE_MT_20180820095936.NII
# 	 WH1622_NEUROMELANIN_T1_FSE-XL_20171130103707.NII
# 	 SH058_AX_T1_SE_MT_20180607104235.NII
# 	 WH1492_AX_FSPGR_MIN_20170222140740.NII
# 	 WH1492_COR_FSPGR_AVG_20170222140740.NII
# 	 WH1492_SAG_FSPGR_AVG_20170222140740.NII
# 	 SH056_AX_T1_SE_MT_20180523111443.NII
# 	 WH1621_NEUROMELANIN_T1_FSE-XL_20180416155525.NII
# 	 BR025_NEUROMELANIN_T1_FSE-XL_20180314150410.NII
# 	 SH022_AX_FSPGR_MIN_20170307144621.NII
# 	 SH022_COR_FSPGR_AVG_20170307144621.NII
# 	 SH022_SAG_FSPGR_AVG_20170307144621.NII
# 	 WH1653_NEUROMELANIN_T1_FSE-XL_20180213094821.NII
# 	 BR023_NEUROMELANIN_T1_FSE-XL_20180130092950.NII
# 	 SH006_AX_FSPGR_MIN_20161221104818.NII
# 	 SH006_COR_FSPGR_AVG_20161221104818.NII
# 	 SH006_SAG_FSPGR_AVG_20161221104818.NII
# 	 WH1488_AX_FSPGR_MIN_20170125104140.NII
# 	 WH1488_COR_FSPGR_AVG_20170125104140.NII
# 	 WH1488_SAG_FSPGR_AVG_20170125104140.NII
# 	 BR035_AX_T1_SE_MT_20180703114026.NII
# 	 MEN020_AX_FSPGR_MIN_20170301110535.NII
# 	 MEN020_COR_FSPGR_AVG_20170301110535.NII
# 	 MEN020_SAG_FSPGR_AVG_20170301110535.NII
# 	 WH1495_AX_FSPGR_MIN_20170203094107.NII
# 	 WH1495_COR_FSPGR_AVG_20170203094107.NII
# 	 WH1495_SAG_FSPGR_AVG_20170203094107.NII
# 	 BR030_NEUROMELANIN_T1_FSE-XL_20180412153641.NII
# 	 SH008_AX_FSPGR_MIN_20170110103631.NII
# 	 SH008_COR_FSPGR_AVG_20170110103631.NII
# 	 SH008_SAG_FSPGR_AVG_20170110103631.NII
# 	 MEN023_AX_FSPGR_MIN_20170314104715.NII
# 	 MEN023_COR_FSPGR_AVG_20170314104715.NII
# 	 MEN023_SAG_FSPGR_AVG_20170314104715.NII
# 	 SH021_AX_FSPGR_MIN_20170306144313.NII
# 	 SH021_COR_FSPGR_AVG_20170306144313.NII
# 	 SH021_SAG_FSPGR_AVG_20170306144313.NII
# 	 WH1242_AX_T1_SE_MT_20180530105839.NII
# 	 MEN06_AX_FSPGR_MIN_20170209141749.NII
# 	 MEN06_COR_FSPGR_AVG_20170209141749.NII
# 	 MEN06_SAG_FSPGR_AVG_20170209141749.NII
# 	 BR032_AX_T1_SE_MT_20180601114100.NII
# 	 BR031_NEUROMELANIN_T1_FSE-XL_20180416122456.NII
# 	 SH018_AX_FSPGR_MIN_20170216093410.NII
# 	 SH018_COR_FSPGR_AVG_20170216093410.NII
# 	 SH018_SAG_FSPGR_AVG_20170216093410.NII
# 	 MEN007_AX_FSPGR_MIN_20170224101446.NII
# 	 MEN007_COR_FSPGR_AVG_20170224101446.NII
# 	 MEN007_SAG_FSPGR_AVG_20170224101446.NII
# 	 WH1658_NEUROMELANIN_T1_FSE-XL_20180329144124.NII
# 	 WH1602_AX_FSPGR_MIN_20170306102628.NII
# 	 WH1602_COR_FSPGR_AVG_20170306102628.NII
# 	 WH1602_SAG_FSPGR_AVG_20170306102628.NII
# 	 WH1635_COR_OBLIQUE_T1_20190404131136_I00001.NII
# 	 WH1635_COR_OBLIQUE_T1_20190404131136_I00002.NII
# 	 WH1720_HIPPOCAMPUS_T1_20190923161210_I00002.NII
# 	 WH1720_HIPPOCAMPUS_T1_20190923161210_I00001.NII
# 	 WH1720_AX_T1_POST_PROCESS_20190923161210.NII
# 	 SH064_AX_T1_POST_PROCESS_20190823090723.NII
# 	 BR019_NEUROMELANIN_T1_FSE-XL_20171220144153.NII
# 	 SH003_AX_FSPGR_MIN_20161216104513.NII
# 	 SH003_COR_FSPGR_AVG_20161216104513.NII
# 	 SH003_SAG_FSPGR_AVG_20161216104513.NII
# 	 WH5002_AX_FSPGR_3D_T1_20180316143842_I00001A.NII
# 	 WH5002_AX_FSPGR_3D_T1_20180316143842_I00002A.NII
# 	 WH5002_COR_FSPGR_3D_T1_20180316143842_I00002A.NII
# 	 WH5002_COR_FSPGR_3D_T1_20180316143842_I00001A.NII
# 	 WH5002_NEUROMELANIN_T1_FSE-XL_20180316143842.NII
# 	 WH5002_NEUROMELANIN_T1_FSE-XL_20180316143842A.NII
# 	 SH002_AX_T1_POST_PROCESS_20190816150337.NII
# 	 SH054_NEUROMELANIN_T1_FSE-XL_20171211102322.NII
# 	 WH1232_AX_2DTOF_FSPGR_20190311094507.NII
# 	 WH1232_COL_AX_2DTOF_FSPGR_20190311094507.NII
# 	 MEN013_AX_FSPGR_MIN_20170222101110.NII
# 	 MEN013_COR_FSPGR_AVG_20170222101110.NII
# 	 MEN013_SAG_FSPGR_AVG_20170222101110.NII
# 	 WH1245_NEUROMELANIN_T1_FSE-XL_20180316105153.NII
# 	 SH060_AX_T1_POST_PROCESS_20190628105216.NII
# 	 MEN027_AX_FSPGR_MIN_20170303141530.NII
# 	 MEN027_COR_FSPGR_AVG_20170303141530.NII
# 	 MEN027_SAG_FSPGR_AVG_20170303141530.NII
# 	 WH1618_NEUROMELANIN_T1_FSE-XL_20171219143448.NII
# 	 WH1624_AX_FSPGR_3D_T1_20170829105946_I00002A.NII
# 	 WH1624_AX_FSPGR_3D_T1_20170829105946_I00001A.NII
# 	 MEN019_AX_FSPGR_MIN_20170223095238.NII
# 	 MEN019_COR_FSPGR_AVG_20170223095238.NII
# 	 MEN019_SAG_FSPGR_AVG_20170223095238.NII
# 	 WH1645_NEUROMELANIN_T1_FSE-XL_20180208143523.NII
# FLAIR
# 	 MEN005_AX_3D_FLAIR_RECON_AVG_20170223153214.NII
# 	 MEN005_AX_3D_FLAIR_MIP_20170223153214.NII
# 	 MEN005_SAG_3D_FLAIR_MIP_20170223153214.NII
# 	 MEN021_AX_3D_FLAIR_RECON_AVG_20170302095957.NII
# 	 MEN021_AX_3D_FLAIR_MIP_20170302095957.NII
# 	 MEN021_SAG_3D_FLAIR_MIP_20170302095957.NII
# 	 SH009_AX_3D_FLAIR_RECON_AVG_20170112140902.NII
# 	 SH009_AX_3D_FLAIR_MIP_20170112140902.NII
# 	 SH009_SAG_3D_FLAIR_MIP_20170112140902.NII
# 	 BR003_AX_3D_FLAIR_RECON_AVG_20170620095427.NII
# 	 BR003_AX_3D_FLAIR_MIP_20170620095427.NII
# 	 BR003_SAG_3D_FLAIR_MIP_20170620095427.NII
# 	 SH017_AX_3D_FLAIR_RECON_AVG_20170213140013.NII
# 	 SH017_AX_3D_FLAIR_MIP_20170213140013.NII
# 	 SH017_SAG_3D_FLAIR_MIP_20170213140013.NII
# 	 SH002_AX_3D_FLAIR_RECON_AVG_20161216090218.NII
# 	 SH002_AX_3D_FLAIR_MIP_20161216090218.NII
# 	 SH002_SAG_3D_FLAIR_MIP_20161216090218.NII
# 	 SH012_AX_3D_FLAIR_RECON_AVG_20170131161308.NII
# 	 SH012_AX_3D_FLAIR_MIP_20170131161308.NII
# 	 SH012_SAG_3D_FLAIR_MIP_20170131161308.NII
# 	 SH010_AX_3D_FLAIR_RECON_AVG_20170120152021.NII
# 	 SH010_AX_3D_FLAIR_MIP_20170120152021.NII
# 	 SH010_SAG_3D_FLAIR_MIP_20170120152021.NII
# 	 MEN014_AX_3D_FLAIR_RECON_AVG_20170227145110.NII
# 	 MEN014_AX_3D_FLAIR_MIP_20170227145110.NII
# 	 MEN014_SAG_3D_FLAIR_MIP_20170227145110.NII
# 	 BR011_AX_T2_FLAIR_20190226094521A.NII
# 	 SH011_AX_3D_FLAIR_RECON_AVG_20170131135040.NII
# 	 SH011_AX_3D_FLAIR_MIP_20170131135040.NII
# 	 SH011_SAG_3D_FLAIR_MIP_20170131135040.NII
# 	 MEN009_AX_3D_FLAIR_RECON_AVG_20170307100421.NII
# 	 MEN009_AX_3D_FLAIR_MIP_20170307100421.NII
# 	 MEN009_SAG_3D_FLAIR_MIP_20170307100421.NII
# 	 SH004_AX_3D_FLAIR_RECON_AVG_20161220103018.NII
# 	 SH004_AX_3D_FLAIR_MIP_20161220103018.NII
# 	 SH004_SAG_3D_FLAIR_MIP_20161220103018.NII
# 	 MEN022_AX_3D_FLAIR_RECON_AVG_20170227110618.NII
# 	 MEN022_AX_3D_FLAIR_MIP_20170227110618.NII
# 	 MEN022_SAG_3D_FLAIR_MIP_20170227110618.NII
# 	 WH1487_AX_3D_FLAIR_RECON_AVG_20170306175459.NII
# 	 WH1487_AX_3D_FLAIR_MIP_20170306175459.NII
# 	 WH1487_SAG_3D_FLAIR_MIP_20170306175459.NII
# 	 WH1449_AX_3D_FLAIR_RECON_AVG_20170314150459.NII
# 	 WH1449_AX_3D_FLAIR_MIP_20170314150459.NII
# 	 WH1449_SAG_3D_FLAIR_MIP_20170314150459.NII
# 	 1499_AX_3D_FLAIR_RECON_AVG_20170111101313.NII
# 	 1499_AX_3D_FLAIR_MIP_20170111101313.NII
# 	 1499_SAG_3D_FLAIR_MIP_20170111101313.NII
# 	 MEN029_AX_3D_FLAIR_RECON_AVG_20170222161055.NII
# 	 MEN029_AX_3D_FLAIR_MIP_20170222161055.NII
# 	 MEN029_SAG_3D_FLAIR_MIP_20170222161055.NII
# 	 WH1604_AX_3D_FLAIR_RECON_AVG_20170310134135.NII
# 	 WH1604_AX_3D_FLAIR_MIP_20170310134135.NII
# 	 WH1604_SAG_3D_FLAIR_MIP_20170310134135.NII
# 	 MEN015_AX_3D_FLAIR_RECON_AVG_20170216143327.NII
# 	 MEN015_AX_3D_FLAIR_MIP_20170216143327.NII
# 	 MEN015_SAG_3D_FLAIR_MIP_20170216143327.NII
# 	 SH015_AX_3D_FLAIR_RECON_AVG_20170208134024.NII
# 	 SH015_AX_3D_FLAIR_MIP_20170208134024.NII
# 	 SH015_SAG_3D_FLAIR_MIP_20170208134024.NII
# 	 SH019_AX_3D_FLAIR_RECON_AVG_20170221154543.NII
# 	 SH019_AX_3D_FLAIR_MIP_20170221154543.NII
# 	 SH019_SAG_3D_FLAIR_MIP_20170221154543.NII
# 	 SH001_AX_3D_FLAIR_RECON_AVG_20161213141852.NII
# 	 SH001_AX_3D_FLAIR_MIP_20161213141852.NII
# 	 SH001_SAG_3D_FLAIR_MIP_20161213141852.NII
# 	 SH020_AX_3D_FLAIR_RECON_AVG_20170303103229.NII
# 	 SH020_AX_3D_FLAIR_MIP_20170303103229.NII
# 	 SH020_SAG_3D_FLAIR_MIP_20170303103229.NII
# 	 SH007_AX_3D_FLAIR_RECON_AVG_20170104151649.NII
# 	 SH007_AX_3D_FLAIR_MIP_20170104151649.NII
# 	 SH007_SAG_3D_FLAIR_MIP_20170104151649.NII
# 	 MEN017_AX_3D_FLAIR_RECON_AVG_20170224140230.NII
# 	 MEN017_AX_3D_FLAIR_MIP_20170224140230.NII
# 	 MEN017_SAG_3D_FLAIR_MIP_20170224140230.NII
# 	 MEN001_AX_3D_FLAIR_RECON_AVG_20170214141641.NII
# 	 MEN001_AX_3D_FLAIR_MIP_20170214141641.NII
# 	 MEN001_SAG_3D_FLAIR_MIP_20170214141641.NII
# 	 WH1492_AX_3D_FLAIR_RECON_AVG_20170222140740.NII
# 	 WH1492_AX_3D_FLAIR_MIP_20170222140740.NII
# 	 WH1492_SAG_3D_FLAIR_MIP_20170222140740.NII
# 	 SH056_SAG_3D_FLAIR_20180523111443A.NII
# 	 SH022_AX_3D_FLAIR_RECON_AVG_20170307144621.NII
# 	 SH022_AX_3D_FLAIR_MIP_20170307144621.NII
# 	 SH022_SAG_3D_FLAIR_MIP_20170307144621.NII
# 	 SH006_AX_3D_FLAIR_RECON_AVG_20161221104818.NII
# 	 SH006_AX_3D_FLAIR_MIP_20161221104818.NII
# 	 SH006_SAG_3D_FLAIR_MIP_20161221104818.NII
# 	 WH1488_AX_3D_FLAIR_RECON_AVG_20170125104140.NII
# 	 WH1488_AX_3D_FLAIR_MIP_20170125104140.NII
# 	 WH1488_SAG_3D_FLAIR_MIP_20170125104140.NII
# 	 MEN020_AX_3D_FLAIR_RECON_AVG_20170301110535.NII
# 	 MEN020_AX_3D_FLAIR_MIP_20170301110535.NII
# 	 MEN020_SAG_3D_FLAIR_MIP_20170301110535.NII
# 	 WH1495_AX_3D_FLAIR_RECON_AVG_20170203094107.NII
# 	 WH1495_AX_3D_FLAIR_MIP_20170203094107.NII
# 	 WH1495_SAG_3D_FLAIR_MIP_20170203094107.NII
# 	 SH008_AX_3D_FLAIR_RECON_AVG_20170110103631.NII
# 	 SH008_AX_3D_FLAIR_MIP_20170110103631.NII
# 	 SH008_SAG_3D_FLAIR_MIP_20170110103631.NII
# 	 MEN023_AX_3D_FLAIR_RECON_AVG_20170314104715.NII
# 	 MEN023_AX_3D_FLAIR_MIP_20170314104715.NII
# 	 MEN023_SAG_3D_FLAIR_MIP_20170314104715.NII
# 	 SH021_AX_3D_FLAIR_RECON_AVG_20170306144313.NII
# 	 SH021_AX_3D_FLAIR_MIP_20170306144313.NII
# 	 SH021_SAG_3D_FLAIR_MIP_20170306144313.NII
# 	 WH1242_SAG_3D_FLAIR_20180530105839A.NII
# 	 MEN06_AX_3D_FLAIR_RECON_AVG_20170209141749.NII
# 	 MEN06_AX_3D_FLAIR_MIP_20170209141749.NII
# 	 MEN06_SAG_3D_FLAIR_MIP_20170209141749.NII
# 	 SH018_AX_3D_FLAIR_RECON_AVG_20170216093410.NII
# 	 SH018_AX_3D_FLAIR_MIP_20170216093410.NII
# 	 SH018_SAG_3D_FLAIR_MIP_20170216093410.NII
# 	 MEN007_AX_3D_FLAIR_RECON_AVG_20170224101446.NII
# 	 MEN007_AX_3D_FLAIR_MIP_20170224101446.NII
# 	 MEN007_SAG_3D_FLAIR_MIP_20170224101446.NII
# 	 WH1602_AX_3D_FLAIR_RECON_AVG_20170306102628.NII
# 	 WH1602_AX_3D_FLAIR_MIP_20170306102628.NII
# 	 WH1602_SAG_3D_FLAIR_MIP_20170306102628.NII
# 	 SH003_AX_3D_FLAIR_RECON_AVG_20161216104513.NII
# 	 SH003_AX_3D_FLAIR_MIP_20161216104513.NII
# 	 SH003_SAG_3D_FLAIR_MIP_20161216104513.NII
# 	 MEN013_AX_3D_FLAIR_RECON_AVG_20170222101110.NII
# 	 MEN013_AX_3D_FLAIR_MIP_20170222101110.NII
# 	 MEN013_SAG_3D_FLAIR_MIP_20170222101110.NII
# 	 MEN027_AX_3D_FLAIR_RECON_AVG_20170303141530.NII
# 	 MEN027_AX_3D_FLAIR_MIP_20170303141530.NII
# 	 MEN027_SAG_3D_FLAIR_MIP_20170303141530.NII
# 	 MEN019_AX_3D_FLAIR_RECON_AVG_20170223095238.NII
# 	 MEN019_AX_3D_FLAIR_MIP_20170223095238.NII
# 	 MEN019_SAG_3D_FLAIR_MIP_20170223095238.NII
# T2
# 	 MEN005_AX_3D_T2_MIP_20170223153214.NII
# 	 MEN005_AX_3D_T2_AVG_20170223153214.NII
# 	 MEN005_AX_3D_T2_MIN_IP_20170223153214.NII
# 	 MEN021_AX_3D_T2_MIP_20170302095957.NII
# 	 MEN021_AX_3D_T2_AVG_20170302095957.NII
# 	 MEN021_AX_3D_T2_MIN_IP_20170302095957.NII
# 	 SH009_AX_3D_T2_MIP_20170112140902.NII
# 	 SH009_AX_3D_T2_AVG_20170112140902.NII
# 	 SH009_AX_3D_T2_MIN_IP_20170112140902.NII
# 	 SH017_AX_3D_T2_MIP_20170213140013.NII
# 	 SH017_AX_3D_T2_AVG_20170213140013.NII
# 	 SH017_AX_3D_T2_MIN_IP_20170213140013.NII
# 	 SH002_AX_3D_T2_MIP_20161216090218.NII
# 	 SH002_AX_3D_T2_AVG_20161216090218.NII
# 	 SH002_AX_3D_T2_MIN_IP_20161216090218.NII
# 	 SH012_AX_3D_T2_MIP_20170131161308.NII
# 	 SH012_AX_3D_T2_AVG_20170131161308.NII
# 	 SH012_AX_3D_T2_MIN_IP_20170131161308.NII
# 	 SH010_AX_3D_T2_MIP_20170120152021.NII
# 	 SH010_AX_3D_T2_AVG_20170120152021.NII
# 	 SH010_AX_3D_T2_MIN_IP_20170120152021.NII
# 	 MEN014_AX_3D_T2_MIP_20170227145110.NII
# 	 MEN014_AX_3D_T2_AVG_20170227145110.NII
# 	 MEN014_AX_3D_T2_MIN_IP_20170227145110.NII
# 	 BR011_AX_DE_PD_T2_20171101122356_E1.NII
# 	 BR011_AX_DE_PD_T2_20171101122356_E2.NII
# 	 SH011_AX_3D_T2_MIP_20170131135040.NII
# 	 SH011_AX_3D_T2_AVG_20170131135040.NII
# 	 SH011_AX_3D_T2_MIN_IP_20170131135040.NII
# 	 MEN009_AX_3D_T2_MIP_20170307100421.NII
# 	 MEN009_AX_3D_T2_AVG_20170307100421.NII
# 	 MEN009_AX_3D_T2_MIN_IP_20170307100421.NII
# 	 SH004_AX_3D_T2_MIP_20161220103018.NII
# 	 SH004_AX_3D_T2_AVG_20161220103018.NII
# 	 SH004_AX_3D_T2_MIN_IP_20161220103018.NII
# 	 MEN022_AX_3D_T2_MIP_20170227110618.NII
# 	 MEN022_AX_3D_T2_AVG_20170227110618.NII
# 	 MEN022_AX_3D_T2_MIN_IP_20170227110618.NII
# 	 WH1487_AX_3D_T2_MIP_20170306175459.NII
# 	 WH1487_AX_3D_T2_AVG_20170306175459.NII
# 	 WH1487_AX_3D_T2_MIN_IP_20170306175459.NII
# 	 WH1449_AX_3D_T2_MIP_20170314150459.NII
# 	 WH1449_AX_3D_T2_AVG_20170314150459.NII
# 	 WH1449_AX_3D_T2_MIN_IP_20170314150459.NII
# 	 1499_AX_3D_T2_MIP_20170111101313.NII
# 	 1499_AX_3D_T2_AVG_20170111101313.NII
# 	 1499_AX_3D_T2_MIN_IP_20170111101313.NII
# 	 MEN029_AX_3D_T2_MIP_20170222161055.NII
# 	 MEN029_AX_3D_T2_AVG_20170222161055.NII
# 	 MEN029_AX_3D_T2_MIN_IP_20170222161055.NII
# 	 WH1604_AX_3D_T2_MIP_20170310134135.NII
# 	 WH1604_AX_3D_T2_AVG_20170310134135.NII
# 	 WH1604_AX_3D_T2_MIN_IP_20170310134135.NII
# 	 MEN015_AX_3D_T2_MIP_20170216143327.NII
# 	 MEN015_AX_3D_T2_AVG_20170216143327.NII
# 	 SH015_AX_3D_T2_MIP_20170208134024.NII
# 	 SH015_AX_3D_T2_AVG_20170208134024.NII
# 	 SH015_AX_3D_T2_MIN_IP_20170208134024.NII
# 	 SH019_AX_3D_T2_MIP_20170221154543.NII
# 	 SH019_AX_3D_T2_AVG_20170221154543.NII
# 	 SH019_AX_3D_T2_MIN_IP_20170221154543.NII
# 	 SH001_AX_3D_T2_MIP_20161213141852.NII
# 	 SH001_AX_3D_T2_AVG_20161213141852.NII
# 	 SH001_AX_3D_T2_MIN_IP_20161213141852.NII
# 	 SH020_AX_3D_T2_MIP_20170303103229.NII
# 	 SH020_AX_3D_T2_AVG_20170303103229.NII
# 	 SH020_AX_3D_T2_MIN_IP_20170303103229.NII
# 	 SH007_AX_3D_T2_MIP_20170104151649.NII
# 	 SH007_AX_3D_T2_AVG_20170104151649.NII
# 	 SH007_AX_3D_T2_MIN_IP_20170104151649.NII
# 	 MEN002_AX_3D_T2_MIP_20170215102136.NII
# 	 MEN002_AX_3D_T2_AVG_20170215102136.NII
# 	 MEN002_AX_3D_T2_MIN_IP_20170215102136.NII
# 	 MEN017_AX_3D_T2_MIP_20170224140230.NII
# 	 MEN017_AX_3D_T2_AVG_20170224140230.NII
# 	 MEN017_AX_3D_T2_MIN_IP_20170224140230.NII
# 	 MEN001_AX_3D_T2_MIP_20170214141641.NII
# 	 MEN001_AX_3D_T2_AVG_20170214141641.NII
# 	 MEN001_AX_3D_T2_MIN_IP_20170214141641.NII
# 	 BR043_AX_3D_T2_20190128112730_I00001.NII
# 	 BR043_AX_3D_T2_20190128112730_I00002.NII
# 	 WH1492_AX_3D_T2_MIP_20170222140740.NII
# 	 WH1492_AX_3D_T2_AVG_20170222140740.NII
# 	 WH1492_AX_3D_T2_MIN_IP_20170222140740.NII
# 	 SH022_AX_3D_T2_MIP_20170307144621.NII
# 	 SH022_AX_3D_T2_AVG_20170307144621.NII
# 	 SH022_AX_3D_T2_MIN_IP_20170307144621.NII
# 	 SH006_AX_3D_T2_MIP_20161221104818.NII
# 	 SH006_AX_3D_T2_AVG_20161221104818.NII
# 	 SH006_AX_3D_T2_MIN_IP_20161221104818.NII
# 	 WH1488_AX_3D_T2_MIP_20170125104140.NII
# 	 WH1488_AX_3D_T2_AVG_20170125104140.NII
# 	 WH1488_AX_3D_T2_MIN_IP_20170125104140.NII
# 	 MEN020_AX_3D_T2_MIP_20170301110535.NII
# 	 MEN020_AX_3D_T2_AVG_20170301110535.NII
# 	 MEN020_AX_3D_T2_MIN_IP_20170301110535.NII
# 	 WH1495_AX_3D_T2_MIP_20170203094107.NII
# 	 WH1495_AX_3D_T2_AVG_20170203094107.NII
# 	 WH1495_AX_3D_T2_MIN_IP_20170203094107.NII
# 	 SH008_AX_3D_T2_MIP_20170110103631.NII
# 	 SH008_AX_3D_T2_AVG_20170110103631.NII
# 	 SH008_AX_3D_T2_MIN_IP_20170110103631.NII
# 	 MEN023_AX_3D_T2_MIP_20170314104715.NII
# 	 MEN023_AX_3D_T2_AVG_20170314104715.NII
# 	 MEN023_AX_3D_T2_MIN_IP_20170314104715.NII
# 	 SH021_AX_3D_T2_MIP_20170306144313.NII
# 	 SH021_AX_3D_T2_AVG_20170306144313.NII
# 	 SH021_AX_3D_T2_MIN_IP_20170306144313.NII
# 	 MEN06_AX_3D_T2_MIP_20170209141749.NII
# 	 MEN06_AX_3D_T2_AVG_20170209141749.NII
# 	 MEN06_AX_3D_T2_MIN_IP_20170209141749.NII
# 	 SH018_AX_3D_T2_MIP_20170216093410.NII
# 	 SH018_AX_3D_T2_AVG_20170216093410.NII
# 	 MEN007_AX_3D_T2_MIP_20170224101446.NII
# 	 MEN007_AX_3D_T2_AVG_20170224101446.NII
# 	 MEN007_AX_3D_T2_MIN_IP_20170224101446.NII
# 	 WH1602_AX_3D_T2_MIP_20170306102628.NII
# 	 WH1602_AX_3D_T2_AVG_20170306102628.NII
# 	 WH1602_AX_3D_T2_MIN_IP_20170306102628.NII
# 	 WH1635_MPR_COR_T2_20190404131136A.NII
# 	 SH003_AX_3D_T2_MIP_20161216104513.NII
# 	 SH003_AX_3D_T2_AVG_20161216104513.NII
# 	 SH003_AX_3D_T2_MIN_IP_20161216104513.NII
# 	 MEN013_AX_3D_T2_MIP_20170222101110.NII
# 	 MEN013_AX_3D_T2_AVG_20170222101110.NII
# 	 MEN013_AX_3D_T2_MIN_IP_20170222101110.NII
# 	 MEN027_AX_3D_T2_MIP_20170303141530.NII
# 	 MEN027_AX_3D_T2_AVG_20170303141530.NII
# 	 MEN027_AX_3D_T2_MIN_IP_20170303141530.NII
# 	 MEN019_AX_3D_T2_MIP_20170223095238.NII
# 	 MEN019_AX_3D_T2_AVG_20170223095238.NII
# 	 MEN019_AX_3D_T2_MIN_IP_20170223095238.NII
# BOLD
# 	 SH005_BOLD_20161220144657_EQ_1.nii
# 	 WH1296_BOLD_20170503141006_EQ_1.nii
# 	 MEN009_BOLD_20170307100421_EQ_1.nii
# 	 MEN009_BOLD_20170307100421A.nii
# 	 WH1268_BOLD_20170830100435_EQ_1.nii
# 	 MEN023_BOLD_20170314104715_EQ_1.nii
# DWI
# 	 WH1295_DWI_ASSET_20180221143829A.BVAL
# 	 WH1295_DWI_ASSET_20180221143829B.BVEC
# 	 WH1295_DWI_ASSET_20180221143829A.BVEC
# 	 WH1295_DWI_ASSET_20180221143829B.BVAL
# 	 WH1295_DWI_ASSET_20180221143829B.NII
# 	 WH1295_DWI_ASSET_20180221143829A.NII
# 	 WH1617_AX_DWI_ASSET_20170809111631A.BVAL
# 	 WH1617_AX_DWI_ASSET_20170809111631A.NII
# 	 WH1617_AX_DWI_ASSET_20170809111631A.BVEC
# 	 BR011_DWI_ASSET_20190226094521A.NII
# 	 BR011_DWI_ASSET_20190226094521A.BVAL
# 	 BR011_DWI_ASSET_20190226094521A.BVEC
# 	 WH1702_DWI_ASSET_20190212111148_ADC.NII
# 	 MEN050_DWI_ASSET_20190220154013_ADC.NII
# 	 BR023_DWI_ASSET_20190214093736_ADC.NII
# 	 WH1245_AX_DWI__MULEFTI_BVALUE_20180316105153.NII
# DTI
# DKI
# 	 SH044_AX_DKI_(6_DIRECTIONS)_20170620155335_EQ_1.NII
# SWAN
# 	 WH1723_AX_SWAN_MIDBRAIN_20190530130600.NII
# 	 BR046_AX_SWAN_MIDBRAIN_20190530091459.NII
# 	 SH059_AX_SWAN_20181018134702A.NII
# 	 WH1372_AX_SWAN_MIDBRAIN_20190604102741.NII
# ASL
# 	 SH049_AX_ASL_(NON-CONTRAST)_20170829093206A.NII
# 	 SH017_AX_ASL_(NON-CONTRAST)_20180308151619A.NII
# 	 WH1331_AX_ASL_(NON-CONTRAST)_20190514132222A.NII
# 	 BR022_AX_3D_ASL_(NON-CONTRAST)_20180130110501A.NII
# 	 SH057_AX_ASL_(NON-CONTRAST)_20180523095653A.NII
# 	 BR013_AX_ASL_(NON-CONTRAST)_20190315131838A.NII
# 	 WH1662_AX_ASL_(NON-CONTRAST)_20180608104614A.NII
# 	 WH1340_AX_ASL_(NON-CONTRAST)_20190404091541A.NII
# 	 WH1419_AX_ASL_(NON-CONTRAST)_20180629103853A.NII
# 	 WH1327_AX_ASL_(NON-CONTRAST)_20180508145106A.NII
# 	 WH1686_AX_3D_ASL_(NON-CONTRAST)_20181010154013A.NII
# 	 BR003_3D_ASL_(NON-CONTRAST)_20170620095427A.NII
# 	 WH1354_AX_ASL_(NON-CONTRAST)_20180608161238A.NII
# 	 WH1310_3D_ASL_(NON-CONTRAST)_20170503101521A.NII
# 	 BR016_AX_ASL_(NON-CONTRAST)_20171207130232A.NII
# 	 BR029_AX_ASL_(NON-CONTRAST)_20180410105120A.NII
# 	 SH002_3D_ASL_(NON-CONTRAST)_20161216090218A.NII
# 	 WH1419_AX_ASL_(NON-CONTRAST)_20180629103853A.NII
# 	 BR038_AX_ASL_(NON-CONTRAST)_2025_20190321144633A.NII
# 	 BR038_AX_ASL_(NON-CONTRAST)_2525_20190321144633A.NII
# 	 WH1663_AX_ASL_(NON-CONTRAST)_20190401103857A.NII
# 	 WH1414_AX_ASL_(NON-CONTRAST)_20190104092712A.NII
# 	 BR015_AX_3D_ASL_(NON-CONTRAST)_20171206151415A.NII
# 	 BR011_AX_ASL_(NON-CONTRAST)_20190226094521A.NII
# 	 BR031_AX_ASL_20190513131326A.NII
# 	 WH1707_AX_ASL_(NON-CONTRAST)_20190401135957A.NII
# 	 BR011_AX_3D_ASL_(NON-CONTRAST)_20171101130334A.NII
# 	 WH1723_AX_ASL_(NON-CONTRAST)_20190530130600A.NII
# 	 WH1723_AX_ASL_(NON-CONTRAST)_20190530130600C.NII
# 	 WH1723_AX_ASL_(NON-CONTRAST)_20190530130600B.NII
# 	 BR006_AX_3D_ASL_(NON-CONTRAST)_20171107092455A.NII
# 	 WH1702_AX_ASL_(NON-CONTRAST)_20190212111148A.NII
# 	 WH1664_AX_ASL_(NON-CONTRAST)_20190104133519A.NII
# 	 WH1611_AX_3D_ASL_(NON-CONTRAST)_20170811110429A.NII
# 	 WH1330_AX_ASL_(NON-CONTRAST)_20180518144521A.NII
# 	 BR00_AX_ASL_(NON-CONTRAST)_20171031102929A.NII
# 	 BR005_AX_ASL_(NON-CONTRAST)_20171009120947A.NII
# 	 WH1280_AX_ASL_20190514094350A.NII
# 	 WH1741_AX_ASL_(NON-CONTRAST)_20190626135539A.NII
# 	 BR046_AX_ASL_20190530091459A.NII
# 	 WH1690_AX_3D_ASL_(NON-CONTRAST)_20180913120748A.NII
# 	 BR0012_AX_3D_ASL_(NON-CONTRAST)_20171108113746A.NII
# 	 SH059_AX_ASL_(NON-CONTRAST)_20181018134702A.NII
# 	 WH1655_AX_ASL_(NON-CONTRAST)_20180626145230A.NII
# 	 WH1623_AX_3D_ASL_(NON-CONTRAST)_20170912141759A.NII
# 	 BR018_AX_3D_ASL_(NON-CONTRAST)_20171218112857A.NII
# 	 BR026_AX_ASL_(NON-CONTRAST)_20180327114408A.NII
# 	 WH1705_3D_ASL_(NON-CONTRAST)_20190215134035A.NII
# 	 WH1727_AX_ASL_P.DELAY_2025_20190603131028.NII
# 	 WH1727_AX_ASL_P.DELAY_2025_20190603131028A.NII
# 	 BR038_AX_ASL_(NON-CONTRAST)_20181026104213A.NII
# 	 BR043_AX_ASL_(NON-CONTRAST)_20190205131226A.NII
# 	 MEN051_AX_ASL_(NON-CONTRAST)_20190220154013A.NII
# 	 WH1657_AX_ASL_(NON-CONTRAST)_20180409150847A.NII
# 	 WH1716_AX_ASL_(NON-CONTRAST)_20190213140543A.NII
# 	 BR042_AX_ASL_(NON-CONTRAST)_20181204150351A.NII
# 	 WH1651_AX_ASL_(NON-CONTRAST)_20180501103329A.NII
# 	 BR037_AX_ASL_(NON-CONTRAST)_20181012092433A.NII
# 	 WH1612_AX_3D_ASL_(NON-CONTRAST)_20170706075309A.NII
# 	 MEN044_3D_ASL_(NON-CONTRAST)_20180515111421A.NII
# 	 WH1616_AX_3D_ASL_(NON-CONTRAST)_20170628123050A.NII
# 	 BR021_AX_ASL_(NON-CONTRAST)_20180124120947A.NII
# 	 WH1698_AX_3D_ASL_(NON-CONTRAST)_20181025101859A.NII
# 	 WH1615_AX_ASL_(NON-CONTRAST)_20180105140227A.NII
# 	 BR018_AX_ASL_(NON-CONTRAST)_20190214110618A.NII
# 	 SH046_AX_ASL_(NON-CONTRAST)_20170711102903A.NII
# 	 SH051_AX_ASL_(NON-CONTRAST)_20171027104756A.NII
# 	 WH1268_AX_3D_ASL_(NON-CONTRAST)_20170830100435A.NII
# 	 BR051_AX_ASL_20190909111639A.NII
# 	 WH1275_AX_ASL_(NON-CONTRAST)_20190419091312A.NII
# 	 BR014_AX_3D_ASL_(NON-CONTRAST)_20171115123805A.NII
# 	 WH1660_AX_ASL_(NON-CONTRAST)_20180411150611A.NII
# 	 BR020_AX_ASL_(NON-CONTRAST)_20180109135807A.NII
# 	 WH1725_FL_B_SC_AX_ASL_(NON-CONTRAST)_20190617130818.NII
# 	 WH1725_AX_ASL_(NON-CONTRAST)_20190617130818A.NII
# 	 WH1625_AX_3D_ASL_(NON-CONTRAST)_20171009143902A.NII
# 	 BR014_AX_ASL_(NON-CONTRAST)_20181119115538A.NII
# 	 WH1646_AX_ASL_(NON-CONTRAST)_20171215105227A.NII
# 	 SH045_AX_ASL_(NON-CONTRAST)_20170706133844A.NII
# 	 BR009_AX_ASL_(NON-CONTRAST)_20171030160357A.NII
# 	 WH1247_AX_3D_ASL_(NON-CONTRAST)_20181206133418A.NII
# 	 BR024_AX_ASL_(NON-CONTRAST)_20180227163900A.NII
# 	 MEN052_AX_ASL_(NON-CONTRAST)_20190318124108A.NII
# 	 WH1349_AX_ASL_(NON-CONTRAST)_20180627143541A.NII
# 	 WH1649_AX_ASL_(NON-CONTRAST)_20180503093352A.NII
# 	 SH001_3D_ASL_(NON-CONTRAST)_20161213141852A.NII
# 	 BR044_AX_ASL_(NON-CONTRAST)_20190129091124A.NII
# 	 BR027_AX_ASL_(NON-CONTRAST)_20190328100245A.NII
# 	 BR049_AX_ASL_20190624142000A.NII
# 	 MEN044_AX_ASL_(NON-CONTRAST)_20180821094714A.NII
# 	 BR023_AX_ASL_(NON-CONTRAST)_20190214093736A.NII
# 	 WH1696_AX_3D_ASL_(NON-CONTRAST)_20181101112837A.NII
# 	 SH047_AX_ASL_(NON-CONTRAST)_20170712104739A.NII
# 	 SH043_3D_ASL_(NON-CONTRAST)_20170619150511A.NII
# 	 SH052_AX_ASL_(NON-CONTRAST)_20171107135121A.NII
# 	 BR043_AX_ASL_(NON-CONTRAST)_20190128112730A.NII
# 	 WH1667_AX_ASL_(NON-CONTRAST)_20180820095936A.NII
# 	 WH1743_AX_ASL_(NON-CONTRAST)_20191008102726A.NII
# 	 WH1639_AX_3D_ASL_(NON-CONTRAST)_20170914100910A.NII
# 	 WH1622_AX_ASL_(NON-CONTRAST)_20171130103707A.NII
# 	 SH058_AX_ASL_(NON-CONTRAST)_20180607104235A.NII
# 	 MEN043_3D_ASL_(NON-CONTRAST)_20180215095842A.NII
# 	 SH056_AX_ASL_(NON-CONTRAST)_20180523111443A.NII
# 	 SH044_AX_ASL_(NON-CONTRAST)_20170620155335A.NII
# 	 WH1621_AX_ASL_(NON-CONTRAST)_20180416155525A.NII
# 	 WH1609_AX_3D_ASL_(NON-CONTRAST)_20170623104119A.NII
# 	 WH1647_AX_ASL_(NON-CONTRAST)_20171204135728A.NII
# 	 BR025_AX_ASL_(NON-CONTRAST)_20180314150410A.NII
# 	 MEN042_3D_ASL_(NON-CONTRAST)_20170919135612A.NII
# 	 WH1653_AX_ASL_(NON-CONTRAST)_20180213094821A.NII
# 	 BR017_AX_ASL_(NON-CONTRAST)_20171214150846A.NII
# 	 BR023_AX_3D_ASL_(NON-CONTRAST)_20180130092950A.NII
# 	 WH1128_AX_ASL_(NON-CONTRAST)_20190319084647A.NII
# 	 WH1425_AX_3D_ASL_(NON-CONTRAST)_20170714113405A.NII
# 	 BR035_AX_ASL_(NON-CONTRAST)_20180703114026A.NII
# 	 WH1484_AX_3D_ASL_(NON-CONTRAST)_20170718140650A.NII
# 	 BR030_AX_ASL_(NON-CONTRAST)_20180412153641A.NII
# 	 WH1242_AX_ASL_(NON-CONTRAST)_20180530105839A.NII
# 	 WH1635_AX_3D_ASL_(NON-CONTRAST)_20170911141004A.NII
# 	 BR032_AX_ASL_(NON-CONTRAST)_20180601114100A.NII
# 	 BR031_AX_ASL_(NON-CONTRAST)_20180416122456A.NII
# 	 MEN043_3D_ASL_(NON-CONTRAST)_20180515095239A.NII
# 	 BR007_AX_3D_ASL_(NON-CONTRAST)_20171030112405A.NII
# 	 BR026_AX_3D_ASL_(NON-CONTRAST)_20180521162222A.NII
# 	 WH1240_AX_ASL_(NON-CONTRAST)_20190411092848A.NII
# 	 WH1658_AX_ASL_(NON-CONTRAST)_20180329144124A.NII
# 	 MEN049_3D_ASL_(NON-CONTRAST)_20170814112415A.NII
# 	 WH1634_AX_3D_ASL_(NON-CONTRAST)_20171010110844A.NII
# 	 BR039_AX_ASL_(NON-CONTRAST)_20181112130237A.NII
# 	 BR019_AX_3D_ASL_(NON-CONTRAST)_20171220144153A.NII
# 	 SH003_3D_ASL_(NON-CONTRAST)_20161216104513A.NII
# 	 WH5002_AX_ASL_(NON-CONTRAST)_20180316143842A.NII
# 	 BR013_AX_3D_ASL_(NON-CONTRAST)_20171108125219A.NII
# 	 BR004_AX_ASL_(NON-CONTRAST)_20170825094617A.NII
# 	 SH054_AX_ASL_(NON-CONTRAST)_20171211102322A.NII
# 	 BR040_AX_ASL_(NON-CONTRAST)_20181203144627A.NII
# 	 WH1232_AX_ASL_(NON-CONTRAST)_20190311094507A.NII
# 	 SH053_AX_ASL_(NON-CONTRAST)_20171107152207A.NII
# 	 MEN050_AX_ASL_(NON-CONTRAST)_20181109145801A.NII
# 	 WH1245_AX_ASL_(NON-CONTRAST)_20180316105153A.NII
# 	 WH1701_AX_3D_ASL_(NON-CONTRAST)_20181206093440A.NII
# 	 WH1372_FL_B_SC_AX_ASL_(NON-CONTRAST)_20190604102741.NII
# 	 WH1372_AX_ASL_(NON-CONTRAST)_20190604102741A.NII
# 	 SH050_AX_ASL_(NON-CONTRAST)_20171003113239A.NII
# 	 WH1618_AX_ASL_(NON-CONTRAST)_20171219143448A.NII
# 	 WH1624_AX_3D_ASL_(NON-CONTRAST)_20170829105946A.NII
# 	 WH1488_AX_ASL_(NON-CONTRAST)_20191022102404A.NII
# 	 BR033_AX_ASL_20190411112518A.NII
# 	 WH1645_AX_ASL_(NON-CONTRAST)_20180208143523A.NII
# CANDY CANE
# 	 SH063_CANDY_CANE_20190821090159A.NII
# 	 WH1723_CANDY_CANE_20190530130600A.NII
# 	 WH1741_CANDY_CANE_20190626135539A.NII
# 	 WH1736_CANDY_CANE_20190708103024B.NII
# 	 WH1736_CANDY_CANE_20190708103024A.NII
# 	 WH1487_CANDY_CANE_20190712112737A.NII
# 	 WH1720_CANDY_CANE_20190923161210B.NII
# 	 WH1720_CANDY_CANE_20190923161210A.NII
# 	 SH064_CANDY_CANE_20190823090723A.NII
# 	 WH1372_CANDY_CANE_20190604102741A.NII
# 	 WH1488_CANDY_CANE_20191022102404A.NII
# ARCH
# 	 WH1331_CINE_ARCH_VENC_150_20190514132222A.NII
# 	 BR035_CINE_ARCH_VENC_100_20190702101108A.NII
# 	 SH003_CINE_ARCH_20190816130333A.NII
# 	 WH1727_CINE_ARCH_VENC_150_20190603131028A.NII
# 	 WH1275_CINE_ARCH_VENC_150_20190419091312A.NII
# AORTA
# CSF
# 	 WH1419_CSF_FLOW_VENC_20_20180910105606A.NII
# 	 WH1419_CSF_FLOW_VENC_20_20180910105606A.NII
# 	 WH1737_CINE_CSF_FLOW_VENC_15_20190708090335A.NII
# 	 BR043_1.5T_CSF_FLOW_VENC_20_20190205131226.NII
# 	 MEN050_CF_CSF_FLOW_VENC_20_20190220154013.NII
# 	 WH1625_FM_CSF_FLOW_VENC_10_20171009143902.NII
# 	 MEN052_CINE_CSF_C2_FLOW_VENC_3_20190318124108A.NII
# 	 BR044_CSF_FLOW_VENC_15_20190129091124A.NII
# 	 BR023_CSF_FLOW_VENC_15_20190214093736A.NII
# 	 BR043_CSF_FLOW_VENC_20_20190128112730A.NII
# 	 WH1240_CINE_CSF_FLOW_VENC_15_20190411092848A.NII
# 	 WH1651_CSF_FLOW_VENC_15_20190207111154A.NII
# 	 WH1634_FM_CSF_FLOW_VENC_10_20171010110844.NII
# 	 BR040_CSF_FLOW_VENC_15_20181203144627A.NII
# 	 BR040_CSF_FLOW_VENC_15_20181203144627B.NII
# 	 BR040_CSF_FLOW_VENC_15_20181203144627C.NII
# 	 WH1701_AQ_CSF_FLOW_VENC_15_20181206093440A.NII
# CBF
# 	 BR038_CEREBRAL_BLOOD_FLOW_20190321144633A.NII
# 	 WH1723_CEREBRAL_BLOOD_FLOW_20190530130600B.NII
# 	 WH1723_CEREBRAL_BLOOD_FLOW_20190530130600A.NII
# 	 WH1615_CEREBRAL_BLOOD_FLOW_20180105140227A.NII
# 	 WH1615_CEREBRAL_BLOOD_FLOW_20180105140227B.NII
# 	 WH1615_CEREBRAL_BLOOD_FLOW_20180105140227B_EQ_1.NII
# 	 BR013_CEREBRAL_BLOOD_FLOW_20171108125219B.NII
# 	 BR013_CEREBRAL_BLOOD_FLOW_20171108125219A.NII
# PROBE
