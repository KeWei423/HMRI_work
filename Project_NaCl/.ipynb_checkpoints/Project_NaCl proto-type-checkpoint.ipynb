# %%
import os
import pandas as pd
import fnmatch
import re

# %%
# BIGGO TO DO:
# trash bin for each filter

# %%
# NOTE: Possible names for each sequence

# "3D_T1": ['*SAG*T1*NII', '*SAG*FSPGR*3D*NII']
# "FLAIR": <ID>_{SAG | AX | COR}_[T1_ | T2_][3D_]FLAIR_<DOE>.nii
# "T2": <ID>_{SAG | AX | COR}_3D_T2_[<type>]<DOE>.nii
# "T2": <ID>_{SAG | AX | COR}_T2_[<type>]<DOE>_<tag>.nii
# "BOLD": <ID>_BOLD_<DOE>.nii
# "Diffusion kurtosis": <ID>_{AX}_DkI_<small#dirs>_<DOE>.nii
#                       <ID>_{AX}_DkI_<small#dirs>_<DOE>.bval
#                       <ID>_{AX}_DkI_<small#dirs>_<DOE>.bvec
# .                     <ID>_{AX}_DkI_<big#dirs>_<DOE>.nii
#                       <ID>_{AX}_DkI_<big#dirs>_<DOE>.bval
#                       <ID>_{AX}_DkI_<big#dirs>_<DOE>.bvec
# "Diffusion tensor": <ID>_{AX}_D{k|T}I_<#dir>_<DOE>.nii
#                     <ID>_{AX}_D{k|T}I_<#dir>_<DOE>.bval
#                     <ID>_{AX}_D{k|T}I_<#dir>_<DOE>.bvec
# "Diffusion weithed": <ID>_{AX}_DWI_<DOE>.nii
#                      <ID>_{AX}_DWI_<DOE>.bval
#                      <ID>_{AX}_DWI_<DOE>.bvec
# "ASL": <ID>_{SAG | AX | COR}_ASL_<DOE>.nii   
# "SWAN": <ID>_{SAG | AX | COR}_ASL_<DOE>.nii
# "Carotid"
# "Aorta": <ID>_[CINE]_AORTA_VENC_<number>_<DOE>.nii

# %%
def get_sequence_name(sequence_info, notes=None):
    """
    Convert the input from list to string 
    --------------------------------------------------------
    input:
        sequence_info: array-like
            splited the string 
        
    return:
        string : sequence_info joined together
    """
    if notes:
        name = ('_'.join(sequence_info[:-1]))+notes+'.'+sequence_info[-1].lower()
    else:
        name = ('_'.join(sequence_info[:-1]))+'.'+sequence_info[-1].lower()
    return name

# %%
def get_sequence_info(sequence_name):
    """
    Convert the input from string to list 
    --------------------------------------------------------
    input:
        sequence_name: string
        
    return:
        array-like: splited the string into items for parsing later
    """
    str_list = sequence_name.replace('-','_').replace('.','_').split('_')
    if not (str_list[-1] == 'NII' or str_list[-1] == 'JSON'):
        return None
    
    str_list = list(filter(None, str_list)) 
    return str_list

#selected everything expect the '.nii' part of the string

# %%
def extract_notes(sequence_name):
    """
    ignore notes inside the parentheses of sequence_info
    --------------------------------------------------------
    input:
        string: sequence with notes within parentheses
        
    return:
        string: sequence info without the parentheses and notes inside of them
        string: the notes that were in the parentheses
    """
    op = None
    ed = None
    notes = None
    
    for i in range(len(sequence_name)):
        if sequence_name[i] == '(':
            op = i
        if sequence_name[i] == ')':
            ed = i
            break

    return sequence_name[:op] + sequence_name[ed+1:], sequence_name[op:ed]

# %%
def get_DOE(info):
    """
    get the date of exam 
    --------------------------------------------------------
    input:
        info: array-like
        
    return:
        string: date of exame in YYYY/MM/DD
    """
    
    if 'I' in info[-1]:
        DOE=info[-2]
        return(DOE[0:4]+"/"+DOE[4:6]+'/'+DOE[6:8])
    else:
        DOE=info[-1]
        return(DOE[0:4]+"/"+DOE[4:6]+'/'+DOE[6:8])

# %%
def base_standard(o_name):
    """
    clean up the user input sequence name into a standardized naming convetion for sorting later
        SAGITTLE --> SAG
           AXIAL --> AX
         CORONAL --> COR
            CUBE --> 3D
        WHITTIER --> WH
              RT --> RIGHT
              LT --> LEFT
    --------------------------------------------------------
    input:
        o_name: string
    
    return:
        string: standardized sequnece file name
    """
    n_name = o_name.replace('MEN', 'MN').replace('WHITTIER', 'WH')
    n_name = n_name.replace('SAGITTAL', 'SAG').replace('3D', 'CUBE').replace('AXIAL', 'AX').replace('CORONAL', 'COR').replace('OBLIQUE', 'OBL')
    n_name = n_name.replace('RT', 'RIGHT').replace('LT', 'LEFT')
    
    info=n_name.replace('-','_').replace('.','_').split('_')
    
    ID = info[0]
    # ID does not follow designation [2-3 letter cohort designation][3-4 number designation]
    if ID.isdigit():
        info[0] = 'WH'+info[0]
        
    n_name = '_'.join(info)
    
    return n_name

# %%
# <ID>_{SAG | AX | COR}_[T1_ | T2_][3D_]FLAIR_[MIP_ | MIN_IP_]<DOE>[_<tag>].nii
def filt_T1(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    # TO-DO: how to handle 
    # 1) NEUROMELANIN scans
    # 2) SE_MT
    # 3) BRAVO
    # 4) 2DTOF
    # 5) repeat?
    
    sequence_info=get_sequence_info(sequence_name)
    if sequence_info is None:
        return None
    
    if 'CUBE' not in sequence_info and sequence_info[-2][0] == 'I':
        sequence_info[-2] = sequence_info[-2].lower()
    elif not sequence_info[-2].isdigit():
        trash.append(sequence_name)
        return None

    ignore=['AVG', 'MIN', 'POST_PROCESS', 'MT', '2DTOF', 'THIN', 'BRAVO', 'RE']
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    accept = ['SAG', 'AX', 'COR', 'OBL']
    if not any(word in sequence_name for word in accept):
        trash.append(sequence_name)
        return None
    
#     print("file name:", file_name)
    return get_sequence_name(sequence_info)

    
#TO-DO: repeated exam of the same date or at the different date

# %%
# Naming to be estabilshed
# <ID>_{SAG | AX | COR}_[T1_ | T2_][3D_]FLAIR_[MIP_ | MIN_IP_]<DOE>[_<tag>].nii
def filt_FLAIR(sequence_name, flair_3d, flair_2d, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        flair_3d : array-like
            List of files that are 3D FLAIR
        flair_2d : array-like
            List of files that are 2D FLAIR
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)
    if sequence_info is None:
        return None
            
    ignore=['AVG', 'MIN', 'MIP']
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    if 'CUBE' not in sequence_info and sequence_info[-2][0] == 'I':
        sequence_info[-2] = sequence_info[-2].lower()
    elif not sequence_info[-2].isdigit():
        trash.append(sequence_name)
        return None
    
    if "SAG" in sequence_name:
#         print(sequence_info)
        if '3D' in sequence_name:
            flair_3d.append(sequence_name)
        else:
            flair_2d.append(sequence_name)
    elif 'AX' in sequence_name:
#         print(sequence_info)
        if '3D' in sequence_name:
            flair_3d.append(sequence_name)
        else:
            flair_2d.append(sequence_name)
    elif 'COR' in sequence_name:
#         print(sequence_info)
        if '3D' in sequence_name:
            flair_3d.append(sequence_name)
        else:
            flair_2d.append(sequence_name)
    else: 
#         print("\t ", sequence_name)
        trash.append(sequence_name)
        return None
            
    return get_sequence_name(sequence_info)

#TO-DO: T1 has 3D, 2D

# %%
# Naming to be established:
# "T2": <ID>_{SAG | AX | COR}_3D_T2_[<type>]<DOE>.nii
# "T2": <ID>_{SAG | AX | COR}_T2_[<type>]<DOE>_<tag>.nii
def filt_T2(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=get_sequence_info(sequence_name)
    if sequence_info is None:
        return None
    
    ignore=['AVG', 'MIN', 'MIP', 'TRACE', 'SE']
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    if 'CUBE' not in sequence_info and sequence_info[-2][0] == 'I':
        sequence_info[-2] = sequence_info[-2].lower()
    elif not sequence_info[-2].isdigit():
        trash.append(sequence_name)
        return None
#     print(sequence_info)
        
    return get_sequence_name(sequence_info)

#TO-DO: T2 has difference pulse types :0 and some other things

# %%
def filt_DWI(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info=sequence_name.replace('-','_').replace('.','_').split('_')
#     print(sequence_info)
    
    
    if 'AX' not in sequence_info:
        sequence_info=sequence_info[0:1]+['AX']+sequence_info[1:]

    if len(sequence_info) > 6:
        trash.append(sequence_name)
#             print(sequence_info)
        return None

    if not sequence_info[-2].isdigit():
        trash.append(sequence_name)
#             print("repeeat:",sequence_info)
        return None
    else:
        #1. concatinate all with _expect the last item
        #2. lower case the extension (last item) and add a . in front of it
        return get_sequence_name(sequence_info)

# %%
def filt_DTI(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
    n_name = sequence_name.replace('_30_DIRECTION_', '_(30_DIRECTION)_')
    
    return get_sequence_name(sequence_info)

# %%
def filt_DKI(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
    if 'EQ_1' in sequence_name:
        trash.append(sequence_name)
        return None
    
    return get_sequence_name(sequence_info)

# %%
# BOLD naming convention: <ID>_BOLD_<DOE>.nii
def filt_bold(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_name, notes = extract_notes(sequence_name)
    
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
    # The following ID's are the problem ones (from previous runs). Checking if these ID's are unique
#     probs = ['SH005', 'WH1296', 'MEN009', 'WH1612', 'WH1268', 'MEN040', 'SH019', 
#              'MEN023', 'MEN007', 'WHITTIER5002']
    
    # If it contains EQ_1 or a letter attached to the end of the DOE,
    # then there is a previous one that already exists
    if sequence_info[-3] == 'EQ' or not sequence_info[-2].isdigit():
        trash.append(sequence_name)
        return None
        
#     elif ID in probs:
#         problem_bold = sequence_name
    
#     return problem_bold
    return get_sequence_name(sequence_info, notes)

# %%
def filt_asl(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_name, notes = extract_notes(sequence_name)
    
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
    if '3D' not in sequence_info and sequence_info[-2][0] == 'I':
        sequence_info[-2] = sequence_info[-2].lower()
    elif not sequence_info[-2][-1].isdigit():
        trash.append(sequence_name)
        return None

    ignore=['DELAY', 'FL']
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    return get_sequence_name(sequence_info, notes)

# %%
def filt_swan(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_name, notes = extract_notes(sequence_name)
    
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
    if '3D' not in sequence_info and sequence_info[-2][0] == 'I':
        sequence_info[-2] = sequence_info[-2].lower()
    elif not sequence_info[-2][-1].isdigit():
        trash.append(sequence_name)
        return None

    ignore=['MIDBRAIN']
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    return get_sequence_name(sequence_info, notes)

# %%
def filt_csf(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
    index = sequence_info.index('CSF')
    sequence_info.insert(index, 'PC')
    
    if '1.5' in sequence_name:
        trash.append(sequence_name)
        return None
    
    sequence_info=get_sequence_info(sequence_name)
#     print(sequence_name)
#     print(sequence_info)
    if not sequence_info[-2][-1].isdigit():
        trash.append(sequence_name)
        return None
    
    # NOTE: V vs VC vs VENC
    ignore=['CF', 'FM']
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    return get_sequence_name(sequence_info)

#TO-DO: CSF of different location and CINE ON/OFF

# %%
def filt_carotid(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
#     print(sequence_name)

    if not sequence_info[-2][-1].isdigit():
        trash.append(sequence_name)
        return None 
    
    return get_sequence_name(sequence_info)

# %%
def filt_aorta(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None

    ignore=['ASCENDING']
    
    if any(word in sequence_name for word in ignore):
        trash.append(sequence_name)
        return None
    
    return get_sequence_name(sequence_info)

# %%
def filt_candy_cane(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
#     print(sequence_info)
    
    if not sequence_info[-2].isdigit():
        trash.append(sequence_name)
        return None
    
    return get_sequence_name(sequence_info)

# %%
def filt_arch(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
#     print(sequence_name)
#     print(info)
    if not sequence_info[-2][-1].isdigit():
        trash.append(sequence_name)
        return None
    
    if 'VENC' not in sequence_info:
        sequence_info.insert(3, 'VENC_???')
        trash.append('_'.join(sequence_info))
    
    return get_sequence_name(sequence_info)

# %%
def filt_mpr(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
#     print(sequence_name)
    print(sequence_info)

# %%
def filt_cbf(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
    if sequence_info[-3] == 'EQ' or not sequence_info[-2].isdigit():
        trash.append(sequence_name)
        return None
    
    return get_sequence_name(sequence_info)

# %%
def filt_probe(sequence_name, trash):
    """
    Determine if file_name passed in should be kept
    --------------------------------------------------------
    Parameters:
        file_name : string
            Name of file to be checked
        trash : array-like
            List of files that are filtered out by the filter
    
    Returns:
        file_name : string or None
            If file should be kept, return the a renamed version of the file
            else if the file is not to be kept, None is returned
    """
    sequence_info = get_sequence_info(sequence_name)
    
    if sequence_info is None:
        return None
    
#     print(sequence_name)
#     print(sequence_info)
    return get_sequence_name(sequence_info)

# %%
def get_path(root):
    """
    Fliter through all the files in the given path
    --------------------------------------------------------
    Parameters:
        root : string
            Path the directory that contains all the files that is to be filtered through
    """
    
    t1=[]
    flair = []
    flair_3d = []
    flair_2d = []
    t2 = []
    bold = []
    dwi=[]
    dti = []
    dki = []
    swan = []
    asl=[]
    candy_cane=[]
    arch=[]
    aorta=[]
    csf = []
    carotid = []
    cbf=[]
    probe = []
        
    t1_t=[]
    flair_t = []
    t2_t = []
    bold_t = []
    dwi_t=[]
    dti_t = []
    dki_t = []
    swan_t = []
    asl_t=[]
    candy_cane_t=[]
    arch_t=[]
    aorta_t=[]
    csf_t = []
    carotid_t = []
    cbf_t=[]
    probe_t = []
    
    change = 0
    count = 0
    
    for path, subdirs, files in os.walk(root):
        for file in files:
            file_upper=base_standard(file.upper())
            if file_upper is None:
                continue
            if fnmatch.fnmatch(file_upper, '*T1*') or fnmatch.fnmatch(file_upper, '*FSPGR*'):                 
                n_file=filt_T1(file_upper, t1_t)
#                 print("T1:", n_file)
                if n_file is not None:
                    t1.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
#                 pass
            elif fnmatch.fnmatch(file_upper, '*FLAIR*'): 
#                 print("FLAIR: \t", file_upper)
                n_file = filt_FLAIR(file_upper, flair_3d, flair_2d, flair_t)
#                 print("FLAIR:", n_file)
                if n_file is not None:
                    flair.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
#                 pass
            elif fnmatch.fnmatch(file_upper, '*T2*'):
#                 print('\t', file_upper)
                n_file = filt_T2(file_upper, t2_t)
                if n_file is not None:
                    t2.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
#                 pass
            elif fnmatch.fnmatch(file_upper, '*BOLD*'):
                n_file = filt_bold(file_upper, bold_t)
                if n_file is not None:
#                     print(file, '-->', n_file)
                    bold.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
#                 pass
            elif fnmatch.fnmatch(file_upper, '*DWI*'):
#                 print('\t', file_upper)
                n_file=filt_DWI(file_upper, dwi_t)
                if n_file is not None:
                    dwi.append((file, n_file))
            elif fnmatch.fnmatch(file_upper, '*DTI*'):
#                 print('\t', file_upper)
                n_file=filt_DTI(file_upper, dti_t)
                if n_file is not None:
                    dti.append((file, n_file))
            elif fnmatch.fnmatch(file_upper, '*DKI*'):
#                 print('\t', file_upper)
                n_file=filt_DKI(file_upper, dki_t)
                if n_file is not None:
                    dki.append((file, n_file))
            elif fnmatch.fnmatch(file_upper, '*ASL*'):
                n_file=filt_asl(file_upper, asl_t)
                if n_file is not None:
                    asl.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
#                 pass
            elif fnmatch.fnmatch(file_upper, '*SWAN*'):
                # Swan files has very consistant sequence naming
                # beaware of ID naming though
                n_file = filt_swan(file_upper, swan_t)
                if n_file is not None:
                    swan.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
            elif fnmatch.fnmatch(file_upper, '*CSF*'):
#                 print('CSF:', file_upper)
                n_file = filt_csf(file_upper, csf_t)
                if n_file is not None:
                    csf.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
                pass
            elif fnmatch.fnmatch(file_upper, '*CAROTID*'):
                #Need to ask what the carotid is doing: 
                #1. need to know the naming convention for difference carotids
#                 print('Carotid:', file_upper)
                n_file = filt_carotid(file_upper, carotid_t)
                if n_file is not None:
                    carotid.append((file, n_file))
                pass
            elif fnmatch.fnmatch(file_upper, '*AORTA*'):
                n_file=filt_aorta(file_upper, aorta_t)
                if n_file is not None:
                    aorta.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
            elif fnmatch.fnmatch(file_upper, '*CEREBR*BLOOD*FLOW*'):
#                 print("cbf:", file_upper)
                n_file=filt_cbf(file_upper, cbf_t)
                if n_file is not None:
                    cbf.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                     print(file, '-->', n_file)
            elif fnmatch.fnmatch(file_upper, '*MPR*'):
#                 print(file_upper)
#                 filt_mpr(file_upper)
                pass
            elif 'LOC' not in file_upper and fnmatch.fnmatch(file_upper, '*CANDY_CANE*'):
#                 print('Candy cane:', file_upper)
                n_file=filt_candy_cane(file_upper, candy_cane_t)
                if n_file is not None:
                    candy_cane.append((file, n_file))
#                     if file != n_file:
#                     print(file, '-->', n_file)
            elif 'LOC' not in file_upper and fnmatch.fnmatch(file_upper, '*ARCH*'):
                #    
                # 1. the inconsidency happens at the missing venc number.
                #
#                 print(file_upper)
                n_file = filt_arch(file_upper, arch_t)
                if n_file is not None:
                    arch.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                     print(file, '-->', n_file)
                pass
            elif 'LOC' not in file_upper and fnmatch.fnmatch(file_upper, '*PROBE*'):
#                 print(file_upper)
                n_file = filt_probe(file_upper, probe_t)
                if n_file is not None:
                    probe.append((file, n_file))
#                     if file != n_file:
#                         #TODO: rename file
#                         print(file, '-->', n_file)
                pass
            elif fnmatch.fnmatch(file_upper, '*'):
#                 print('\t', file_upper)
                pass
            else:
#                 print('\t\t', file_upper)
                pass

    filtered = {'T1' : t1,
                'FLAIR' : flair,
                'T2' : t2,
                'BOLD' : bold,
                'DWI' : dwi,
                'DTI' : dti,
                'DKI' : dki,
                'SWAN' : swan,
                'ASL' : asl,
                'CANDY CANE' : candy_cane,
                'ARCH' : arch,
                'AORTA' : aorta,
                'CSF': csf,
                'CBF': cbf,
                'PROBE' :probe}

    trash = {'T1' : t1_t,
             'FLAIR' : flair_t,
             'T2' : t2_t,
             'BOLD' : bold_t,
             'DWI' : dwi_t,
             'DTI' : dti_t,
             'DKI' : dki_t,
             'SWAN' : swan_t,
             'ASL' : asl_t,
             'CANDY CANE' : candy_cane_t,
             'ARCH' : arch_t,
             'AORTA' : aorta_t,
             'CSF': csf_t,
             'CBF': cbf_t,
             'PROBE' :probe_t}
    
#     print(len(t1))
#     for pair in t1:
#         print(pair)
#     print(len(flair))
#     for pair in flair:
#         print(pair)
#     print(len(t2))
#     for pair in t2:
#         print(pair)
#     print(len(bold))
#     for pair in bold:
#         print(pair)
#     print(len(asl))
#     for pair in asl:
#         print(pair)
#     print(len(swan))
#     for pair in swan:
#         print(pair)
#     print(len(csf))
#     for pair in csf:
#         print(pair)
#     print(len(aorta))
#     for pair in aorta:
#         print(pair)
#     print(len(cbf))
#     for pair in cbf:
#         print(pair)
#     print(len(candy_cane))
#     for pair in candy_cane:
#         print(pair)
#     print(len(arch))
#     for pair in arch:
#         print(pair)
#     print(len(probe))
#     for pair in probe:
#         print(pair)

#     print("count: ", count)
#     print(change)

#     for can in trash:
#         print(can)
#         if can == 'CSF':
#             for entry in trash[can]:
#                 print('\t', entry)

    for key in filtered:
        print(key)
        for entry in filtered[key]:
            print('    ', entry)

# %%
def main():
#     source_dir=input("Enter source dir:")
#     source_dir="/Users/baymac/Desktop/Project_NaCl_Test_DataSet/3T_Last_updated_31OCT19KW"
    source_dir = '/media/ke/8tb_part2/FSL_work/all_info'
    get_path(source_dir)

# %%
if __name__ =="__main__":
    main()
# Out:
# T1
#      ('SH049_SAG_FSPGR_3D_20170829093206.nii', 'SH049_SAG_FSPGR_CUBE_20170829093206.nii')
#      ('SH049_SAG_FSPGR_3D_20170829093206.json', 'SH049_SAG_FSPGR_CUBE_20170829093206.json')
#      ('MEN005_SAG_FSPGR_3D_20170223153214.nii', 'MN005_SAG_FSPGR_CUBE_20170223153214.nii')
#      ('MEN005_SAG_FSPGR_3D_20170223153214.json', 'MN005_SAG_FSPGR_CUBE_20170223153214.json')
#      ('WH1331_Sagittal_T1_3D_20190514132222.json', 'WH1331_SAG_T1_CUBE_20190514132222.json')
#      ('WH1331_Sagittal_T1_3D_20190514132222.nii', 'WH1331_SAG_T1_CUBE_20190514132222.nii')
#      ('WH1331_CORONAL_T1_20190514132222.json', 'WH1331_COR_T1_20190514132222.json')
#      ('WH1331_CORONAL_T1_20190514132222.nii', 'WH1331_COR_T1_20190514132222.nii')
#      ('WH1331_SAGITTAL_T1_20190514132222.nii', 'WH1331_SAG_T1_20190514132222.nii')
#      ('WH1331_SAGITTAL_T1_20190514132222.json', 'WH1331_SAG_T1_20190514132222.json')
#      ('WH1331_AXIAL_T1_20190514132222.json', 'WH1331_AX_T1_20190514132222.json')
#      ('WH1331_AXIAL_T1_20190514132222.nii', 'WH1331_AX_T1_20190514132222.nii')
#      ('MEN021_SAG_FSPGR_3D_20170302095957.json', 'MN021_SAG_FSPGR_CUBE_20170302095957.json')
#      ('MEN021_SAG_FSPGR_3D_20170302095957.nii', 'MN021_SAG_FSPGR_CUBE_20170302095957.nii')
#      ('BR022_SAG_FSPGR_3D_T1_20180130110501.nii', 'BR022_SAG_FSPGR_CUBE_T1_20180130110501.nii')
#      ('BR022_SAG_FSPGR_3D_T1_20180130110501.json', 'BR022_SAG_FSPGR_CUBE_T1_20180130110501.json')
#      ('WH1619_SAG_FSPGR_3D_T1_20170829140829.json', 'WH1619_SAG_FSPGR_CUBE_T1_20170829140829.json')
#      ('WH1619_SAG_FSPGR_3D_T1_20170829140829.nii', 'WH1619_SAG_FSPGR_CUBE_T1_20170829140829.nii')
#      ('SH057_SAG_FSPGR_3D_20180523095653.json', 'SH057_SAG_FSPGR_CUBE_20180523095653.json')
#      ('SH057_SAG_FSPGR_3D_20180523095653.nii', 'SH057_SAG_FSPGR_CUBE_20180523095653.nii')
#      ('BR013_SAG_FSPGR_3D_20190315131838.json', 'BR013_SAG_FSPGR_CUBE_20190315131838.json')
#      ('BR013_SAG_FSPGR_3D_20190315131838.nii', 'BR013_SAG_FSPGR_CUBE_20190315131838.nii')
#      ('WH1295_SAG_FSPGR_3D_T1_20180221143829.nii', 'WH1295_SAG_FSPGR_CUBE_T1_20180221143829.nii')
#      ('WH1295_SAG_FSPGR_3D_T1_20180221143829.json', 'WH1295_SAG_FSPGR_CUBE_T1_20180221143829.json')
#      ('WH1662_SAG_FSPGR_3D_20180608104614.json', 'WH1662_SAG_FSPGR_CUBE_20180608104614.json')
#      ('WH1662_SAG_FSPGR_3D_20180608104614.nii', 'WH1662_SAG_FSPGR_CUBE_20180608104614.nii')
#      ('SH026_SAG_FSPGR_3D_20170501110237.nii', 'SH026_SAG_FSPGR_CUBE_20170501110237.nii')
#      ('SH026_SAG_FSPGR_3D_20170501110237.json', 'SH026_SAG_FSPGR_CUBE_20170501110237.json')
#      ('WH1340_Coronal_oblique_T1_20190404091541_i00001.nii', 'WH1340_COR_OBL_T1_20190404091541_i00001.nii')
#      ('WH1340_Coronal_oblique_T1_20190404091541_i00002.json', 'WH1340_COR_OBL_T1_20190404091541_i00002.json')
#      ('WH1340_Coronal_oblique_T1_20190404091541_i00002.nii', 'WH1340_COR_OBL_T1_20190404091541_i00002.nii')
#      ('WH1340_Coronal_oblique_T1_20190404091541_i00001.json', 'WH1340_COR_OBL_T1_20190404091541_i00001.json')
#      ('WH1340_SAG_FSPGR_3D_20190404091541.json', 'WH1340_SAG_FSPGR_CUBE_20190404091541.json')
#      ('WH1340_SAG_FSPGR_3D_20190404091541.nii', 'WH1340_SAG_FSPGR_CUBE_20190404091541.nii')
#      ('WH1419_SAG_FSPGR_3D_20180629103853.json', 'WH1419_SAG_FSPGR_CUBE_20180629103853.json')
#      ('WH1419_SAG_FSPGR_3D_20180629103853.nii', 'WH1419_SAG_FSPGR_CUBE_20180629103853.nii')
#      ('SH063_SAG_FSPGR_3D_20190821090159.nii', 'SH063_SAG_FSPGR_CUBE_20190821090159.nii')
#      ('SH063_SAG_FSPGR_3D_20190821090159.json', 'SH063_SAG_FSPGR_CUBE_20190821090159.json')
#      ('WH1327_SAG_FSPGR_3D_T1_20180508145106.nii', 'WH1327_SAG_FSPGR_CUBE_T1_20180508145106.nii')
#      ('WH1327_SAG_FSPGR_3D_T1_20180508145106.json', 'WH1327_SAG_FSPGR_CUBE_T1_20180508145106.json')
#      ('SH009_SAG_FSPGR_3D_20170112140902.nii', 'SH009_SAG_FSPGR_CUBE_20170112140902.nii')
#      ('SH009_SAG_FSPGR_3D_20170112140902.json', 'SH009_SAG_FSPGR_CUBE_20170112140902.json')
#      ('Br048_SAG_FSPGR_3D_20190621094305.nii', 'BR048_SAG_FSPGR_CUBE_20190621094305.nii')
#      ('Br048_SAG_FSPGR_3D_20190621094305.json', 'BR048_SAG_FSPGR_CUBE_20190621094305.json')
#      ('WH1686_SAG_FSPGR_3D_20181010154013.nii', 'WH1686_SAG_FSPGR_CUBE_20181010154013.nii')
#      ('WH1686_SAG_FSPGR_3D_20181010154013.json', 'WH1686_SAG_FSPGR_CUBE_20181010154013.json')
#      ('BR003_SAG_FSPGR_3D_20170620095427.json', 'BR003_SAG_FSPGR_CUBE_20170620095427.json')
#      ('BR003_SAG_FSPGR_3D_20170620095427.nii', 'BR003_SAG_FSPGR_CUBE_20170620095427.nii')
#      ('WH1354_SAG_FSPGR_3D_20180608161238.nii', 'WH1354_SAG_FSPGR_CUBE_20180608161238.nii')
#      ('WH1354_SAG_FSPGR_3D_20180608161238.json', 'WH1354_SAG_FSPGR_CUBE_20180608161238.json')
#      ('WH1310_SAG_FSPGR_3D_20170503101521.nii', 'WH1310_SAG_FSPGR_CUBE_20170503101521.nii')
#      ('WH1310_SAG_FSPGR_3D_20170503101521.json', 'WH1310_SAG_FSPGR_CUBE_20170503101521.json')
#      ('SH035_SAG_FSPGR_3D_20170509143850.nii', 'SH035_SAG_FSPGR_CUBE_20170509143850.nii')
#      ('SH035_SAG_FSPGR_3D_20170509143850.json', 'SH035_SAG_FSPGR_CUBE_20170509143850.json')
#      ('SH017_SAG_FSPGR_3D_20170213140013.json', 'SH017_SAG_FSPGR_CUBE_20170213140013.json')
#      ('SH017_SAG_FSPGR_3D_20170213140013.nii', 'SH017_SAG_FSPGR_CUBE_20170213140013.nii')
#      ('BR016_SAG_FSPGR_3D_20171207130232.json', 'BR016_SAG_FSPGR_CUBE_20171207130232.json')
#      ('BR016_SAG_FSPGR_3D_20171207130232.nii', 'BR016_SAG_FSPGR_CUBE_20171207130232.nii')
#      ('SH004_Sag_T1_FLAIR_20170106143911.nii', 'SH004_SAG_T1_FLAIR_20170106143911.nii')
#      ('SH004_Sag_T1_FLAIR_20170106143911.json', 'SH004_SAG_T1_FLAIR_20170106143911.json')
#      ('BR029_SAG_FSPGR_3D_T1_20180410105120.nii', 'BR029_SAG_FSPGR_CUBE_T1_20180410105120.nii')
#      ('BR029_SAG_FSPGR_3D_T1_20180410105120.json', 'BR029_SAG_FSPGR_CUBE_T1_20180410105120.json')
#      ('WH1142_SAG_FSPGR_3D_20170502100931.nii', 'WH1142_SAG_FSPGR_CUBE_20170502100931.nii')
#      ('WH1142_SAG_FSPGR_3D_20170502100931.json', 'WH1142_SAG_FSPGR_CUBE_20170502100931.json')
#      ('SH002_SAG_FSPGR_3D_20161216090218.nii', 'SH002_SAG_FSPGR_CUBE_20161216090218.nii')
#      ('SH002_SAG_FSPGR_3D_20161216090218.json', 'SH002_SAG_FSPGR_CUBE_20161216090218.json')
#      ('WH1020_SAG_FSPGR_3D_20170404142255.json', 'WH1020_SAG_FSPGR_CUBE_20170404142255.json')
#      ('WH1020_SAG_FSPGR_3D_20170404142255.nii', 'WH1020_SAG_FSPGR_CUBE_20170404142255.nii')
#      ('Wh1419_SAG_FSPGR_3D_20180910105606.nii', 'WH1419_SAG_FSPGR_CUBE_20180910105606.nii')
#      ('Wh1419_SAG_FSPGR_3D_20180910105606.json', 'WH1419_SAG_FSPGR_CUBE_20180910105606.json')
#      ('WH1419_SAG_FSPGR_3D_20180629103853.json', 'WH1419_SAG_FSPGR_CUBE_20180629103853.json')
#      ('WH1419_SAG_FSPGR_3D_20180629103853.nii', 'WH1419_SAG_FSPGR_CUBE_20180629103853.nii')
#      ('BR038_SAG_FSPGR_3D_20190321144633.json', 'BR038_SAG_FSPGR_CUBE_20190321144633.json')
#      ('BR038_SAG_FSPGR_3D_20190321144633.nii', 'BR038_SAG_FSPGR_CUBE_20190321144633.nii')
#      ('SH012_SAG_FSPGR_3D_20170131161308.json', 'SH012_SAG_FSPGR_CUBE_20170131161308.json')
#      ('SH012_SAG_FSPGR_3D_20170131161308.nii', 'SH012_SAG_FSPGR_CUBE_20170131161308.nii')
#      ('SH030_SAG_FSPGR_3D_20170419101903.nii', 'SH030_SAG_FSPGR_CUBE_20170419101903.nii')
#      ('SH030_SAG_FSPGR_3D_20170419101903.json', 'SH030_SAG_FSPGR_CUBE_20170419101903.json')
#      ('WH1663_T1_Coronal_20190401103857_i00001.nii', 'WH1663_T1_COR_20190401103857_i00001.nii')
#      ('WH1663_T1_Coronal_20190401103857_i00001.json', 'WH1663_T1_COR_20190401103857_i00001.json')
#      ('WH1663_T1_Coronal_20190401103857_i00002.json', 'WH1663_T1_COR_20190401103857_i00002.json')
#      ('WH1663_T1_Coronal_20190401103857_i00002.nii', 'WH1663_T1_COR_20190401103857_i00002.nii')
#      ('WH1663_Sag_T1_FLAIR_20190401102106.nii', 'WH1663_SAG_T1_FLAIR_20190401102106.nii')
#      ('WH1663_Sag_T1_FLAIR_20190401102106.json', 'WH1663_SAG_T1_FLAIR_20190401102106.json')
#      ('WH1663_SAG_FSPGR_3D_20190401103857.nii', 'WH1663_SAG_FSPGR_CUBE_20190401103857.nii')
#      ('WH1663_SAG_FSPGR_3D_20190401103857.json', 'WH1663_SAG_FSPGR_CUBE_20190401103857.json')
#      ('WH1721_Axial_T1_20190813110806_i00001.json', 'WH1721_AX_T1_20190813110806_i00001.json')
#      ('WH1721_Axial_T1_20190813110806_i00002.nii', 'WH1721_AX_T1_20190813110806_i00002.nii')
#      ('WH1721_Axial_T1_20190813110806_i00001.nii', 'WH1721_AX_T1_20190813110806_i00001.nii')
#      ('WH1721_Axial_T1_20190813110806_i00002.json', 'WH1721_AX_T1_20190813110806_i00002.json')
#      ('WH1721_Coronal_T1_20190813110806_i00001.json', 'WH1721_COR_T1_20190813110806_i00001.json')
#      ('WH1721_Coronal_T1_20190813110806_i00001.nii', 'WH1721_COR_T1_20190813110806_i00001.nii')
#      ('WH1721_Coronal_T1_20190813110806_i00002.json', 'WH1721_COR_T1_20190813110806_i00002.json')
#      ('WH1721_Coronal_T1_20190813110806_i00002.nii', 'WH1721_COR_T1_20190813110806_i00002.nii')
#      ('WH1721_SAG_FSPGR_3D_20190813110806.nii', 'WH1721_SAG_FSPGR_CUBE_20190813110806.nii')
#      ('WH1721_SAG_FSPGR_3D_20190813110806.json', 'WH1721_SAG_FSPGR_CUBE_20190813110806.json')
#      ('SH010_SAG_FSPGR_3D_20170120152021.nii', 'SH010_SAG_FSPGR_CUBE_20170120152021.nii')
#      ('SH010_SAG_FSPGR_3D_20170120152021.json', 'SH010_SAG_FSPGR_CUBE_20170120152021.json')
#      ('Wh1419_SAG_FSPGR_3D_20180910105606.nii', 'WH1419_SAG_FSPGR_CUBE_20180910105606.nii')
#      ('Wh1419_SAG_FSPGR_3D_20180910105606.json', 'WH1419_SAG_FSPGR_CUBE_20180910105606.json')
#      ('WH1311_SAG_FSPGR_3D_20170504101914.nii', 'WH1311_SAG_FSPGR_CUBE_20170504101914.nii')
#      ('WH1311_SAG_FSPGR_3D_20170504101914.json', 'WH1311_SAG_FSPGR_CUBE_20170504101914.json')
#      ('WH1608_SAG_FSPGR_3D_T1_20170621104914.nii', 'WH1608_SAG_FSPGR_CUBE_T1_20170621104914.nii')
#      ('WH1608_SAG_FSPGR_3D_T1_20170621104914.json', 'WH1608_SAG_FSPGR_CUBE_T1_20170621104914.json')
#      ('WH1414_SAG_FSPGR_3D_20190104092712.json', 'WH1414_SAG_FSPGR_CUBE_20190104092712.json')
#      ('WH1414_SAG_FSPGR_3D_20190104092712.nii', 'WH1414_SAG_FSPGR_CUBE_20190104092712.nii')
#      ('BR015_SAG_FSPGR_3D_T1_20171206151415.nii', 'BR015_SAG_FSPGR_CUBE_T1_20171206151415.nii')
#      ('BR015_SAG_FSPGR_3D_T1_20171206151415.json', 'BR015_SAG_FSPGR_CUBE_T1_20171206151415.json')
#      ('WH1655_SAG_FSPGR_3D_20181011105008.json', 'WH1655_SAG_FSPGR_CUBE_20181011105008.json')
#      ('WH1655_SAG_FSPGR_3D_20181011105008.nii', 'WH1655_SAG_FSPGR_CUBE_20181011105008.nii')
#      ('WH1617_SAG_FSPGR_3D_T1_20170809111631.nii', 'WH1617_SAG_FSPGR_CUBE_T1_20170809111631.nii')
#      ('WH1617_SAG_FSPGR_3D_T1_20170809111631.json', 'WH1617_SAG_FSPGR_CUBE_T1_20170809111631.json')
#      ('MEN014_SAG_FSPGR_3D_20170227145110.nii', 'MN014_SAG_FSPGR_CUBE_20170227145110.nii')
#      ('MEN014_SAG_FSPGR_3D_20170227145110.json', 'MN014_SAG_FSPGR_CUBE_20170227145110.json')
#      ('BR011_Sag_T1_FLAIR_20190226094521.nii', 'BR011_SAG_T1_FLAIR_20190226094521.nii')
#      ('BR011_Sag_T1_FLAIR_20190226094521.json', 'BR011_SAG_T1_FLAIR_20190226094521.json')
#      ('BR011_SAG_FSPGR_3D_20190226094521.nii', 'BR011_SAG_FSPGR_CUBE_20190226094521.nii')
#      ('BR011_SAG_FSPGR_3D_20190226094521.json', 'BR011_SAG_FSPGR_CUBE_20190226094521.json')
#      ('BR031_SAG_FSPGR_3D_20190513131326.json', 'BR031_SAG_FSPGR_CUBE_20190513131326.json')
#      ('BR031_SAG_FSPGR_3D_20190513131326.nii', 'BR031_SAG_FSPGR_CUBE_20190513131326.nii')
#      ('WH1707_SAG_T1_20190401135957.json', 'WH1707_SAG_T1_20190401135957.json')
#      ('WH1707_SAG_T1_20190401135957.nii', 'WH1707_SAG_T1_20190401135957.nii')
#      ('WH1707_T1_Coronal_20190401135957_i00002.json', 'WH1707_T1_COR_20190401135957_i00002.json')
#      ('WH1707_T1_Coronal_20190401135957_i00001.nii', 'WH1707_T1_COR_20190401135957_i00001.nii')
#      ('WH1707_T1_Coronal_20190401135957_i00002.nii', 'WH1707_T1_COR_20190401135957_i00002.nii')
#      ('WH1707_T1_Coronal_20190401135957_i00001.json', 'WH1707_T1_COR_20190401135957_i00001.json')
#      ('WH1737_Sagittal_T1_3D_20190708090335.nii', 'WH1737_SAG_T1_CUBE_20190708090335.nii')
#      ('WH1737_Sagittal_T1_3D_20190708090335.json', 'WH1737_SAG_T1_CUBE_20190708090335.json')
#      ('WH1737_CORONAL_T1_20190708090335.nii', 'WH1737_COR_T1_20190708090335.nii')
#      ('WH1737_CORONAL_T1_20190708090335.json', 'WH1737_COR_T1_20190708090335.json')
#      ('WH1737_SAGITTAL_T1_20190708090335.nii', 'WH1737_SAG_T1_20190708090335.nii')
#      ('WH1737_SAGITTAL_T1_20190708090335.json', 'WH1737_SAG_T1_20190708090335.json')
#      ('WH1737_AXIAL_T1_20190708090335.json', 'WH1737_AX_T1_20190708090335.json')
#      ('WH1737_AXIAL_T1_20190708090335.nii', 'WH1737_AX_T1_20190708090335.nii')
#      ('BR011_SAG_FSPGR_3D_T1_20171101130334.nii', 'BR011_SAG_FSPGR_CUBE_T1_20171101130334.nii')
#      ('BR011_SAG_FSPGR_3D_T1_20171101130334.json', 'BR011_SAG_FSPGR_CUBE_T1_20171101130334.json')
#      ('BR011_SAG_FSPGR_3D_20171101122356.nii', 'BR011_SAG_FSPGR_CUBE_20171101122356.nii')
#      ('BR011_SAG_FSPGR_3D_20171101122356.json', 'BR011_SAG_FSPGR_CUBE_20171101122356.json')
#      ('SH011_SAG_FSPGR_3D_20170131135040.nii', 'SH011_SAG_FSPGR_CUBE_20170131135040.nii')
#      ('SH011_SAG_FSPGR_3D_20170131135040.json', 'SH011_SAG_FSPGR_CUBE_20170131135040.json')
#      ('WH1333_CORONAL_T1_20191105094123.json', 'WH1333_COR_T1_20191105094123.json')
#      ('WH1333_CORONAL_T1_20191105094123.nii', 'WH1333_COR_T1_20191105094123.nii')
#      ('WH1333_SAGITTAL_T1_20191105094123.nii', 'WH1333_SAG_T1_20191105094123.nii')
#      ('WH1333_SAGITTAL_T1_20191105094123.json', 'WH1333_SAG_T1_20191105094123.json')
#      ('WH1333_AXIAL_T1_20191105094123.json', 'WH1333_AX_T1_20191105094123.json')
#      ('WH1333_AXIAL_T1_20191105094123.nii', 'WH1333_AX_T1_20191105094123.nii')
#      ('WH1333_SAG_FSPGR_3D_20191105094123.json', 'WH1333_SAG_FSPGR_CUBE_20191105094123.json')
#      ('WH1333_SAG_FSPGR_3D_20191105094123.nii', 'WH1333_SAG_FSPGR_CUBE_20191105094123.nii')
#      ('WH1723_Sagittal_T1_3D_20190530130600.nii', 'WH1723_SAG_T1_CUBE_20190530130600.nii')
#      ('WH1723_Sagittal_T1_3D_20190530130600.json', 'WH1723_SAG_T1_CUBE_20190530130600.json')
#      ('WH1723_CORONAL_T1_20190530130600.json', 'WH1723_COR_T1_20190530130600.json')
#      ('WH1723_CORONAL_T1_20190530130600.nii', 'WH1723_COR_T1_20190530130600.nii')
#      ('WH1723_SAGITTAL_T1_20190530130600.nii', 'WH1723_SAG_T1_20190530130600.nii')
#      ('WH1723_SAGITTAL_T1_20190530130600.json', 'WH1723_SAG_T1_20190530130600.json')
#      ('WH1723_AXIAL_T1_20190530130600.json', 'WH1723_AX_T1_20190530130600.json')
#      ('WH1723_AXIAL_T1_20190530130600.nii', 'WH1723_AX_T1_20190530130600.nii')
#      ('MEN031_SAG_FSPGR_3D_20170418100741.nii', 'MN031_SAG_FSPGR_CUBE_20170418100741.nii')
#      ('MEN031_SAG_FSPGR_3D_20170418100741.json', 'MN031_SAG_FSPGR_CUBE_20170418100741.json')
#      ('BR006_SAG_FSPGR_3D_T1_20171107092455.json', 'BR006_SAG_FSPGR_CUBE_T1_20171107092455.json')
#      ('BR006_SAG_FSPGR_3D_T1_20171107092455.nii', 'BR006_SAG_FSPGR_CUBE_T1_20171107092455.nii')
#      ('WH1702_SAG_FSPGR_3D_20190212111148.json', 'WH1702_SAG_FSPGR_CUBE_20190212111148.json')
#      ('WH1702_SAG_FSPGR_3D_20190212111148.nii', 'WH1702_SAG_FSPGR_CUBE_20190212111148.nii')
#      ('WH1664_SAG_FSPGR_3D_20190104133519.json', 'WH1664_SAG_FSPGR_CUBE_20190104133519.json')
#      ('WH1664_SAG_FSPGR_3D_20190104133519.nii', 'WH1664_SAG_FSPGR_CUBE_20190104133519.nii')
#      ('WH1611_SAG_FSPGR_3D_T1_20170811110429.nii', 'WH1611_SAG_FSPGR_CUBE_T1_20170811110429.nii')
#      ('WH1611_SAG_FSPGR_3D_T1_20170811110429.json', 'WH1611_SAG_FSPGR_CUBE_T1_20170811110429.json')
#      ('SH062_SAG_FSPGR_3D_20190813091545.json', 'SH062_SAG_FSPGR_CUBE_20190813091545.json')
#      ('SH062_SAG_FSPGR_3D_20190813091545.nii', 'SH062_SAG_FSPGR_CUBE_20190813091545.nii')
#      ('WH1330_SAG_FSPGR_3D_T1_20180518144521.json', 'WH1330_SAG_FSPGR_CUBE_T1_20180518144521.json')
#      ('WH1330_SAG_FSPGR_3D_T1_20180518144521.nii', 'WH1330_SAG_FSPGR_CUBE_T1_20180518144521.nii')
#      ('BR00_SAG_FSPGR_3D_20171031102929.nii', 'BR00_SAG_FSPGR_CUBE_20171031102929.nii')
#      ('BR00_SAG_FSPGR_3D_20171031102929.json', 'BR00_SAG_FSPGR_CUBE_20171031102929.json')
#      ('BR005_SAG_FSPGR_3D_20171009120947.nii', 'BR005_SAG_FSPGR_CUBE_20171009120947.nii')
#      ('BR005_SAG_FSPGR_3D_20171009120947.json', 'BR005_SAG_FSPGR_CUBE_20171009120947.json')
#      ('BR035_SAG_FSPGR_3D_20190702101108.nii', 'BR035_SAG_FSPGR_CUBE_20190702101108.nii')
#      ('BR035_SAG_FSPGR_3D_20190702101108.json', 'BR035_SAG_FSPGR_CUBE_20190702101108.json')
#      ('WH1280_CORONAL_T1_20190514094350.nii', 'WH1280_COR_T1_20190514094350.nii')
#      ('WH1280_CORONAL_T1_20190514094350.json', 'WH1280_COR_T1_20190514094350.json')
#      ('WH1280_SAGITTAL_T1_20190514094350.nii', 'WH1280_SAG_T1_20190514094350.nii')
#      ('WH1280_SAGITTAL_T1_20190514094350.json', 'WH1280_SAG_T1_20190514094350.json')
#      ('WH1280_AXIAL_T1_20190514094350.nii', 'WH1280_AX_T1_20190514094350.nii')
#      ('WH1280_AXIAL_T1_20190514094350.json', 'WH1280_AX_T1_20190514094350.json')
#      ('WH1280_SAG_FSPGR_3D_20190514094350.nii', 'WH1280_SAG_FSPGR_CUBE_20190514094350.nii')
#      ('WH1280_SAG_FSPGR_3D_20190514094350.json', 'WH1280_SAG_FSPGR_CUBE_20190514094350.json')
#      ('WH1741_Sagittal_T1_3D_20190626135539.nii', 'WH1741_SAG_T1_CUBE_20190626135539.nii')
#      ('WH1741_Sagittal_T1_3D_20190626135539.json', 'WH1741_SAG_T1_CUBE_20190626135539.json')
#      ('WH1741_CORONAL_T1_20190626135539.json', 'WH1741_COR_T1_20190626135539.json')
#      ('WH1741_CORONAL_T1_20190626135539.nii', 'WH1741_COR_T1_20190626135539.nii')
#      ('WH1741_SAGITTAL_T1_20190626135539.nii', 'WH1741_SAG_T1_20190626135539.nii')
#      ('WH1741_SAGITTAL_T1_20190626135539.json', 'WH1741_SAG_T1_20190626135539.json')
#      ('WH1741_AXIAL_T1_20190626135539.nii', 'WH1741_AX_T1_20190626135539.nii')
#      ('WH1741_AXIAL_T1_20190626135539.json', 'WH1741_AX_T1_20190626135539.json')
#      ('BR046_SAG_FSPGR_3D_20190530091459.json', 'BR046_SAG_FSPGR_CUBE_20190530091459.json')
#      ('BR046_SAG_FSPGR_3D_20190530091459.nii', 'BR046_SAG_FSPGR_CUBE_20190530091459.nii')
#      ('MEN009_SAG_FSPGR_3D_20170307100421.nii', 'MN009_SAG_FSPGR_CUBE_20170307100421.nii')
#      ('MEN009_SAG_FSPGR_3D_20170307100421.json', 'MN009_SAG_FSPGR_CUBE_20170307100421.json')
#      ('WH1690_SAG_FSPGR_3D_20180913120748.json', 'WH1690_SAG_FSPGR_CUBE_20180913120748.json')
#      ('WH1690_SAG_FSPGR_3D_20180913120748.nii', 'WH1690_SAG_FSPGR_CUBE_20180913120748.nii')
#      ('BR0012_SAG_FSPGR_3D_T1_20171108113746.nii', 'BR0012_SAG_FSPGR_CUBE_T1_20171108113746.nii')
#      ('BR0012_SAG_FSPGR_3D_T1_20171108113746.json', 'BR0012_SAG_FSPGR_CUBE_T1_20171108113746.json')
#      ('SH059_SAG_FSPGR_3D_20181018134702.nii', 'SH059_SAG_FSPGR_CUBE_20181018134702.nii')
#      ('SH059_SAG_FSPGR_3D_20181018134702.json', 'SH059_SAG_FSPGR_CUBE_20181018134702.json')
#      ('SH048_SAG_FSPGR_3D_20170816104637.json', 'SH048_SAG_FSPGR_CUBE_20170816104637.json')
#      ('SH048_SAG_FSPGR_3D_20170816104637.nii', 'SH048_SAG_FSPGR_CUBE_20170816104637.nii')
#      ('SH004_SAG_FSPGR_3D_20161220103018.nii', 'SH004_SAG_FSPGR_CUBE_20161220103018.nii')
#      ('SH004_SAG_FSPGR_3D_20161220103018.json', 'SH004_SAG_FSPGR_CUBE_20161220103018.json')
#      ('WH1655_SAG_FSPGR_3D_20180626145230.nii', 'WH1655_SAG_FSPGR_CUBE_20180626145230.nii')
#      ('WH1655_SAG_FSPGR_3D_20180626145230.json', 'WH1655_SAG_FSPGR_CUBE_20180626145230.json')
#      ('WH1623_SAG_FSPGR_3D_T1_20170912141759.json', 'WH1623_SAG_FSPGR_CUBE_T1_20170912141759.json')
#      ('WH1623_SAG_FSPGR_3D_T1_20170912141759.nii', 'WH1623_SAG_FSPGR_CUBE_T1_20170912141759.nii')
#      ('BR018_SAG_FSPGR_3D_T1_20171218112857.nii', 'BR018_SAG_FSPGR_CUBE_T1_20171218112857.nii')
#      ('BR018_SAG_FSPGR_3D_T1_20171218112857.json', 'BR018_SAG_FSPGR_CUBE_T1_20171218112857.json')
#      ('MEN022_SAG_FSPGR_3D_20170227110618.json', 'MN022_SAG_FSPGR_CUBE_20170227110618.json')
#      ('MEN022_SAG_FSPGR_3D_20170227110618.nii', 'MN022_SAG_FSPGR_CUBE_20170227110618.nii')
#      ('WH1648_SAG_FSPGR_3D_T1_20171213095323.json', 'WH1648_SAG_FSPGR_CUBE_T1_20171213095323.json')
#      ('WH1648_SAG_FSPGR_3D_T1_20171213095323.nii', 'WH1648_SAG_FSPGR_CUBE_T1_20171213095323.nii')
#      ('WH1601_SAG_FSPGR_3D_20170331102006.nii', 'WH1601_SAG_FSPGR_CUBE_20170331102006.nii')
#      ('WH1601_SAG_FSPGR_3D_20170331102006.json', 'WH1601_SAG_FSPGR_CUBE_20170331102006.json')
#      ('WH1360_SAG_FSPGR_3D_T1_20170515111656.nii', 'WH1360_SAG_FSPGR_CUBE_T1_20170515111656.nii')
#      ('WH1360_SAG_FSPGR_3D_T1_20170515111656.json', 'WH1360_SAG_FSPGR_CUBE_T1_20170515111656.json')
#      ('WH1487_SAG_FSPGR_3D_20170306175459.nii', 'WH1487_SAG_FSPGR_CUBE_20170306175459.nii')
#      ('WH1487_SAG_FSPGR_3D_20170306175459.json', 'WH1487_SAG_FSPGR_CUBE_20170306175459.json')
#      ('BR026_SAG_FSPGR_3D_T1_20180327114408.nii', 'BR026_SAG_FSPGR_CUBE_T1_20180327114408.nii')
#      ('BR026_SAG_FSPGR_3D_T1_20180327114408.json', 'BR026_SAG_FSPGR_CUBE_T1_20180327114408.json')
#      ('SH039_SAG_FSPGR_3D_20170518165501.json', 'SH039_SAG_FSPGR_CUBE_20170518165501.json')
#      ('SH039_SAG_FSPGR_3D_20170518165501.nii', 'SH039_SAG_FSPGR_CUBE_20170518165501.nii')
#      ('SH003_SAG_FSPGR_3D_20190816130333.nii', 'SH003_SAG_FSPGR_CUBE_20190816130333.nii')
#      ('SH003_SAG_FSPGR_3D_20190816130333.json', 'SH003_SAG_FSPGR_CUBE_20190816130333.json')
#      ('WH1449_SAG_FSPGR_3D_20170314150459.nii', 'WH1449_SAG_FSPGR_CUBE_20170314150459.nii')
#      ('WH1449_SAG_FSPGR_3D_20170314150459.json', 'WH1449_SAG_FSPGR_CUBE_20170314150459.json')
#      ('WH1705_SAG_FSPGR_3D_20190215134035.json', 'WH1705_SAG_FSPGR_CUBE_20190215134035.json')
#      ('WH1705_SAG_FSPGR_3D_20190215134035.nii', 'WH1705_SAG_FSPGR_CUBE_20190215134035.nii')
#      ('BR030_SAG_FSPGR_3D_20190314134705.json', 'BR030_SAG_FSPGR_CUBE_20190314134705.json')
#      ('BR030_SAG_FSPGR_3D_20190314134705.nii', 'BR030_SAG_FSPGR_CUBE_20190314134705.nii')
#      ('WH1727_Sagittal_T1_3D_20190603131028.nii', 'WH1727_SAG_T1_CUBE_20190603131028.nii')
#      ('WH1727_Sagittal_T1_3D_20190603131028.json', 'WH1727_SAG_T1_CUBE_20190603131028.json')
#      ('WH1727_CORONAL_T1_20190603131028.nii', 'WH1727_COR_T1_20190603131028.nii')
#      ('WH1727_CORONAL_T1_20190603131028.json', 'WH1727_COR_T1_20190603131028.json')
#      ('WH1727_SAGITTAL_T1_20190603131028.json', 'WH1727_SAG_T1_20190603131028.json')
#      ('WH1727_SAGITTAL_T1_20190603131028.nii', 'WH1727_SAG_T1_20190603131028.nii')
#      ('WH1727_AXIAL_T1_20190603131028.nii', 'WH1727_AX_T1_20190603131028.nii')
#      ('WH1727_AXIAL_T1_20190603131028.json', 'WH1727_AX_T1_20190603131028.json')
#      ('BR038_SAG_FSPGR_3D_20181026104213.json', 'BR038_SAG_FSPGR_CUBE_20181026104213.json')
#      ('BR038_SAG_FSPGR_3D_20181026104213.nii', 'BR038_SAG_FSPGR_CUBE_20181026104213.nii')
#      ('BR043_SAG_FSPGR_3D_20190205131226.nii', 'BR043_SAG_FSPGR_CUBE_20190205131226.nii')
#      ('BR043_SAG_FSPGR_3D_20190205131226.json', 'BR043_SAG_FSPGR_CUBE_20190205131226.json')
#      ('MEN050_SAG_FSPGR_3D_20190220154013.json', 'MN050_SAG_FSPGR_CUBE_20190220154013.json')
#      ('MEN050_SAG_FSPGR_3D_20190220154013.nii', 'MN050_SAG_FSPGR_CUBE_20190220154013.nii')
#      ('WH1657_SAG_FSPGR_3D_T1_20180409150847.nii', 'WH1657_SAG_FSPGR_CUBE_T1_20180409150847.nii')
#      ('WH1657_SAG_FSPGR_3D_T1_20180409150847.json', 'WH1657_SAG_FSPGR_CUBE_T1_20180409150847.json')
#      ('BR001_SAG_FSPGR_3D_T1_20170511102034.json', 'BR001_SAG_FSPGR_CUBE_T1_20170511102034.json')
#      ('BR001_SAG_FSPGR_3D_T1_20170511102034.nii', 'BR001_SAG_FSPGR_CUBE_T1_20170511102034.nii')
#      ('WH1716_SAG_FSPGR_3D_20190213140543.json', 'WH1716_SAG_FSPGR_CUBE_20190213140543.json')
#      ('WH1716_SAG_FSPGR_3D_20190213140543.nii', 'WH1716_SAG_FSPGR_CUBE_20190213140543.nii')
#      ('BR042_SAG_FSPGR_3D_20181204150351.nii', 'BR042_SAG_FSPGR_CUBE_20181204150351.nii')
#      ('BR042_SAG_FSPGR_3D_20181204150351.json', 'BR042_SAG_FSPGR_CUBE_20181204150351.json')
#      ('WH1651_SAG_FSPGR_3D_T1_20180501103329.nii', 'WH1651_SAG_FSPGR_CUBE_T1_20180501103329.nii')
#      ('WH1651_SAG_FSPGR_3D_T1_20180501103329.json', 'WH1651_SAG_FSPGR_CUBE_T1_20180501103329.json')
#      ('BR037_SAG_FSPGR_3D_20181012092433.json', 'BR037_SAG_FSPGR_CUBE_20181012092433.json')
#      ('BR037_SAG_FSPGR_3D_20181012092433.nii', 'BR037_SAG_FSPGR_CUBE_20181012092433.nii')
#      ('MEN041_SAG_FSPGR_3D_20170815143559.json', 'MN041_SAG_FSPGR_CUBE_20170815143559.json')
#      ('MEN041_SAG_FSPGR_3D_20170815143559.nii', 'MN041_SAG_FSPGR_CUBE_20170815143559.nii')
#      ('MEN032_SAG_FSPGR_3D_20170411100927.json', 'MN032_SAG_FSPGR_CUBE_20170411100927.json')
#      ('MEN032_SAG_FSPGR_3D_20170411100927.nii', 'MN032_SAG_FSPGR_CUBE_20170411100927.nii')
#      ('1499_SAG_FSPGR_3D_20170111101313.json', 'WH1499_SAG_FSPGR_CUBE_20170111101313.json')
#      ('1499_SAG_FSPGR_3D_20170111101313.nii', 'WH1499_SAG_FSPGR_CUBE_20170111101313.nii')
#      ('SH032_SAG_FSPGR_3D_20170404095639.json', 'SH032_SAG_FSPGR_CUBE_20170404095639.json')
#      ('SH032_SAG_FSPGR_3D_20170404095639.nii', 'SH032_SAG_FSPGR_CUBE_20170404095639.nii')
#      ('WH1612_SAG_FSPGR_3D_T1_20170706075309.json', 'WH1612_SAG_FSPGR_CUBE_T1_20170706075309.json')
#      ('WH1612_SAG_FSPGR_3D_T1_20170706075309.nii', 'WH1612_SAG_FSPGR_CUBE_T1_20170706075309.nii')
#      ('MEN044_SAG_FSPGR_3D_20180515111421.json', 'MN044_SAG_FSPGR_CUBE_20180515111421.json')
#      ('MEN044_SAG_FSPGR_3D_20180515111421.nii', 'MN044_SAG_FSPGR_CUBE_20180515111421.nii')
#      ('BR034_SAG_FSPGR_3D_20180814154401.nii', 'BR034_SAG_FSPGR_CUBE_20180814154401.nii')
#      ('BR034_SAG_FSPGR_3D_20180814154401.json', 'BR034_SAG_FSPGR_CUBE_20180814154401.json')
#      ('WH1616_SAG_FSPGR_3D_T1_20170628123050.json', 'WH1616_SAG_FSPGR_CUBE_T1_20170628123050.json')
#      ('WH1616_SAG_FSPGR_3D_T1_20170628123050.nii', 'WH1616_SAG_FSPGR_CUBE_T1_20170628123050.nii')
#      ('BR027_SAG_FSPGR_3D_T1_20180328115320.json', 'BR027_SAG_FSPGR_CUBE_T1_20180328115320.json')
#      ('BR027_SAG_FSPGR_3D_T1_20180328115320.nii', 'BR027_SAG_FSPGR_CUBE_T1_20180328115320.nii')
#      ('BR021_SAG_FSPGR_3D_T1_20180124120947.json', 'BR021_SAG_FSPGR_CUBE_T1_20180124120947.json')
#      ('BR021_SAG_FSPGR_3D_T1_20180124120947.nii', 'BR021_SAG_FSPGR_CUBE_T1_20180124120947.nii')
#      ('WH1698_SAG_FSPGR_3D_20181025101859.nii', 'WH1698_SAG_FSPGR_CUBE_20181025101859.nii')
#      ('WH1698_SAG_FSPGR_3D_20181025101859.json', 'WH1698_SAG_FSPGR_CUBE_20181025101859.json')
#      ('MEN029_SAG_FSPGR_3D_20170222161055.nii', 'MN029_SAG_FSPGR_CUBE_20170222161055.nii')
#      ('MEN029_SAG_FSPGR_3D_20170222161055.json', 'MN029_SAG_FSPGR_CUBE_20170222161055.json')
#      ('MEN030_SAG_FSPGR_3D_20170327140610.nii', 'MN030_SAG_FSPGR_CUBE_20170327140610.nii')
#      ('MEN030_SAG_FSPGR_3D_20170327140610.json', 'MN030_SAG_FSPGR_CUBE_20170327140610.json')
#      ('WH1615_SAG_FSPGR_3D_T1_20180105140227.nii', 'WH1615_SAG_FSPGR_CUBE_T1_20180105140227.nii')
#      ('WH1615_SAG_FSPGR_3D_T1_20180105140227.json', 'WH1615_SAG_FSPGR_CUBE_T1_20180105140227.json')
#      ('WH1604_SAG_FSPGR_3D_20170310134135.nii', 'WH1604_SAG_FSPGR_CUBE_20170310134135.nii')
#      ('WH1604_SAG_FSPGR_3D_20170310134135.json', 'WH1604_SAG_FSPGR_CUBE_20170310134135.json')
#      ('WH1242_SAG_FSPGR_3D_20190115130142.json', 'WH1242_SAG_FSPGR_CUBE_20190115130142.json')
#      ('WH1242_SAG_FSPGR_3D_20190115130142.nii', 'WH1242_SAG_FSPGR_CUBE_20190115130142.nii')
#      ('BR018_SAG_FSPGR_3D_20190214110618.json', 'BR018_SAG_FSPGR_CUBE_20190214110618.json')
#      ('BR018_SAG_FSPGR_3D_20190214110618.nii', 'BR018_SAG_FSPGR_CUBE_20190214110618.nii')
#      ('SH046_SAG_FSPGR_3D_20170711102903.nii', 'SH046_SAG_FSPGR_CUBE_20170711102903.nii')
#      ('SH046_SAG_FSPGR_3D_20170711102903.json', 'SH046_SAG_FSPGR_CUBE_20170711102903.json')
#      ('SH051_SAG_FSPGR_3D_20171027104756.json', 'SH051_SAG_FSPGR_CUBE_20171027104756.json')
#      ('SH051_SAG_FSPGR_3D_20171027104756.nii', 'SH051_SAG_FSPGR_CUBE_20171027104756.nii')
#      ('MEN015_SAG_FSPGR_3D_20170216143327.nii', 'MN015_SAG_FSPGR_CUBE_20170216143327.nii')
#      ('MEN015_SAG_FSPGR_3D_20170216143327.json', 'MN015_SAG_FSPGR_CUBE_20170216143327.json')
#      ('WH1268_SAG_FSPGR_3D_T1_20170830100435.json', 'WH1268_SAG_FSPGR_CUBE_T1_20170830100435.json')
#      ('WH1268_SAG_FSPGR_3D_T1_20170830100435.nii', 'WH1268_SAG_FSPGR_CUBE_T1_20170830100435.nii')
#      ('WH1482_SAG_FSPGR_3D_20161111100738.nii', 'WH1482_SAG_FSPGR_CUBE_20161111100738.nii')
#      ('WH1482_SAG_FSPGR_3D_20161111100738.json', 'WH1482_SAG_FSPGR_CUBE_20161111100738.json')
#      ('BR047_SAG_FSPGR_3D_20190617093504.json', 'BR047_SAG_FSPGR_CUBE_20190617093504.json')
#      ('BR047_SAG_FSPGR_3D_20190617093504.nii', 'BR047_SAG_FSPGR_CUBE_20190617093504.nii')
#      ('BR051_SAG_FSPGR_3D_20190909111639.nii', 'BR051_SAG_FSPGR_CUBE_20190909111639.nii')
#      ('BR051_SAG_FSPGR_3D_20190909111639.json', 'BR051_SAG_FSPGR_CUBE_20190909111639.json')
#      ('WH1275_Sagittal_T1_3D_20190419091312.json', 'WH1275_SAG_T1_CUBE_20190419091312.json')
#      ('WH1275_Sagittal_T1_3D_20190419091312.nii', 'WH1275_SAG_T1_CUBE_20190419091312.nii')
#      ('WH1275_CORONAL_T1_20190419091312.json', 'WH1275_COR_T1_20190419091312.json')
#      ('WH1275_CORONAL_T1_20190419091312.nii', 'WH1275_COR_T1_20190419091312.nii')
#      ('WH1275_SAGITTAL_T1_20190419091312.nii', 'WH1275_SAG_T1_20190419091312.nii')
#      ('WH1275_SAGITTAL_T1_20190419091312.json', 'WH1275_SAG_T1_20190419091312.json')
#      ('WH1275_AXIAL_T1_20190419091312.nii', 'WH1275_AX_T1_20190419091312.nii')
#      ('WH1275_AXIAL_T1_20190419091312.json', 'WH1275_AX_T1_20190419091312.json')
#      ('BR014_SAG_FSPGR_3D_T1_20171115123805.nii', 'BR014_SAG_FSPGR_CUBE_T1_20171115123805.nii')
#      ('BR014_SAG_FSPGR_3D_T1_20171115123805.json', 'BR014_SAG_FSPGR_CUBE_T1_20171115123805.json')
#      ('WH1660_SAG_FSPGR_3D_T1_20180411150611.nii', 'WH1660_SAG_FSPGR_CUBE_T1_20180411150611.nii')
#      ('WH1660_SAG_FSPGR_3D_T1_20180411150611.json', 'WH1660_SAG_FSPGR_CUBE_T1_20180411150611.json')
#      ('WH1296_SAG_FSPGR_3D_20170503142848.nii', 'WH1296_SAG_FSPGR_CUBE_20170503142848.nii')
#      ('WH1296_SAG_FSPGR_3D_20170503142848.json', 'WH1296_SAG_FSPGR_CUBE_20170503142848.json')
#      ('SH015_SAG_FSPGR_3D_20170208134024.nii', 'SH015_SAG_FSPGR_CUBE_20170208134024.nii')
#      ('SH015_SAG_FSPGR_3D_20170208134024.json', 'SH015_SAG_FSPGR_CUBE_20170208134024.json')
#      ('WH1738_Sagittal_T1_3D_20190715094319.json', 'WH1738_SAG_T1_CUBE_20190715094319.json')
#      ('WH1738_Sagittal_T1_3D_20190715094319.nii', 'WH1738_SAG_T1_CUBE_20190715094319.nii')
#      ('WH1738_CORONAL_T1_20190715094319.nii', 'WH1738_COR_T1_20190715094319.nii')
#      ('WH1738_CORONAL_T1_20190715094319.json', 'WH1738_COR_T1_20190715094319.json')
#      ('WH1738_SAGITTAL_T1_20190715094319.json', 'WH1738_SAG_T1_20190715094319.json')
#      ('WH1738_SAGITTAL_T1_20190715094319.nii', 'WH1738_SAG_T1_20190715094319.nii')
#      ('WH1738_AXIAL_T1_20190715094319.json', 'WH1738_AX_T1_20190715094319.json')
#      ('WH1738_AXIAL_T1_20190715094319.nii', 'WH1738_AX_T1_20190715094319.nii')
#      ('SH042_SAG_FSPGR_3D_20170523152429.json', 'SH042_SAG_FSPGR_CUBE_20170523152429.json')
#      ('SH042_SAG_FSPGR_3D_20170523152429.nii', 'SH042_SAG_FSPGR_CUBE_20170523152429.nii')
#      ('BR020_SAG_FSPGR_3D_20180109135807.nii', 'BR020_SAG_FSPGR_CUBE_20180109135807.nii')
#      ('BR020_SAG_FSPGR_3D_20180109135807.json', 'BR020_SAG_FSPGR_CUBE_20180109135807.json')
#      ('SH041_SAG_FSPGR_3D_20170519150042.json', 'SH041_SAG_FSPGR_CUBE_20170519150042.json')
#      ('SH041_SAG_FSPGR_3D_20170519150042.nii', 'SH041_SAG_FSPGR_CUBE_20170519150042.nii')
#      ('WH1725_Sagittal_T1_3D_20190617130818.json', 'WH1725_SAG_T1_CUBE_20190617130818.json')
#      ('WH1725_Sagittal_T1_3D_20190617130818.nii', 'WH1725_SAG_T1_CUBE_20190617130818.nii')
#      ('WH1725_CORONAL_T1_20190617130818.json', 'WH1725_COR_T1_20190617130818.json')
#      ('WH1725_CORONAL_T1_20190617130818.nii', 'WH1725_COR_T1_20190617130818.nii')
#      ('WH1725_SAGITTAL_T1_20190617130818.json', 'WH1725_SAG_T1_20190617130818.json')
#      ('WH1725_SAGITTAL_T1_20190617130818.nii', 'WH1725_SAG_T1_20190617130818.nii')
#      ('WH1725_AXIAL_T1_20190617130818.json', 'WH1725_AX_T1_20190617130818.json')
#      ('WH1725_AXIAL_T1_20190617130818.nii', 'WH1725_AX_T1_20190617130818.nii')
#      ('WH1625_SAG_FSPGR_3D_T1_20171009143902.nii', 'WH1625_SAG_FSPGR_CUBE_T1_20171009143902.nii')
#      ('WH1625_SAG_FSPGR_3D_T1_20171009143902.json', 'WH1625_SAG_FSPGR_CUBE_T1_20171009143902.json')
#      ('BR014_SAG_FSPGR_3D_20181119115538.json', 'BR014_SAG_FSPGR_CUBE_20181119115538.json')
#      ('BR014_SAG_FSPGR_3D_20181119115538.nii', 'BR014_SAG_FSPGR_CUBE_20181119115538.nii')
#      ('SH028_SAG_FSPGR_3D_20170512104944.json', 'SH028_SAG_FSPGR_CUBE_20170512104944.json')
#      ('SH028_SAG_FSPGR_3D_20170512104944.nii', 'SH028_SAG_FSPGR_CUBE_20170512104944.nii')
#      ('WH1736_Sagittal_T1_3D_20190708103024.nii', 'WH1736_SAG_T1_CUBE_20190708103024.nii')
#      ('WH1736_Sagittal_T1_3D_20190708103024.json', 'WH1736_SAG_T1_CUBE_20190708103024.json')
#      ('WH1736_CORONAL_T1_20190708103024.json', 'WH1736_COR_T1_20190708103024.json')
#      ('WH1736_CORONAL_T1_20190708103024.nii', 'WH1736_COR_T1_20190708103024.nii')
#      ('WH1736_SAGITTAL_T1_20190708103024.json', 'WH1736_SAG_T1_20190708103024.json')
#      ('WH1736_SAGITTAL_T1_20190708103024.nii', 'WH1736_SAG_T1_20190708103024.nii')
#      ('WH1736_AXIAL_T1_20190708103024.json', 'WH1736_AX_T1_20190708103024.json')
#      ('WH1736_AXIAL_T1_20190708103024.nii', 'WH1736_AX_T1_20190708103024.nii')
#      ('WH1646_SAG_FSPGR_3D_T1_20171215105227.json', 'WH1646_SAG_FSPGR_CUBE_T1_20171215105227.json')
#      ('WH1646_SAG_FSPGR_3D_T1_20171215105227.nii', 'WH1646_SAG_FSPGR_CUBE_T1_20171215105227.nii')
#      ('SH045_SAG_FSPGR_3D_20170706133844.json', 'SH045_SAG_FSPGR_CUBE_20170706133844.json')
#      ('SH045_SAG_FSPGR_3D_20170706133844.nii', 'SH045_SAG_FSPGR_CUBE_20170706133844.nii')
#      ('MEN038_SAG_FSPGR_3D_20170418135909.json', 'MN038_SAG_FSPGR_CUBE_20170418135909.json')
#      ('MEN038_SAG_FSPGR_3D_20170418135909.nii', 'MN038_SAG_FSPGR_CUBE_20170418135909.nii')
#      ('SH025_SAG_FSPGR_3D_20170329141311.json', 'SH025_SAG_FSPGR_CUBE_20170329141311.json')
#      ('SH025_SAG_FSPGR_3D_20170329141311.nii', 'SH025_SAG_FSPGR_CUBE_20170329141311.nii')
#      ('MEN040_SAG_FSPGR_3D_20170512130925.nii', 'MN040_SAG_FSPGR_CUBE_20170512130925.nii')
#      ('MEN040_SAG_FSPGR_3D_20170512130925.json', 'MN040_SAG_FSPGR_CUBE_20170512130925.json')
#      ('BR009_SAG_FSPGR_3D_20171030160357.nii', 'BR009_SAG_FSPGR_CUBE_20171030160357.nii')
#      ('BR009_SAG_FSPGR_3D_20171030160357.json', 'BR009_SAG_FSPGR_CUBE_20171030160357.json')
#      ('MEN028_SAG_FSPGR_3D_20170316101107.json', 'MN028_SAG_FSPGR_CUBE_20170316101107.json')
#      ('MEN028_SAG_FSPGR_3D_20170316101107.nii', 'MN028_SAG_FSPGR_CUBE_20170316101107.nii')
#      ('WH1247_SAG_FSPGR_3D_20181206133418.json', 'WH1247_SAG_FSPGR_CUBE_20181206133418.json')
#      ('WH1247_SAG_FSPGR_3D_20181206133418.nii', 'WH1247_SAG_FSPGR_CUBE_20181206133418.nii')
#      ('SH031_SAG_FSPGR_3D_20170505142808.json', 'SH031_SAG_FSPGR_CUBE_20170505142808.json')
#      ('SH031_SAG_FSPGR_3D_20170505142808.nii', 'SH031_SAG_FSPGR_CUBE_20170505142808.nii')
#      ('BR024_SAG_FSPGR_3D_T1_20180227163900.nii', 'BR024_SAG_FSPGR_CUBE_T1_20180227163900.nii')
#      ('BR024_SAG_FSPGR_3D_T1_20180227163900.json', 'BR024_SAG_FSPGR_CUBE_T1_20180227163900.json')
#      ('SH060_SAG_FSPGR_3D_20190820133401.json', 'SH060_SAG_FSPGR_CUBE_20190820133401.json')
#      ('SH060_SAG_FSPGR_3D_20190820133401.nii', 'SH060_SAG_FSPGR_CUBE_20190820133401.nii')
#      ('WH1406_SAG_FSPGR_3D_T1_20170511142945.nii', 'WH1406_SAG_FSPGR_CUBE_T1_20170511142945.nii')
#      ('WH1406_SAG_FSPGR_3D_T1_20170511142945.json', 'WH1406_SAG_FSPGR_CUBE_T1_20170511142945.json')
#      ('MEN052_SAG_FSPGR_3D_20190318124108.json', 'MN052_SAG_FSPGR_CUBE_20190318124108.json')
#      ('MEN052_SAG_FSPGR_3D_20190318124108.nii', 'MN052_SAG_FSPGR_CUBE_20190318124108.nii')
#      ('WH1349_SAG_FSPGR_3D_20180627143541.nii', 'WH1349_SAG_FSPGR_CUBE_20180627143541.nii')
#      ('WH1349_SAG_FSPGR_3D_20180627143541.json', 'WH1349_SAG_FSPGR_CUBE_20180627143541.json')
#      ('WH1649_SAG_FSPGR_3D_T1_20180503093352.nii', 'WH1649_SAG_FSPGR_CUBE_T1_20180503093352.nii')
#      ('WH1649_SAG_FSPGR_3D_T1_20180503093352.json', 'WH1649_SAG_FSPGR_CUBE_T1_20180503093352.json')
#      ('SH019_SAG_FSPGR_3D_20170221154543.json', 'SH019_SAG_FSPGR_CUBE_20170221154543.json')
#      ('SH019_SAG_FSPGR_3D_20170221154543.nii', 'SH019_SAG_FSPGR_CUBE_20170221154543.nii')
#      ('SH001_SAG_FSPGR_3D_20161213141852.nii', 'SH001_SAG_FSPGR_CUBE_20161213141852.nii')
#      ('SH001_SAG_FSPGR_3D_20161213141852.json', 'SH001_SAG_FSPGR_CUBE_20161213141852.json')
#      ('BR044_SAG_FSPGR_3D_20190129091124.json', 'BR044_SAG_FSPGR_CUBE_20190129091124.json')
#      ('BR044_SAG_FSPGR_3D_20190129091124.nii', 'BR044_SAG_FSPGR_CUBE_20190129091124.nii')
#      ('MEN034_SAG_FSPGR_3D_20170407102028.nii', 'MN034_SAG_FSPGR_CUBE_20170407102028.nii')
#      ('MEN034_SAG_FSPGR_3D_20170407102028.json', 'MN034_SAG_FSPGR_CUBE_20170407102028.json')
#      ('BR027_SAG_FSPGR_3D_20190328100245.nii', 'BR027_SAG_FSPGR_CUBE_20190328100245.nii')
#      ('BR027_SAG_FSPGR_3D_20190328100245.json', 'BR027_SAG_FSPGR_CUBE_20190328100245.json')
#      ('BR049_Axial_T1_20190624142000.nii', 'BR049_AX_T1_20190624142000.nii')
#      ('BR049_Axial_T1_20190624142000.json', 'BR049_AX_T1_20190624142000.json')
#      ('BR049_Coronal_T1_20190624142000.nii', 'BR049_COR_T1_20190624142000.nii')
#      ('BR049_Coronal_T1_20190624142000.json', 'BR049_COR_T1_20190624142000.json')
#      ('BR049_SAG_FSPGR_3D_20190624142000.json', 'BR049_SAG_FSPGR_CUBE_20190624142000.json')
#      ('BR049_SAG_FSPGR_3D_20190624142000.nii', 'BR049_SAG_FSPGR_CUBE_20190624142000.nii')
#      ('MEN026_SAG_FSPGR_3D_20170315093730.json', 'MN026_SAG_FSPGR_CUBE_20170315093730.json')
#      ('MEN026_SAG_FSPGR_3D_20170315093730.nii', 'MN026_SAG_FSPGR_CUBE_20170315093730.nii')
#      ('SH020_SAG_FSPGR_3D_20170303103229.nii', 'SH020_SAG_FSPGR_CUBE_20170303103229.nii')
#      ('SH020_SAG_FSPGR_3D_20170303103229.json', 'SH020_SAG_FSPGR_CUBE_20170303103229.json')
#      ('MEN044_SAG_FSPGR_3D_20180821094714.nii', 'MN044_SAG_FSPGR_CUBE_20180821094714.nii')
#      ('MEN044_SAG_FSPGR_3D_20180821094714.json', 'MN044_SAG_FSPGR_CUBE_20180821094714.json')
#      ('SH007_SAG_FSPGR_3D_20170104151649.nii', 'SH007_SAG_FSPGR_CUBE_20170104151649.nii')
#      ('SH007_SAG_FSPGR_3D_20170104151649.json', 'SH007_SAG_FSPGR_CUBE_20170104151649.json')
#      ('MEN002_SAG_FSPGR_3D_20170215102136.nii', 'MN002_SAG_FSPGR_CUBE_20170215102136.nii')
#      ('MEN002_SAG_FSPGR_3D_20170215102136.json', 'MN002_SAG_FSPGR_CUBE_20170215102136.json')
#      ('BR023_SAG_FSPGR_3D_20190214093736.nii', 'BR023_SAG_FSPGR_CUBE_20190214093736.nii')
#      ('BR023_SAG_FSPGR_3D_20190214093736.json', 'BR023_SAG_FSPGR_CUBE_20190214093736.json')
#      ('WH1696_SAG_FSPGR_3D_20181101112837.json', 'WH1696_SAG_FSPGR_CUBE_20181101112837.json')
#      ('WH1696_SAG_FSPGR_3D_20181101112837.nii', 'WH1696_SAG_FSPGR_CUBE_20181101112837.nii')
#      ('WH1523_SAG_FSPGR_3D_20170509110534.nii', 'WH1523_SAG_FSPGR_CUBE_20170509110534.nii')
#      ('WH1523_SAG_FSPGR_3D_20170509110534.json', 'WH1523_SAG_FSPGR_CUBE_20170509110534.json')
#      ('SH047_SAG_FSPGR_3D_20170712104739.nii', 'SH047_SAG_FSPGR_CUBE_20170712104739.nii')
#      ('SH047_SAG_FSPGR_3D_20170712104739.json', 'SH047_SAG_FSPGR_CUBE_20170712104739.json')
#      ('MEN017_SAG_FSPGR_3D_20170224140230.nii', 'MN017_SAG_FSPGR_CUBE_20170224140230.nii')
#      ('MEN017_SAG_FSPGR_3D_20170224140230.json', 'MN017_SAG_FSPGR_CUBE_20170224140230.json')
#      ('MEN050_SAG_FSPGR_3D_20190220151037.nii', 'MN050_SAG_FSPGR_CUBE_20190220151037.nii')
#      ('MEN050_SAG_FSPGR_3D_20190220151037.json', 'MN050_SAG_FSPGR_CUBE_20190220151037.json')
#      ('WH1733_Sagittal_T1_3D_20190612090542.json', 'WH1733_SAG_T1_CUBE_20190612090542.json')
#      ('WH1733_Sagittal_T1_3D_20190612090542.nii', 'WH1733_SAG_T1_CUBE_20190612090542.nii')
#      ('WH1733_CORONAL_T1_20190612090542.nii', 'WH1733_COR_T1_20190612090542.nii')
#      ('WH1733_CORONAL_T1_20190612090542.json', 'WH1733_COR_T1_20190612090542.json')
#      ('WH1733_SAGITTAL_T1_20190612090542.json', 'WH1733_SAG_T1_20190612090542.json')
#      ('WH1733_SAGITTAL_T1_20190612090542.nii', 'WH1733_SAG_T1_20190612090542.nii')
#      ('WH1733_AXIAL_T1_20190612090542.json', 'WH1733_AX_T1_20190612090542.json')
#      ('WH1733_AXIAL_T1_20190612090542.nii', 'WH1733_AX_T1_20190612090542.nii')
#      ('MEN001_SAG_FSPGR_3D_20170214141641.json', 'MN001_SAG_FSPGR_CUBE_20170214141641.json')
#      ('MEN001_SAG_FSPGR_3D_20170214141641.nii', 'MN001_SAG_FSPGR_CUBE_20170214141641.nii')
#      ('SH043_SAG_FSPGR_3D_20170619150511.nii', 'SH043_SAG_FSPGR_CUBE_20170619150511.nii')
#      ('SH043_SAG_FSPGR_3D_20170619150511.json', 'SH043_SAG_FSPGR_CUBE_20170619150511.json')
#      ('SH027_SAG_FSPGR_3D_20170406101506.nii', 'SH027_SAG_FSPGR_CUBE_20170406101506.nii')
#      ('SH027_SAG_FSPGR_3D_20170406101506.json', 'SH027_SAG_FSPGR_CUBE_20170406101506.json')
#      ('SH052_SAG_FSPGR_3D_20171107135121.nii', 'SH052_SAG_FSPGR_CUBE_20171107135121.nii')
#      ('SH052_SAG_FSPGR_3D_20171107135121.json', 'SH052_SAG_FSPGR_CUBE_20171107135121.json')
#      ('BR043_SAG_FSPGR_3D_20190128112730.nii', 'BR043_SAG_FSPGR_CUBE_20190128112730.nii')
#      ('BR043_SAG_FSPGR_3D_20190128112730.json', 'BR043_SAG_FSPGR_CUBE_20190128112730.json')
#      ('WH1667_SAG_FSPGR_3D_20180820095936.json', 'WH1667_SAG_FSPGR_CUBE_20180820095936.json')
#      ('WH1667_SAG_FSPGR_3D_20180820095936.nii', 'WH1667_SAG_FSPGR_CUBE_20180820095936.nii')
#      ('WH1743_Sagittal_T1_3D_20191008102726.nii', 'WH1743_SAG_T1_CUBE_20191008102726.nii')
#      ('WH1743_Sagittal_T1_3D_20191008102726.json', 'WH1743_SAG_T1_CUBE_20191008102726.json')
#      ('WH1743_CORONAL_T1_20191008102726.json', 'WH1743_COR_T1_20191008102726.json')
#      ('WH1743_CORONAL_T1_20191008102726.nii', 'WH1743_COR_T1_20191008102726.nii')
#      ('WH1743_SAGITTAL_T1_20191008102726.nii', 'WH1743_SAG_T1_20191008102726.nii')
#      ('WH1743_SAGITTAL_T1_20191008102726.json', 'WH1743_SAG_T1_20191008102726.json')
#      ('WH1743_AXIAL_T1_20191008102726.json', 'WH1743_AX_T1_20191008102726.json')
#      ('WH1743_AXIAL_T1_20191008102726.nii', 'WH1743_AX_T1_20191008102726.nii')
#      ('WH1628_SAG_FSPGR_3D_T1_20171116152250.json', 'WH1628_SAG_FSPGR_CUBE_T1_20171116152250.json')
#      ('WH1628_SAG_FSPGR_3D_T1_20171116152250.nii', 'WH1628_SAG_FSPGR_CUBE_T1_20171116152250.nii')
#      ('WH1728_Sagittal_T1_3D_20190716110139.json', 'WH1728_SAG_T1_CUBE_20190716110139.json')
#      ('WH1728_Sagittal_T1_3D_20190716110139.nii', 'WH1728_SAG_T1_CUBE_20190716110139.nii')
#      ('WH1728_CORONAL_T1_20190716110139.json', 'WH1728_COR_T1_20190716110139.json')
#      ('WH1728_CORONAL_T1_20190716110139.nii', 'WH1728_COR_T1_20190716110139.nii')
#      ('WH1728_SAGITTAL_T1_20190716110139.nii', 'WH1728_SAG_T1_20190716110139.nii')
#      ('WH1728_SAGITTAL_T1_20190716110139.json', 'WH1728_SAG_T1_20190716110139.json')
#      ('WH1728_AXIAL_T1_20190716110139.nii', 'WH1728_AX_T1_20190716110139.nii')
#      ('WH1728_AXIAL_T1_20190716110139.json', 'WH1728_AX_T1_20190716110139.json')
#      ('WH1639_SAG_FSPGR_3D_T1_20170914100910.nii', 'WH1639_SAG_FSPGR_CUBE_T1_20170914100910.nii')
#      ('WH1639_SAG_FSPGR_3D_T1_20170914100910.json', 'WH1639_SAG_FSPGR_CUBE_T1_20170914100910.json')
#      ('WH1622_SAG_FSPGR_3D_T1_20171130103707.json', 'WH1622_SAG_FSPGR_CUBE_T1_20171130103707.json')
#      ('WH1622_SAG_FSPGR_3D_T1_20171130103707.nii', 'WH1622_SAG_FSPGR_CUBE_T1_20171130103707.nii')
#      ('SH058_SAG_FSPGR_3D_20180607104235.nii', 'SH058_SAG_FSPGR_CUBE_20180607104235.nii')
#      ('SH058_SAG_FSPGR_3D_20180607104235.json', 'SH058_SAG_FSPGR_CUBE_20180607104235.json')
#      ('WH1492_SAG_FSPGR_3D_20170222140740.nii', 'WH1492_SAG_FSPGR_CUBE_20170222140740.nii')
#      ('WH1492_SAG_FSPGR_3D_20170222140740.json', 'WH1492_SAG_FSPGR_CUBE_20170222140740.json')
#      ('WH1487_Sagittal_T1_3D_20190712112737.json', 'WH1487_SAG_T1_CUBE_20190712112737.json')
#      ('WH1487_Sagittal_T1_3D_20190712112737.nii', 'WH1487_SAG_T1_CUBE_20190712112737.nii')
#      ('WH1487_CORONAL_T1_20190712112737.nii', 'WH1487_COR_T1_20190712112737.nii')
#      ('WH1487_CORONAL_T1_20190712112737.json', 'WH1487_COR_T1_20190712112737.json')
#      ('WH1487_SAGITTAL_T1_20190712112737.json', 'WH1487_SAG_T1_20190712112737.json')
#      ('WH1487_SAGITTAL_T1_20190712112737.nii', 'WH1487_SAG_T1_20190712112737.nii')
#      ('WH1487_AXIAL_T1_20190712112737.nii', 'WH1487_AX_T1_20190712112737.nii')
#      ('WH1487_AXIAL_T1_20190712112737.json', 'WH1487_AX_T1_20190712112737.json')
#      ('SH016_SAG_FSPGR_3D_20170510161050.json', 'SH016_SAG_FSPGR_CUBE_20170510161050.json')
#      ('SH016_SAG_FSPGR_3D_20170510161050.nii', 'SH016_SAG_FSPGR_CUBE_20170510161050.nii')
#      ('MEN043_SAG_FSPGR_3D_20180215095842.nii', 'MN043_SAG_FSPGR_CUBE_20180215095842.nii')
#      ('MEN043_SAG_FSPGR_3D_20180215095842.json', 'MN043_SAG_FSPGR_CUBE_20180215095842.json')
#      ('SH056_SAG_FSPGR_3D_20180523111443.json', 'SH056_SAG_FSPGR_CUBE_20180523111443.json')
#      ('SH056_SAG_FSPGR_3D_20180523111443.nii', 'SH056_SAG_FSPGR_CUBE_20180523111443.nii')
#      ('SH032_SAG_FSPGR_3D_20170417091212.nii', 'SH032_SAG_FSPGR_CUBE_20170417091212.nii')
#      ('SH032_SAG_FSPGR_3D_20170417091212.json', 'SH032_SAG_FSPGR_CUBE_20170417091212.json')
#      ('SH044_SAG_FSPGR_3D_20170620155335.json', 'SH044_SAG_FSPGR_CUBE_20170620155335.json')
#      ('SH044_SAG_FSPGR_3D_20170620155335.nii', 'SH044_SAG_FSPGR_CUBE_20170620155335.nii')
#      ('WH1726_Sagittal_T1_3D_20190702130610.json', 'WH1726_SAG_T1_CUBE_20190702130610.json')
#      ('WH1726_Sagittal_T1_3D_20190702130610.nii', 'WH1726_SAG_T1_CUBE_20190702130610.nii')
#      ('WH1726_CORONAL_T1_20190702130610.json', 'WH1726_COR_T1_20190702130610.json')
#      ('WH1726_CORONAL_T1_20190702130610.nii', 'WH1726_COR_T1_20190702130610.nii')
#      ('WH1726_SAGITTAL_T1_20190702130610.nii', 'WH1726_SAG_T1_20190702130610.nii')
#      ('WH1726_SAGITTAL_T1_20190702130610.json', 'WH1726_SAG_T1_20190702130610.json')
#      ('WH1726_AXIAL_T1_20190702130610.json', 'WH1726_AX_T1_20190702130610.json')
#      ('WH1726_AXIAL_T1_20190702130610.nii', 'WH1726_AX_T1_20190702130610.nii')
#      ('WH1621_SAG_FSPGR_3D_T1_20180416155525.nii', 'WH1621_SAG_FSPGR_CUBE_T1_20180416155525.nii')
#      ('WH1621_SAG_FSPGR_3D_T1_20180416155525.json', 'WH1621_SAG_FSPGR_CUBE_T1_20180416155525.json')
#      ('WH1609_SAG_FSPGR_3D_T1_20170623104119.nii', 'WH1609_SAG_FSPGR_CUBE_T1_20170623104119.nii')
#      ('WH1609_SAG_FSPGR_3D_T1_20170623104119.json', 'WH1609_SAG_FSPGR_CUBE_T1_20170623104119.json')
#      ('WH1647_SAG_FSPGR_3D_T1_20171204135728.json', 'WH1647_SAG_FSPGR_CUBE_T1_20171204135728.json')
#      ('WH1647_SAG_FSPGR_3D_T1_20171204135728.nii', 'WH1647_SAG_FSPGR_CUBE_T1_20171204135728.nii')
#      ('BR025_SAG_FSPGR_3D_T1_20180314150410.json', 'BR025_SAG_FSPGR_CUBE_T1_20180314150410.json')
#      ('BR025_SAG_FSPGR_3D_T1_20180314150410.nii', 'BR025_SAG_FSPGR_CUBE_T1_20180314150410.nii')
#      ('SH033_SAG_FSPGR_3D_20170504154607.nii', 'SH033_SAG_FSPGR_CUBE_20170504154607.nii')
#      ('SH033_SAG_FSPGR_3D_20170504154607.json', 'SH033_SAG_FSPGR_CUBE_20170504154607.json')
#      ('MEN008_SAG_FSPGR_3D_20170406135804.json', 'MN008_SAG_FSPGR_CUBE_20170406135804.json')
#      ('MEN008_SAG_FSPGR_3D_20170406135804.nii', 'MN008_SAG_FSPGR_CUBE_20170406135804.nii')
#      ('MEN042_SAG_FSPGR_3D_20170919135612.json', 'MN042_SAG_FSPGR_CUBE_20170919135612.json')
#      ('MEN042_SAG_FSPGR_3D_20170919135612.nii', 'MN042_SAG_FSPGR_CUBE_20170919135612.nii')
#      ('SH022_SAG_FSPGR_3D_20170307144621.nii', 'SH022_SAG_FSPGR_CUBE_20170307144621.nii')
#      ('SH022_SAG_FSPGR_3D_20170307144621.json', 'SH022_SAG_FSPGR_CUBE_20170307144621.json')
#      ('WH1653_SAG_FSPGR_3D_T1_20180213094821.json', 'WH1653_SAG_FSPGR_CUBE_T1_20180213094821.json')
#      ('WH1653_SAG_FSPGR_3D_T1_20180213094821.nii', 'WH1653_SAG_FSPGR_CUBE_T1_20180213094821.nii')
#      ('BR017_SAG_FSPGR_3D_20171214150846.json', 'BR017_SAG_FSPGR_CUBE_20171214150846.json')
#      ('BR017_SAG_FSPGR_3D_20171214150846.nii', 'BR017_SAG_FSPGR_CUBE_20171214150846.nii')
#      ('BR023_SAG_FSPGR_3D_T1_20180130092950.json', 'BR023_SAG_FSPGR_CUBE_T1_20180130092950.json')
#      ('BR023_SAG_FSPGR_3D_T1_20180130092950.nii', 'BR023_SAG_FSPGR_CUBE_T1_20180130092950.nii')
#      ('SH006_SAG_FSPGR_3D_20161221104818.json', 'SH006_SAG_FSPGR_CUBE_20161221104818.json')
#      ('SH006_SAG_FSPGR_3D_20161221104818.nii', 'SH006_SAG_FSPGR_CUBE_20161221104818.nii')
#      ('SH038_SAG_FSPGR_3D_20170505102428.nii', 'SH038_SAG_FSPGR_CUBE_20170505102428.nii')
#      ('SH038_SAG_FSPGR_3D_20170505102428.json', 'SH038_SAG_FSPGR_CUBE_20170505102428.json')
# ...
#      ('WH1662_FGM_PROBE-SV_35_20180831100221.nii', 'WH1662_FGM_PROBE_SV_35_20180831100221.nii')
#      ('SH054_Par_WM_PROBE-SV_35_20171211102322.json', 'SH054_PAR_WM_PROBE_SV_35_20171211102322.json')
#      ('SH054_Par_WM_PROBE-SV_35_20171211102322.nii', 'SH054_PAR_WM_PROBE_SV_35_20171211102322.nii')
#      ('SH054_BG_PROBE-SV_35_20171211102322.json', 'SH054_BG_PROBE_SV_35_20171211102322.json')
#      ('SH054_BG_PROBE-SV_35_20171211102322.nii', 'SH054_BG_PROBE_SV_35_20171211102322.nii')
#      ('SH054_FGM_PROBE-SV_35_20171211102322.nii', 'SH054_FGM_PROBE_SV_35_20171211102322.nii')
#      ('SH054_FGM_PROBE-SV_35_20171211102322.json', 'SH054_FGM_PROBE_SV_35_20171211102322.json')
#      ('SH054_Post_GM_PROBE-SV_35_20171211102322.json', 'SH054_POST_GM_PROBE_SV_35_20171211102322.json')
#      ('SH054_Post_GM_PROBE-SV_35_20171211102322.nii', 'SH054_POST_GM_PROBE_SV_35_20171211102322.nii')
#      ('SH054_FWM_PROBE-SV_35_20171211102322.nii', 'SH054_FWM_PROBE_SV_35_20171211102322.nii')
#      ('SH054_FWM_PROBE-SV_35_20171211102322.json', 'SH054_FWM_PROBE_SV_35_20171211102322.json')
#      ('BR040_Par_WM_PROBE-SV_35_20181203144627.nii', 'BR040_PAR_WM_PROBE_SV_35_20181203144627.nii')
#      ('BR040_Par_WM_PROBE-SV_35_20181203144627.json', 'BR040_PAR_WM_PROBE_SV_35_20181203144627.json')
#      ('BR040_BG_PROBE-SV_35_20181203144627.nii', 'BR040_BG_PROBE_SV_35_20181203144627.nii')
#      ('BR040_BG_PROBE-SV_35_20181203144627.json', 'BR040_BG_PROBE_SV_35_20181203144627.json')
#      ('BR040_FGM_PROBE-SV_35_20181203144627.json', 'BR040_FGM_PROBE_SV_35_20181203144627.json')
#      ('BR040_FGM_PROBE-SV_35_20181203144627.nii', 'BR040_FGM_PROBE_SV_35_20181203144627.nii')
#      ('BR040_Post_GM_PROBE-SV_35_20181203144627.nii', 'BR040_POST_GM_PROBE_SV_35_20181203144627.nii')
#      ('BR040_Post_GM_PROBE-SV_35_20181203144627.json', 'BR040_POST_GM_PROBE_SV_35_20181203144627.json')
#      ('BR040_FWM_PROBE-SV_35_20181203144627.json', 'BR040_FWM_PROBE_SV_35_20181203144627.json')
#      ('BR040_FWM_PROBE-SV_35_20181203144627.nii', 'BR040_FWM_PROBE_SV_35_20181203144627.nii')
#      ('WH1232_WM_PROBE-SV_35_20190311094507.nii', 'WH1232_WM_PROBE_SV_35_20190311094507.nii')
#      ('WH1232_WM_PROBE-SV_35_20190311094507.json', 'WH1232_WM_PROBE_SV_35_20190311094507.json')
#      ('WH1232_GM_PROBE-SV_35_20190311094507.json', 'WH1232_GM_PROBE_SV_35_20190311094507.json')
#      ('WH1232_GM_PROBE-SV_35_20190311094507.nii', 'WH1232_GM_PROBE_SV_35_20190311094507.nii')
#      ('SH053_Par_WM_PROBE-SV_35_20171107152207.json', 'SH053_PAR_WM_PROBE_SV_35_20171107152207.json')
#      ('SH053_Par_WM_PROBE-SV_35_20171107152207.nii', 'SH053_PAR_WM_PROBE_SV_35_20171107152207.nii')
#      ('SH053_BG_PROBE-SV_35_20171107152207.json', 'SH053_BG_PROBE_SV_35_20171107152207.json')
#      ('SH053_BG_PROBE-SV_35_20171107152207.nii', 'SH053_BG_PROBE_SV_35_20171107152207.nii')
#      ('SH053_FGM_PROBE-SV_35_20171107152207.nii', 'SH053_FGM_PROBE_SV_35_20171107152207.nii')
#      ('SH053_FGM_PROBE-SV_35_20171107152207.json', 'SH053_FGM_PROBE_SV_35_20171107152207.json')
#      ('SH053_Post_GM_PROBE-SV_35_20171107152207.json', 'SH053_POST_GM_PROBE_SV_35_20171107152207.json')
#      ('SH053_Post_GM_PROBE-SV_35_20171107152207.nii', 'SH053_POST_GM_PROBE_SV_35_20171107152207.nii')
#      ('SH053_FWM_PROBE-SV_35_20171107152207.nii', 'SH053_FWM_PROBE_SV_35_20171107152207.nii')
#      ('SH053_FWM_PROBE-SV_35_20171107152207.json', 'SH053_FWM_PROBE_SV_35_20171107152207.json')
#      ('MEN050_Par_WM_PROBE-SV_35_20181109145801.nii', 'MN050_PAR_WM_PROBE_SV_35_20181109145801.nii')
#      ('MEN050_Par_WM_PROBE-SV_35_20181109145801.json', 'MN050_PAR_WM_PROBE_SV_35_20181109145801.json')
#      ('MEN050_BG_PROBE-SV_35_20181109145801.nii', 'MN050_BG_PROBE_SV_35_20181109145801.nii')
#      ('MEN050_BG_PROBE-SV_35_20181109145801.json', 'MN050_BG_PROBE_SV_35_20181109145801.json')
#      ('MEN050_FGM_PROBE-SV_35_20181109145801.nii', 'MN050_FGM_PROBE_SV_35_20181109145801.nii')
#      ('MEN050_FGM_PROBE-SV_35_20181109145801.json', 'MN050_FGM_PROBE_SV_35_20181109145801.json')
#      ('MEN050_Post_GM_PROBE-SV_35_20181109145801.nii', 'MN050_POST_GM_PROBE_SV_35_20181109145801.nii')
#      ('MEN050_Post_GM_PROBE-SV_35_20181109145801.json', 'MN050_POST_GM_PROBE_SV_35_20181109145801.json')
#      ('MEN050_FWM_PROBE-SV_35_20181109145801.nii', 'MN050_FWM_PROBE_SV_35_20181109145801.nii')
#      ('MEN050_FWM_PROBE-SV_35_20181109145801.json', 'MN050_FWM_PROBE_SV_35_20181109145801.json')
#      ('MEN013_Par_WM_PROBE-SV_35_20170222101110.json', 'MN013_PAR_WM_PROBE_SV_35_20170222101110.json')
#      ('MEN013_Par_WM_PROBE-SV_35_20170222101110.nii', 'MN013_PAR_WM_PROBE_SV_35_20170222101110.nii')
#      ('MEN013_BG_PROBE-SV_35_20170222101110.json', 'MN013_BG_PROBE_SV_35_20170222101110.json')
#      ('MEN013_BG_PROBE-SV_35_20170222101110.nii', 'MN013_BG_PROBE_SV_35_20170222101110.nii')
#      ('MEN013_FGM_PROBE-SV_35_20170222101110.json', 'MN013_FGM_PROBE_SV_35_20170222101110.json')
#      ('MEN013_FGM_PROBE-SV_35_20170222101110.nii', 'MN013_FGM_PROBE_SV_35_20170222101110.nii')
#      ('MEN013_Post_GM_PROBE-SV_35_20170222101110.json', 'MN013_POST_GM_PROBE_SV_35_20170222101110.json')
#      ('MEN013_Post_GM_PROBE-SV_35_20170222101110.nii', 'MN013_POST_GM_PROBE_SV_35_20170222101110.nii')
#      ('MEN013_FWM_PROBE-SV_35_20170222101110.nii', 'MN013_FWM_PROBE_SV_35_20170222101110.nii')
#      ('MEN013_FWM_PROBE-SV_35_20170222101110.json', 'MN013_FWM_PROBE_SV_35_20170222101110.json')
#      ('WH1245_WM_PROBE-SV_35_20180316105153.nii', 'WH1245_WM_PROBE_SV_35_20180316105153.nii')
#      ('WH1245_WM_PROBE-SV_35_20180316105153.json', 'WH1245_WM_PROBE_SV_35_20180316105153.json')
#      ('WH1245_GM_PROBE-SV_35_20180316105153.json', 'WH1245_GM_PROBE_SV_35_20180316105153.json')
#      ('WH1245_GM_PROBE-SV_35_20180316105153.nii', 'WH1245_GM_PROBE_SV_35_20180316105153.nii')
#      ('WH1490_WM_PROBE-SV_35_20170327102834.json', 'WH1490_WM_PROBE_SV_35_20170327102834.json')
#      ('WH1490_WM_PROBE-SV_35_20170327102834.nii', 'WH1490_WM_PROBE_SV_35_20170327102834.nii')
#      ('WH1490_GM_PROBE-SV_35_20170327102834.nii', 'WH1490_GM_PROBE_SV_35_20170327102834.nii')
#      ('WH1490_GM_PROBE-SV_35_20170327102834.json', 'WH1490_GM_PROBE_SV_35_20170327102834.json')
#      ('WH1490_FGM_PROBE-SV_35_20170327102834.json', 'WH1490_FGM_PROBE_SV_35_20170327102834.json')
#      ('WH1490_FGM_PROBE-SV_35_20170327102834.nii', 'WH1490_FGM_PROBE_SV_35_20170327102834.nii')
#      ('WH1701_PGM_PROBE-SV_35_20181206093440.json', 'WH1701_PGM_PROBE_SV_35_20181206093440.json')
#      ('WH1701_PGM_PROBE-SV_35_20181206093440.nii', 'WH1701_PGM_PROBE_SV_35_20181206093440.nii')
#      ('SH060_Post_GM_PROBE-SV_35_20190628105216.nii', 'SH060_POST_GM_PROBE_SV_35_20190628105216.nii')
#      ('SH060_Post_GM_PROBE-SV_35_20190628105216.json', 'SH060_POST_GM_PROBE_SV_35_20190628105216.json')
#      ('SH024_Par_WM_PROBE-SV_35_20170329100405.nii', 'SH024_PAR_WM_PROBE_SV_35_20170329100405.nii')
#      ('SH024_Par_WM_PROBE-SV_35_20170329100405.json', 'SH024_PAR_WM_PROBE_SV_35_20170329100405.json')
#      ('SH024_BG_PROBE-SV_35_20170329100405.nii', 'SH024_BG_PROBE_SV_35_20170329100405.nii')
#      ('SH024_BG_PROBE-SV_35_20170329100405.json', 'SH024_BG_PROBE_SV_35_20170329100405.json')
#      ('SH024_PONS_PROBE-SV_35_20170329100405.json', 'SH024_PONS_PROBE_SV_35_20170329100405.json')
#      ('SH024_PONS_PROBE-SV_35_20170329100405.nii', 'SH024_PONS_PROBE_SV_35_20170329100405.nii')
#      ('SH024_FGM_PROBE-SV_35_20170329100405.nii', 'SH024_FGM_PROBE_SV_35_20170329100405.nii')
#      ('SH024_FGM_PROBE-SV_35_20170329100405.json', 'SH024_FGM_PROBE_SV_35_20170329100405.json')
#      ('SH024_Post_GM_PROBE-SV_35_20170329100405.json', 'SH024_POST_GM_PROBE_SV_35_20170329100405.json')
#      ('SH024_Post_GM_PROBE-SV_35_20170329100405.nii', 'SH024_POST_GM_PROBE_SV_35_20170329100405.nii')
#      ('SH024_FWM_PROBE-SV_35_20170329100405.nii', 'SH024_FWM_PROBE_SV_35_20170329100405.nii')
#      ('SH024_FWM_PROBE-SV_35_20170329100405.json', 'SH024_FWM_PROBE_SV_35_20170329100405.json')
#      ('WH1372_Par_WM_PROBE-SV_35_20190604102741.nii', 'WH1372_PAR_WM_PROBE_SV_35_20190604102741.nii')
#      ('WH1372_Par_WM_PROBE-SV_35_20190604102741.json', 'WH1372_PAR_WM_PROBE_SV_35_20190604102741.json')
#      ('WH1372_Post_GM_PROBE-SV_35_20190604102741.json', 'WH1372_POST_GM_PROBE_SV_35_20190604102741.json')
#      ('WH1372_Post_GM_PROBE-SV_35_20190604102741.nii', 'WH1372_POST_GM_PROBE_SV_35_20190604102741.nii')
#      ('SH050_Par_WM_PROBE-SV_35_20171003113239.json', 'SH050_PAR_WM_PROBE_SV_35_20171003113239.json')
#      ('SH050_Par_WM_PROBE-SV_35_20171003113239.nii', 'SH050_PAR_WM_PROBE_SV_35_20171003113239.nii')
#      ('SH050_BG_PROBE-SV_35_20171003113239.nii', 'SH050_BG_PROBE_SV_35_20171003113239.nii')
#      ('SH050_BG_PROBE-SV_35_20171003113239.json', 'SH050_BG_PROBE_SV_35_20171003113239.json')
#      ('SH050_PONS_PROBE-SV_35_20171003113239.nii', 'SH050_PONS_PROBE_SV_35_20171003113239.nii')
#      ('SH050_PONS_PROBE-SV_35_20171003113239.json', 'SH050_PONS_PROBE_SV_35_20171003113239.json')
#      ('SH050_FGM_PROBE-SV_35_20171003113239.nii', 'SH050_FGM_PROBE_SV_35_20171003113239.nii')
#      ('SH050_FGM_PROBE-SV_35_20171003113239.json', 'SH050_FGM_PROBE_SV_35_20171003113239.json')
#      ('SH050_Post_GM_PROBE-SV_35_20171003113239.json', 'SH050_POST_GM_PROBE_SV_35_20171003113239.json')
#      ('SH050_Post_GM_PROBE-SV_35_20171003113239.nii', 'SH050_POST_GM_PROBE_SV_35_20171003113239.nii')
#      ('SH050_FWM_PROBE-SV_35_20171003113239.nii', 'SH050_FWM_PROBE_SV_35_20171003113239.nii')
#      ('SH050_FWM_PROBE-SV_35_20171003113239.json', 'SH050_FWM_PROBE_SV_35_20171003113239.json')
#      ('MEN027_Par_WM_PROBE-SV_35_20170303141530.json', 'MN027_PAR_WM_PROBE_SV_35_20170303141530.json')
#      ('MEN027_Par_WM_PROBE-SV_35_20170303141530.nii', 'MN027_PAR_WM_PROBE_SV_35_20170303141530.nii')
#      ('MEN027_BG_PROBE-SV_35_20170303141530.json', 'MN027_BG_PROBE_SV_35_20170303141530.json')
#      ('MEN027_BG_PROBE-SV_35_20170303141530.nii', 'MN027_BG_PROBE_SV_35_20170303141530.nii')
#      ('MEN027_FGM_PROBE-SV_35_20170303141530.json', 'MN027_FGM_PROBE_SV_35_20170303141530.json')
#      ('MEN027_FGM_PROBE-SV_35_20170303141530.nii', 'MN027_FGM_PROBE_SV_35_20170303141530.nii')
#      ('MEN027_Post_GM_PROBE-SV_35_20170303141530.json', 'MN027_POST_GM_PROBE_SV_35_20170303141530.json')
#      ('MEN027_Post_GM_PROBE-SV_35_20170303141530.nii', 'MN027_POST_GM_PROBE_SV_35_20170303141530.nii')
#      ('MEN027_FWM_PROBE-SV_35_20170303141530.nii', 'MN027_FWM_PROBE_SV_35_20170303141530.nii')
#      ('MEN027_FWM_PROBE-SV_35_20170303141530.json', 'MN027_FWM_PROBE_SV_35_20170303141530.json')
#      ('WH1618_WM_PROBE-SV_35_20171219143448.nii', 'WH1618_WM_PROBE_SV_35_20171219143448.nii')
#      ('WH1618_WM_PROBE-SV_35_20171219143448.json', 'WH1618_WM_PROBE_SV_35_20171219143448.json')
#      ('WH1618_GM_PROBE-SV_35_20171219143448.json', 'WH1618_GM_PROBE_SV_35_20171219143448.json')
#      ('WH1618_GM_PROBE-SV_35_20171219143448.nii', 'WH1618_GM_PROBE_SV_35_20171219143448.nii')
#      ('WH1624_WM_PROBE-SV_35_20170829105946.nii', 'WH1624_WM_PROBE_SV_35_20170829105946.nii')
#      ('WH1624_WM_PROBE-SV_35_20170829105946.json', 'WH1624_WM_PROBE_SV_35_20170829105946.json')
#      ('WH1624_GM_PROBE-SV_35_20170829105946.json', 'WH1624_GM_PROBE_SV_35_20170829105946.json')
#      ('WH1624_GM_PROBE-SV_35_20170829105946.nii', 'WH1624_GM_PROBE_SV_35_20170829105946.nii')
#      ('WH1624_FGM_PROBE-SV_35_20170829105946.nii', 'WH1624_FGM_PROBE_SV_35_20170829105946.nii')
#      ('WH1624_FGM_PROBE-SV_35_20170829105946.json', 'WH1624_FGM_PROBE_SV_35_20170829105946.json')
#      ('WH1488_Par_WM_PROBE-SV_35_20191022102404.nii', 'WH1488_PAR_WM_PROBE_SV_35_20191022102404.nii')
#      ('WH1488_Par_WM_PROBE-SV_35_20191022102404.json', 'WH1488_PAR_WM_PROBE_SV_35_20191022102404.json')
#      ('WH1488_Post_GM_PROBE-SV_35_20191022102404.nii', 'WH1488_POST_GM_PROBE_SV_35_20191022102404.nii')
#      ('WH1488_Post_GM_PROBE-SV_35_20191022102404.json', 'WH1488_POST_GM_PROBE_SV_35_20191022102404.json')
#      ('SH034_Par_WM_PROBE-SV_35_20170501151802.nii', 'SH034_PAR_WM_PROBE_SV_35_20170501151802.nii')
#      ('SH034_Par_WM_PROBE-SV_35_20170501151802.json', 'SH034_PAR_WM_PROBE_SV_35_20170501151802.json')
#      ('SH034_BG_PROBE-SV_35_20170501151802.json', 'SH034_BG_PROBE_SV_35_20170501151802.json')
#      ('SH034_BG_PROBE-SV_35_20170501151802.nii', 'SH034_BG_PROBE_SV_35_20170501151802.nii')
#      ('SH034_PONS_PROBE-SV_35_20170501151802.nii', 'SH034_PONS_PROBE_SV_35_20170501151802.nii')
#      ('SH034_PONS_PROBE-SV_35_20170501151802.json', 'SH034_PONS_PROBE_SV_35_20170501151802.json')
#      ('SH034_FGM_PROBE-SV_35_20170501151802.nii', 'SH034_FGM_PROBE_SV_35_20170501151802.nii')
#      ('SH034_FGM_PROBE-SV_35_20170501151802.json', 'SH034_FGM_PROBE_SV_35_20170501151802.json')
#      ('SH034_Post_GM_PROBE-SV_35_20170501151802.json', 'SH034_POST_GM_PROBE_SV_35_20170501151802.json')
#      ('SH034_Post_GM_PROBE-SV_35_20170501151802.nii', 'SH034_POST_GM_PROBE_SV_35_20170501151802.nii')
#      ('SH034_FWM_PROBE-SV_35_20170501151802.json', 'SH034_FWM_PROBE_SV_35_20170501151802.json')
#      ('SH034_FWM_PROBE-SV_35_20170501151802.nii', 'SH034_FWM_PROBE_SV_35_20170501151802.nii')
#      ('SH040_Par_WM_PROBE-SV_35_20170518143236.json', 'SH040_PAR_WM_PROBE_SV_35_20170518143236.json')
#      ('SH040_Par_WM_PROBE-SV_35_20170518143236.nii', 'SH040_PAR_WM_PROBE_SV_35_20170518143236.nii')
#      ('SH040_BG_PROBE-SV_35_20170518143236.json', 'SH040_BG_PROBE_SV_35_20170518143236.json')
#      ('SH040_BG_PROBE-SV_35_20170518143236.nii', 'SH040_BG_PROBE_SV_35_20170518143236.nii')
#      ('SH040_PONS_PROBE-SV_35_20170518143236.json', 'SH040_PONS_PROBE_SV_35_20170518143236.json')
#      ('SH040_PONS_PROBE-SV_35_20170518143236.nii', 'SH040_PONS_PROBE_SV_35_20170518143236.nii')
#      ('SH040_FGM_PROBE-SV_35_20170518143236.json', 'SH040_FGM_PROBE_SV_35_20170518143236.json')
#      ('SH040_FGM_PROBE-SV_35_20170518143236.nii', 'SH040_FGM_PROBE_SV_35_20170518143236.nii')
#      ('SH040_Post_GM_PROBE-SV_35_20170518143236.json', 'SH040_POST_GM_PROBE_SV_35_20170518143236.json')
#      ('SH040_Post_GM_PROBE-SV_35_20170518143236.nii', 'SH040_POST_GM_PROBE_SV_35_20170518143236.nii')
#      ('SH040_FWM_PROBE-SV_35_20170518143236.nii', 'SH040_FWM_PROBE_SV_35_20170518143236.nii')
#      ('SH040_FWM_PROBE-SV_35_20170518143236.json', 'SH040_FWM_PROBE_SV_35_20170518143236.json')
#      ('MEN019_Par_WM_PROBE-SV_35_20170223095238.json', 'MN019_PAR_WM_PROBE_SV_35_20170223095238.json')
#      ('MEN019_Par_WM_PROBE-SV_35_20170223095238.nii', 'MN019_PAR_WM_PROBE_SV_35_20170223095238.nii')
#      ('MEN019_BG_PROBE-SV_35_20170223095238.nii', 'MN019_BG_PROBE_SV_35_20170223095238.nii')
#      ('MEN019_BG_PROBE-SV_35_20170223095238.json', 'MN019_BG_PROBE_SV_35_20170223095238.json')
#      ('MEN019_FGM_PROBE-SV_35_20170223095238.nii', 'MN019_FGM_PROBE_SV_35_20170223095238.nii')
#      ('MEN019_FGM_PROBE-SV_35_20170223095238.json', 'MN019_FGM_PROBE_SV_35_20170223095238.json')
#      ('MEN019_Post_GM_PROBE-SV_35_20170223095238.json', 'MN019_POST_GM_PROBE_SV_35_20170223095238.json')
#      ('MEN019_Post_GM_PROBE-SV_35_20170223095238.nii', 'MN019_POST_GM_PROBE_SV_35_20170223095238.nii')
#      ('MEN019_FWM_PROBE-SV_35_20170223095238.json', 'MN019_FWM_PROBE_SV_35_20170223095238.json')
#      ('MEN019_FWM_PROBE-SV_35_20170223095238.nii', 'MN019_FWM_PROBE_SV_35_20170223095238.nii')
#      ('BR033_Par_WM_PROBE-SV_35_20190411112518.nii', 'BR033_PAR_WM_PROBE_SV_35_20190411112518.nii')
#      ('BR033_Par_WM_PROBE-SV_35_20190411112518.json', 'BR033_PAR_WM_PROBE_SV_35_20190411112518.json')
#      ('BR033_Post_GM_PROBE-SV_35_20190411112518.nii', 'BR033_POST_GM_PROBE_SV_35_20190411112518.nii')
#      ('BR033_Post_GM_PROBE-SV_35_20190411112518.json', 'BR033_POST_GM_PROBE_SV_35_20190411112518.json')
#      ('WH1645_WM_PROBE-SV_35_20180208143523.nii', 'WH1645_WM_PROBE_SV_35_20180208143523.nii')
#      ('WH1645_WM_PROBE-SV_35_20180208143523.json', 'WH1645_WM_PROBE_SV_35_20180208143523.json')
#      ('WH1645_GM_PROBE-SV_35_20180208143523.nii', 'WH1645_GM_PROBE_SV_35_20180208143523.nii')
#      ('WH1645_GM_PROBE-SV_35_20180208143523.json', 'WH1645_GM_PROBE_SV_35_20180208143523.json')

# %%
# NOTE: Standarized Naming
# > study ID: 2 letters 

# "3D_T1": <AB####>
# "FLAIR": <ID>_{SAG | AX | COR}_[T1_ | T2_][3D_]FLAIR_<DOE>.nii
# "T2": <ID>_{SAG | AX | COR}_3D_T2_[<type>]<DOE>.nii
# "T2": <ID>_{SAG | AX | COR}_T2_[<type>]<DOE>_<tag>.nii
# "BOLD": <ID>_BOLD_<DOE>.nii
# "Diffusion kurtosis": <ID>_{AX}_DkI_<small#dirs>_<DOE>.nii
#                       <ID>_{AX}_DkI_<small#dirs>_<DOE>.bval
#                       <ID>_{AX}_DkI_<small#dirs>_<DOE>.bvec
# .                     <ID>_{AX}_DkI_<big#dirs>_<DOE>.nii
#                       <ID>_{AX}_DkI_<big#dirs>_<DOE>.bval
#                       <ID>_{AX}_DkI_<big#dirs>_<DOE>.bvec
# "Diffusion tensor": <ID>_{AX}_D{k|T}I_<#dir>_<DOE>.nii
#                     <ID>_{AX}_D{k|T}I_<#dir>_<DOE>.bval
#                     <ID>_{AX}_D{k|T}I_<#dir>_<DOE>.bvec
# "Diffusion weithed": <ID>_{AX}_DWI_<DOE>.nii
#                      <ID>_{AX}_DWI_<DOE>.bval
#                      <ID>_{AX}_DWI_<DOE>.bvec
# "ASL": <ID>_{SAG | AX | COR}_ASL_<DOE>.nii   
# "SWAN": <ID>_{SAG | AX | COR}_ASL_<DOE>.nii
# "Carotid"
# "Aorta": <ID>_[CINE]_AORTA_VENC_<number>_<DOE>.nii
